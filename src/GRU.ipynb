# %%
from pandas import read_csv
#Load data set
look_back = 15
split = 735-200
series_influ_A_df = read_csv('../temp_data/influA_vietnam_last_10_days.csv', index_col=0, engine='python')
series_influ_A_df = series_influ_A_df.iloc[200:]
train_df = series_influ_A_df.iloc[0:split]
test_df = series_influ_A_df.iloc[split-look_back:]
# series_influ_A_df = series_influ_A_df["case"]

series_influ_A_df = series_influ_A_df.rename(columns= {"Influenza A - All types of surveillance": "case"})
series_influ_A_df = series_influ_A_df[["case", "temp", "tempmax", "dew","windspeed"]]

# %%
def exponential_moving_average(data, span):
    return data.ewm(span=span, adjust=False).mean()

# %%
series_influ_A_df = series_influ_A_df.dropna()
span = 52  # Bạn có thể điều chỉnh độ dài span tùy ý
series_influ_A_df['case'] = exponential_moving_average(series_influ_A_df['case'], span)
series_influ_A_df = series_influ_A_df.astype('float32')
series_influ_A_df = series_influ_A_df.values
# normalize the dataset
from sklearn.preprocessing import MinMaxScaler, RobustScaler
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(series_influ_A_df)
# scaler = RobustScaler()
# dataset = scaler.fit_transform(series_influ_A_df)
# Create Training and Test

train = dataset[:split, :]
test = dataset[split-look_back:, :]

import numpy as np
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

# %%
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN, GRU


model = Sequential([
    GRU(units=64, activation='relu', input_shape=(look_back,5)),
    #  Dense(units=32, activation='relu'),
    #   Dense(units=16, activation='relu'),
    Dense(units=5, activation='sigmoid' )
])

# # Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2, validation_data=(testX, testY))
# Out:
# Epoch 1/100
# d:\my_study\gr3\DATN\venv\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 520/520 - 3s - 5ms/step - loss: 0.0321 - val_loss: 0.0183
# Epoch 2/100
# 520/520 - 1s - 3ms/step - loss: 0.0152 - val_loss: 0.0122
# Epoch 3/100
# 520/520 - 1s - 3ms/step - loss: 0.0108 - val_loss: 0.0115
# Epoch 4/100
# 520/520 - 1s - 3ms/step - loss: 0.0100 - val_loss: 0.0116
# Epoch 5/100
# 520/520 - 1s - 3ms/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 6/100
# 520/520 - 1s - 3ms/step - loss: 0.0093 - val_loss: 0.0114
# Epoch 7/100
# 520/520 - 1s - 3ms/step - loss: 0.0089 - val_loss: 0.0115
# Epoch 8/100
# 520/520 - 1s - 3ms/step - loss: 0.0085 - val_loss: 0.0114
# Epoch 9/100
# 520/520 - 1s - 3ms/step - loss: 0.0084 - val_loss: 0.0112
# Epoch 10/100
# 520/520 - 1s - 3ms/step - loss: 0.0084 - val_loss: 0.0105
# Epoch 11/100
# 520/520 - 1s - 3ms/step - loss: 0.0081 - val_loss: 0.0109
# Epoch 12/100
# 520/520 - 1s - 3ms/step - loss: 0.0080 - val_loss: 0.0100
# Epoch 13/100
# 520/520 - 1s - 3ms/step - loss: 0.0078 - val_loss: 0.0097
# Epoch 14/100
# 520/520 - 1s - 3ms/step - loss: 0.0079 - val_loss: 0.0099
# Epoch 15/100
# 520/520 - 1s - 3ms/step - loss: 0.0078 - val_loss: 0.0115
# Epoch 16/100
# 520/520 - 1s - 3ms/step - loss: 0.0078 - val_loss: 0.0101
# Epoch 17/100
# 520/520 - 2s - 3ms/step - loss: 0.0077 - val_loss: 0.0097
# Epoch 18/100
# 520/520 - 1s - 3ms/step - loss: 0.0076 - val_loss: 0.0094
# Epoch 19/100
# 520/520 - 1s - 3ms/step - loss: 0.0075 - val_loss: 0.0098
# Epoch 20/100
# 520/520 - 1s - 3ms/step - loss: 0.0074 - val_loss: 0.0095
# Epoch 21/100
# 520/520 - 1s - 3ms/step - loss: 0.0074 - val_loss: 0.0099
# Epoch 22/100
# 520/520 - 1s - 3ms/step - loss: 0.0074 - val_loss: 0.0095
# Epoch 23/100
# 520/520 - 1s - 3ms/step - loss: 0.0074 - val_loss: 0.0092
# Epoch 24/100
# 520/520 - 1s - 3ms/step - loss: 0.0073 - val_loss: 0.0093
# Epoch 25/100
# 520/520 - 1s - 3ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 26/100
# 520/520 - 1s - 3ms/step - loss: 0.0072 - val_loss: 0.0098
# Epoch 27/100
# 520/520 - 1s - 3ms/step - loss: 0.0071 - val_loss: 0.0093
# Epoch 28/100
# 520/520 - 1s - 3ms/step - loss: 0.0070 - val_loss: 0.0097
# Epoch 29/100
# 520/520 - 1s - 3ms/step - loss: 0.0070 - val_loss: 0.0093
# Epoch 30/100
# 520/520 - 1s - 3ms/step - loss: 0.0070 - val_loss: 0.0097
# Epoch 31/100
# 520/520 - 1s - 3ms/step - loss: 0.0071 - val_loss: 0.0093
# Epoch 32/100
# 520/520 - 1s - 3ms/step - loss: 0.0071 - val_loss: 0.0089
# Epoch 33/100
# 520/520 - 1s - 3ms/step - loss: 0.0069 - val_loss: 0.0094
# Epoch 34/100
# 520/520 - 1s - 3ms/step - loss: 0.0069 - val_loss: 0.0093
# Epoch 35/100
# 520/520 - 1s - 3ms/step - loss: 0.0069 - val_loss: 0.0090
# Epoch 36/100
# 520/520 - 1s - 3ms/step - loss: 0.0067 - val_loss: 0.0092
# Epoch 37/100
# 520/520 - 1s - 3ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 38/100
# 520/520 - 1s - 3ms/step - loss: 0.0067 - val_loss: 0.0091
# Epoch 39/100
# 520/520 - 1s - 3ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 40/100
# 520/520 - 1s - 3ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 41/100
# 520/520 - 1s - 3ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 42/100
# 520/520 - 1s - 3ms/step - loss: 0.0065 - val_loss: 0.0086
# Epoch 43/100
# 520/520 - 1s - 3ms/step - loss: 0.0066 - val_loss: 0.0093
# Epoch 44/100
# 520/520 - 1s - 3ms/step - loss: 0.0066 - val_loss: 0.0092
# Epoch 45/100
# 520/520 - 1s - 3ms/step - loss: 0.0066 - val_loss: 0.0094
# Epoch 46/100
# 520/520 - 1s - 3ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 47/100
# 520/520 - 1s - 3ms/step - loss: 0.0066 - val_loss: 0.0089
# Epoch 48/100
# 520/520 - 1s - 3ms/step - loss: 0.0064 - val_loss: 0.0091
# Epoch 49/100
# 520/520 - 1s - 3ms/step - loss: 0.0065 - val_loss: 0.0093
# Epoch 50/100
# 520/520 - 1s - 3ms/step - loss: 0.0063 - val_loss: 0.0087
# Epoch 51/100
# 520/520 - 1s - 3ms/step - loss: 0.0063 - val_loss: 0.0096
# Epoch 52/100
# 520/520 - 1s - 3ms/step - loss: 0.0063 - val_loss: 0.0098
# Epoch 53/100
# 520/520 - 1s - 3ms/step - loss: 0.0062 - val_loss: 0.0088
# Epoch 54/100
# 520/520 - 1s - 3ms/step - loss: 0.0062 - val_loss: 0.0092
# Epoch 55/100
# 520/520 - 1s - 3ms/step - loss: 0.0062 - val_loss: 0.0092
# Epoch 56/100
# 520/520 - 1s - 3ms/step - loss: 0.0061 - val_loss: 0.0094
# Epoch 57/100
# 520/520 - 1s - 3ms/step - loss: 0.0060 - val_loss: 0.0102
# Epoch 58/100
# 520/520 - 1s - 3ms/step - loss: 0.0060 - val_loss: 0.0093
# Epoch 59/100
# 520/520 - 1s - 3ms/step - loss: 0.0060 - val_loss: 0.0090
# Epoch 60/100
# 520/520 - 1s - 3ms/step - loss: 0.0060 - val_loss: 0.0091
# Epoch 61/100
# 520/520 - 1s - 3ms/step - loss: 0.0059 - val_loss: 0.0104
# Epoch 62/100
# 520/520 - 1s - 3ms/step - loss: 0.0059 - val_loss: 0.0095
# Epoch 63/100
# 520/520 - 1s - 3ms/step - loss: 0.0058 - val_loss: 0.0094
# Epoch 64/100
# 520/520 - 1s - 3ms/step - loss: 0.0058 - val_loss: 0.0091
# Epoch 65/100
# 520/520 - 1s - 3ms/step - loss: 0.0058 - val_loss: 0.0095
# Epoch 66/100
# 520/520 - 1s - 3ms/step - loss: 0.0058 - val_loss: 0.0094
# Epoch 67/100
# 520/520 - 1s - 3ms/step - loss: 0.0056 - val_loss: 0.0096
# Epoch 68/100
# 520/520 - 1s - 3ms/step - loss: 0.0058 - val_loss: 0.0092
# Epoch 69/100
# 520/520 - 1s - 3ms/step - loss: 0.0056 - val_loss: 0.0104
# Epoch 70/100
# 520/520 - 1s - 3ms/step - loss: 0.0056 - val_loss: 0.0098
# Epoch 71/100
# 520/520 - 1s - 3ms/step - loss: 0.0055 - val_loss: 0.0103
# Epoch 72/100
# 520/520 - 1s - 3ms/step - loss: 0.0054 - val_loss: 0.0096
# Epoch 73/100
# 520/520 - 1s - 3ms/step - loss: 0.0055 - val_loss: 0.0097
# Epoch 74/100
# 520/520 - 1s - 3ms/step - loss: 0.0055 - val_loss: 0.0098
# Epoch 75/100
# 520/520 - 1s - 3ms/step - loss: 0.0054 - val_loss: 0.0101
# Epoch 76/100
# 520/520 - 1s - 3ms/step - loss: 0.0053 - val_loss: 0.0100
# Epoch 77/100
# 520/520 - 1s - 3ms/step - loss: 0.0053 - val_loss: 0.0100
# Epoch 78/100
# 520/520 - 1s - 3ms/step - loss: 0.0052 - val_loss: 0.0099
# Epoch 79/100
# 520/520 - 1s - 3ms/step - loss: 0.0053 - val_loss: 0.0101
# Epoch 80/100
# 520/520 - 1s - 3ms/step - loss: 0.0052 - val_loss: 0.0094
# Epoch 81/100
# 520/520 - 1s - 3ms/step - loss: 0.0053 - val_loss: 0.0106
# Epoch 82/100
# 520/520 - 1s - 3ms/step - loss: 0.0051 - val_loss: 0.0096
# Epoch 83/100
# 520/520 - 1s - 3ms/step - loss: 0.0052 - val_loss: 0.0106
# Epoch 84/100
# 520/520 - 1s - 3ms/step - loss: 0.0050 - val_loss: 0.0103
# Epoch 85/100
# 520/520 - 1s - 3ms/step - loss: 0.0051 - val_loss: 0.0112
# Epoch 86/100
# 520/520 - 1s - 3ms/step - loss: 0.0050 - val_loss: 0.0101
# Epoch 87/100
# 520/520 - 1s - 3ms/step - loss: 0.0050 - val_loss: 0.0100
# Epoch 88/100
# 520/520 - 1s - 3ms/step - loss: 0.0048 - val_loss: 0.0104
# Epoch 89/100
# 520/520 - 1s - 3ms/step - loss: 0.0049 - val_loss: 0.0104
# Epoch 90/100
# 520/520 - 1s - 3ms/step - loss: 0.0049 - val_loss: 0.0114
# Epoch 91/100
# 520/520 - 1s - 3ms/step - loss: 0.0047 - val_loss: 0.0114
# Epoch 92/100
# 520/520 - 1s - 3ms/step - loss: 0.0049 - val_loss: 0.0106
# Epoch 93/100
# 520/520 - 1s - 3ms/step - loss: 0.0047 - val_loss: 0.0108
# Epoch 94/100
# 520/520 - 1s - 3ms/step - loss: 0.0048 - val_loss: 0.0109
# Epoch 95/100
# 520/520 - 1s - 3ms/step - loss: 0.0047 - val_loss: 0.0114
# Epoch 96/100
# 520/520 - 1s - 3ms/step - loss: 0.0046 - val_loss: 0.0105
# Epoch 97/100
# 520/520 - 1s - 3ms/step - loss: 0.0047 - val_loss: 0.0104
# Epoch 98/100
# 520/520 - 1s - 3ms/step - loss: 0.0046 - val_loss: 0.0107
# Epoch 99/100
# 520/520 - 1s - 3ms/step - loss: 0.0045 - val_loss: 0.0127
# Epoch 100/100
# 520/520 - 1s - 3ms/step - loss: 0.0046 - val_loss: 0.0111

# %%
from sklearn.metrics import mean_squared_error
# [[1,3]] :shape 1,2
def predict_one(X, model):
    X= np.array([X])
    predicted = model.predict(X, verbose=0)
    return predicted[0]


#X_start: [[1,3]]
def predict(X_start, num_weeks, model):
    result = []
    X=np.array([X_start])
    for i in range(num_weeks):
        predicted = predict_one(X[i], model)
        result.append(predicted)
        X_continue = np.vstack((X[-1][1:], predicted.reshape(1,5)))
        X = np.append(X, [X_continue], axis=0)
    import json
    # with open('./X.json', 'w') as f:
    #     json.dump(X.tolist(), f)
    return result
    
# make predictions
# testPredict = model.predict(testX)
testPredict = predict(testX[0], len(test)-look_back, model)
# invert predictions
testPredict = scaler.inverse_transform(testPredict)
testY_ = scaler.inverse_transform(testY)
# calculate root mean squared error
testScore = np.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 20.91 RMSE

# %%
import matplotlib.pyplot as plt
# (x,3)
testPredictPlot = np.empty([testX.shape[0]])
testPredictPlot[:] = np.nan
testPredictPlot[:] = testPredict[:,0].reshape(-1)
testPlot = np.empty([testX.shape[0]])
testPlot[:] = np.nan
testPlot[:] = scaler.inverse_transform(test[look_back:])[:,0].reshape(-1)
# plt.plot(scaler.inverse_transform(train)[:,0].reshape(-1), label="observed")
plt.plot(testPlot, "-y", label="actual", marker= '.')
plt.plot(testPredictPlot, color = 'green', label="forecast", marker='x')
plt.xlabel("Day since 2009-01-12 week by week")
plt.ylabel("Number of infections")
plt.legend(["observed", "actual", "forecast"])
plt.show()
