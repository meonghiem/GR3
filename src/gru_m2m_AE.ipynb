# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, RobustScaler
scaler = MinMaxScaler()
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM, TimeDistributed, Input, Dropout, GRU
from sklearn.model_selection import GridSearchCV
import tensorflow as tf
from keras.saving import register_keras_serializable
from sklearn.metrics import r2_score

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(0, len(dataset)-2 *look_back+1, look_back):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back: i+ 2*look_back])
    return np.array(dataX), np.array(dataY)

def exponential_moving_average(data, span):
    return data.ewm(span=span, adjust=False).mean()

def read_data(file_path, num_features = 1):
    from pandas import read_csv
    series_influ_A_df = read_csv(file_path, index_col=0, engine='python')
    series_influ_A_df = series_influ_A_df.rename(columns= {"Influenza A - All types of surveillance": "case"})
    series_influ_A_df = series_influ_A_df[["case", "humidity", "temp", "dew","windspeed", "tempmax",][:num_features]]
    return series_influ_A_df.dropna()

def prepare_data(series, look_back, scaler, is_ema = False):
    if is_ema:
        span = 52  # Bạn có thể điều chỉnh độ dài span tùy ý
        series['case'] = exponential_moving_average(series['case'], span)
    series = series.astype('float32')
    series = series.values
    if scaler is not None:
        flattened_dataset = series.flatten()
        dataset = scaler.fit_transform(flattened_dataset.reshape(-1,1))
        dataset = dataset.reshape(series.shape)

    else: 
        dataset = series

    rest = len(dataset) % look_back
    dataset = dataset[rest:, :]
    trainsize = len(dataset) - look_back
    train = dataset[:trainsize, :]
    test = dataset[trainsize - look_back:, :]

    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)
    return trainX, trainY, testX, testY

def forecast(input, model):
    predicted = model.predict(input, verbose=0)
    return predicted


def save_plot(x,y, file_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Create the scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, squared_error, color='red', marker="o", label=f'squared Error (R²={r2:.2f})')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title('Scatter Plot with R-squared Line')
    plt.legend()
    plt.grid()
    plt.savefig(file_path)
    plt.close()

def inverse_transform(data, scaler):
    flattened_data = data.flatten()
    inverse_flattened_data = scaler.inverse_transform(flattened_data.reshape(-1,1))
    return inverse_flattened_data.reshape(data.shape)

# %%
@register_keras_serializable()
class MyLSTM (Sequential):
    def __init__(self, look_back, dense_units =[],unit=64, optimizer='adam',name='lstm'):
        super().__init__(name=name)
        self.look_back = look_back
        self.add(Input(shape=(look_back,1)))
        self.add(LSTM(units=unit, activation='relu', return_sequences=True))
        for unit in dense_units:
            self.add(Dense(units=unit, activation='relu'))
        self.add(TimeDistributed(Dense(units=5, activation='sigmoid' )))
        self.compile(optimizer=optimizer, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    

def build_model(input_shape, dropout=None, dense_units = [], unit=64, optimizer='adam'):
    model = Sequential()
    model.add(Input(shape=input_shape))

    #Encoder:
    # First GRU layer with Dropout regularisation
    model.add(GRU(units=dense_units[0], return_sequences=True))
    model.add(Dropout(0.2))
    # Second GRU layer
    model.add(GRU(units=dense_units[1], return_sequences=True))
    model.add(Dropout(0.2))
    # Third GRU layer
    model.add(GRU(units=dense_units[2], return_sequences=True))
    model.add(Dropout(0.2))

    #Decoder
    # Fourth GRU layer
    model.add(GRU(units=dense_units[2], return_sequences=True))
    model.add(Dropout(0.2))

    model.add(GRU(units=dense_units[1], return_sequences=True))
    model.add(Dropout(0.2))
    # Fourth GRU layer
    model.add(GRU(units=dense_units[0], return_sequences=True))
    model.add(Dropout(0.2))

    # if first_additional_layer:
    #     model.add(LSTM(units=unit, return_sequences=True))
    #     model.add(Dropout(dropout))

    # if second_additional_layer:
    #     model.add(LSTM(units=unit, return_sequences=True))
    #     model.add(Dropout(dropout))

    # if third_additional_layer:
    #     model.add(GRU(units=unit, return_sequences=True))
    #     model.add(Dropout(dropout))
    model.add(TimeDistributed(Dense(units=input_shape[1], activation='sigmoid' )))
    model.compile(optimizer=optimizer, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# %%
def plot(testY, forecasts):
    import matplotlib.pyplot as plt
    forecastsPlot = forecasts[:,:,0].reshape(-1)
    testPlot = testY[:,:,0].reshape(-1)
    plt.plot(testPlot, "-y", label="actual", marker= '.')
    plt.plot(forecastsPlot, color = 'green', marker = 'x', label="forecast")
    plt.ylabel("Number of infections")
    plt.legend(["actual", "forecast"])
    plt.show()

# %%
import itertools
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os, json
from keras.models import load_model


def LSTM_HyperParameter_Tuning(config, df, scaler):
    
    num_features, layers, n_neurons, n_batch_sizes, dropouts, look_backs, is_emas = config
    possible_combinations = list(itertools.product(num_features, layers, n_neurons, n_batch_sizes, dropouts, look_backs, is_emas))
    
    print(possible_combinations)
    print('\n')
    
    hist = []
    for i in range(0, len(possible_combinations)):
        print(f'{i+1}th combination: \n')
        print('--------------------------------------------------------------------')
        num_features, layers, n_neurons, n_batch_size, dropout, look_back, is_ema = possible_combinations[i]

        df = read_data('../temp_data/influA_vietnam_last_10_days.csv',num_features=num_features)
        
        trainX, trainY, testX, testY = prepare_data(df, look_back, scaler, is_ema=is_ema)
        model = build_model(
            input_shape=(trainX.shape[1], trainX.shape[2]),
            # first_additional_layer= layers[0],
            # second_additional_layer=layers[1],
            # third_additional_layer=layers[2],
            dense_units=n_neurons[1:],
            unit=n_neurons[0])

        es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
        '''''
        From the mentioned article above --> If a validation dataset is specified to the fit() function via the validation_data or v
        alidation_split arguments,then the loss on the validation dataset will be made available via the name “val_loss.”
        '''''
        a = 'ema' if is_ema else 'not_ema'
        lstm_dir = os.path.join("../result", f"""gru_AE_{a}""")
        lstm_combination_dir = os.path.join(lstm_dir, str(i))
        os.makedirs(lstm_combination_dir, exist_ok=True)

        file_path = os.path.join(lstm_combination_dir, 'best_gru_AE_m2m_model.keras')

        mc = ModelCheckpoint(file_path, monitor='loss', mode='min', verbose=1, save_best_only=True)

        '''''
        cb = Callback(...)  # First, callbacks must be instantiated.
        cb_list = [cb, ...]  # Then, one or more callbacks that you intend to use must be added to a Python list.
        model.fit(..., callbacks=cb_list)  # Finally, the list of callbacks is provided to the callback argument when fitting the model.
        '''''

        model.fit(trainX, trainY,batch_size=n_batch_size, callbacks=[es, mc], verbose=0, epochs=200)
        train_accuracy = model.evaluate(trainX, trainY, verbose=0)
        # test_accuracy = model.evaluate(testX, testY, verbose=0)
        # hist.append(list((n_neurons, n_batch_size, dropout,look_back,
        #                   train_accuracy, test_accuracy)))
        hist.append(list((n_neurons, n_batch_size, dropout,look_back,
                          train_accuracy)))
        
        
        config= {
            "num_features": num_features,
            "layers": layers,
            "units": n_neurons,
            "n_batch_size": n_batch_size,
            "dropout": dropout,
            "look_back": look_back,
            "is_ema": is_ema
        }
        with open(os.path.join(lstm_combination_dir,'config.json'), 'w') as f:
            json.dump(config, f)

        

        # print(f'{str(i)}-th combination = {possible_combinations[i]} \n train accuracy: {train_accuracy}')
        
        # print('--------------------------------------------------------------------')
        # print('--------------------------------------------------------------------')
        # print('--------------------------------------------------------------------')
        # print('--------------------------------------------------------------------')
    for i in range(0, len(possible_combinations)):

        num_features, layers, n_neurons, n_batch_size, dropout, look_back, is_ema = possible_combinations[i]
        df = read_data('../temp_data/influA_vietnam_last_10_days.csv',num_features=num_features)
        trainX, trainY, testX, testY = prepare_data(df, look_back, scaler, is_ema=is_ema)

        a = 'ema' if is_ema else 'not_ema'
        lstm_dir = os.path.join("../result", f"""gru_AE_{a}""")
        lstm_combination_dir = os.path.join(lstm_dir, str(i))
        os.makedirs(lstm_combination_dir, exist_ok=True)

        file_path = os.path.join(lstm_combination_dir, 'best_gru_AE_m2m_model.keras')


        model = load_model(file_path)

        #TODO: save r square
        testY_hat = forecast(testX, model)
        y_hat_inverse = inverse_transform(testY_hat, scaler)
        y_inverse = inverse_transform(testY, scaler)

        r2_image_path = os.path.join(lstm_combination_dir, 'r2_image.png')
        save_plot(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten(), r2_image_path)
        
    import pandas as pd
    hist_df = pd.DataFrame(hist)
    hist_df = hist_df.rename(columns={0: 'units', 1: 'batch_size', 2: 'dropout', 3: 'look_back', 4: 'train_loss'})
    hist_df = hist_df.sort_values(by=['train_loss'], ascending=True)
    hist_df.to_csv(os.path.join(lstm_dir, 'history.csv'))
    return hist_df

# %%
#TODO: [layers, units, batch_size, dropout, look_back, is_ema]
num_features = [1,2]
layers = [[False, True, True]] # at this file, not effect
units = [[64,64,32,16], [64, 128, 64, 32]]
config = [num_features, layers, units, [1, 2, 4, 8], [0.2],[10,12,15,17], [False]] 
df = read_data('../temp_data/influA_vietnam_last_10_days.csv', num_features=1)
hist = LSTM_HyperParameter_Tuning(config, df, scaler)
# Out:
# [(1, [False, True, True], [64, 64, 32, 16], 1, 0.2, 10, False), (1, [False, True, True], [64, 64, 32, 16], 1, 0.2, 12, False), (1, [False, True, True], [64, 64, 32, 16], 1, 0.2, 15, False), (1, [False, True, True], [64, 64, 32, 16], 1, 0.2, 17, False), (1, [False, True, True], [64, 64, 32, 16], 2, 0.2, 10, False), (1, [False, True, True], [64, 64, 32, 16], 2, 0.2, 12, False), (1, [False, True, True], [64, 64, 32, 16], 2, 0.2, 15, False), (1, [False, True, True], [64, 64, 32, 16], 2, 0.2, 17, False), (1, [False, True, True], [64, 64, 32, 16], 4, 0.2, 10, False), (1, [False, True, True], [64, 64, 32, 16], 4, 0.2, 12, False), (1, [False, True, True], [64, 64, 32, 16], 4, 0.2, 15, False), (1, [False, True, True], [64, 64, 32, 16], 4, 0.2, 17, False), (1, [False, True, True], [64, 64, 32, 16], 8, 0.2, 10, False), (1, [False, True, True], [64, 64, 32, 16], 8, 0.2, 12, False), (1, [False, True, True], [64, 64, 32, 16], 8, 0.2, 15, False), (1, [False, True, True], [64, 64, 32, 16], 8, 0.2, 17, False), (1, [False, True, True], [64, 128, 64, 32], 1, 0.2, 10, False), (1, [False, True, True], [64, 128, 64, 32], 1, 0.2, 12, False), (1, [False, True, True], [64, 128, 64, 32], 1, 0.2, 15, False), (1, [False, True, True], [64, 128, 64, 32], 1, 0.2, 17, False), (1, [False, True, True], [64, 128, 64, 32], 2, 0.2, 10, False), (1, [False, True, True], [64, 128, 64, 32], 2, 0.2, 12, False), (1, [False, True, True], [64, 128, 64, 32], 2, 0.2, 15, False), (1, [False, True, True], [64, 128, 64, 32], 2, 0.2, 17, False), (1, [False, True, True], [64, 128, 64, 32], 4, 0.2, 10, False), (1, [False, True, True], [64, 128, 64, 32], 4, 0.2, 12, False), (1, [False, True, True], [64, 128, 64, 32], 4, 0.2, 15, False), (1, [False, True, True], [64, 128, 64, 32], 4, 0.2, 17, False), (1, [False, True, True], [64, 128, 64, 32], 8, 0.2, 10, False), (1, [False, True, True], [64, 128, 64, 32], 8, 0.2, 12, False), (1, [False, True, True], [64, 128, 64, 32], 8, 0.2, 15, False), (1, [False, True, True], [64, 128, 64, 32], 8, 0.2, 17, False), (2, [False, True, True], [64, 64, 32, 16], 1, 0.2, 10, False), (2, [False, True, True], [64, 64, 32, 16], 1, 0.2, 12, False), (2, [False, True, True], [64, 64, 32, 16], 1, 0.2, 15, False), (2, [False, True, True], [64, 64, 32, 16], 1, 0.2, 17, False), (2, [False, True, True], [64, 64, 32, 16], 2, 0.2, 10, False), (2, [False, True, True], [64, 64, 32, 16], 2, 0.2, 12, False), (2, [False, True, True], [64, 64, 32, 16], 2, 0.2, 15, False), (2, [False, True, True], [64, 64, 32, 16], 2, 0.2, 17, False), (2, [False, True, True], [64, 64, 32, 16], 4, 0.2, 10, False), (2, [False, True, True], [64, 64, 32, 16], 4, 0.2, 12, False), (2, [False, True, True], [64, 64, 32, 16], 4, 0.2, 15, False), (2, [False, True, True], [64, 64, 32, 16], 4, 0.2, 17, False), (2, [False, True, True], [64, 64, 32, 16], 8, 0.2, 10, False), (2, [False, True, True], [64, 64, 32, 16], 8, 0.2, 12, False), (2, [False, True, True], [64, 64, 32, 16], 8, 0.2, 15, False), (2, [False, True, True], [64, 64, 32, 16], 8, 0.2, 17, False), (2, [False, True, True], [64, 128, 64, 32], 1, 0.2, 10, False), (2, [False, True, True], [64, 128, 64, 32], 1, 0.2, 12, False), (2, [False, True, True], [64, 128, 64, 32], 1, 0.2, 15, False), (2, [False, True, True], [64, 128, 64, 32], 1, 0.2, 17, False), (2, [False, True, True], [64, 128, 64, 32], 2, 0.2, 10, False), (2, [False, True, True], [64, 128, 64, 32], 2, 0.2, 12, False), (2, [False, True, True], [64, 128, 64, 32], 2, 0.2, 15, False), (2, [False, True, True], [64, 128, 64, 32], 2, 0.2, 17, False), (2, [False, True, True], [64, 128, 64, 32], 4, 0.2, 10, False), (2, [False, True, True], [64, 128, 64, 32], 4, 0.2, 12, False), (2, [False, True, True], [64, 128, 64, 32], 4, 0.2, 15, False), (2, [False, True, True], [64, 128, 64, 32], 4, 0.2, 17, False), (2, [False, True, True], [64, 128, 64, 32], 8, 0.2, 10, False), (2, [False, True, True], [64, 128, 64, 32], 8, 0.2, 12, False), (2, [False, True, True], [64, 128, 64, 32], 8, 0.2, 15, False), ...
#
#
# 1th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.06079, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.06079 to 0.03283, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03283 to 0.02661, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02661 to 0.02417, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02417 to 0.02279, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02279 to 0.02223, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02223 to 0.02222, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02222 to 0.02138, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss did not improve from 0.02138
#
# Epoch 10: loss did not improve from 0.02138
#
# Epoch 11: loss did not improve from 0.02138
#
# Epoch 12: loss did not improve from 0.02138
#
# Epoch 13: loss did not improve from 0.02138
# Epoch 13: early stopping
# 2th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05540, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.05540 to 0.02736, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.02736 to 0.02564, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02564 to 0.02479, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02479 to 0.02163, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02163 to 0.01842, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.01842 to 0.01804, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.01804 to 0.01738, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss did not improve from 0.01738
#
# Epoch 10: loss did not improve from 0.01738
#
# Epoch 11: loss improved from 0.01738 to 0.01712, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss did not improve from 0.01712
#
# Epoch 13: loss improved from 0.01712 to 0.01685, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss did not improve from 0.01685
#
# Epoch 15: loss did not improve from 0.01685
#
# Epoch 16: loss did not improve from 0.01685
#
# Epoch 17: loss improved from 0.01685 to 0.01679, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.01679 to 0.01635, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss did not improve from 0.01635
#
# Epoch 20: loss did not improve from 0.01635
#
# Epoch 21: loss did not improve from 0.01635
#
# Epoch 22: loss did not improve from 0.01635
#
# Epoch 23: loss did not improve from 0.01635
# Epoch 23: early stopping
# 3th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.06006, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.06006 to 0.02789, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.02789 to 0.02663, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02663 to 0.02548, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02548 to 0.02498, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02498 to 0.02486, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02486 to 0.02472, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss did not improve from 0.02472
#
# Epoch 9: loss did not improve from 0.02472
#
# Epoch 10: loss improved from 0.02472 to 0.02470, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02470 to 0.02454, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02454 to 0.02404, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02404 to 0.01965, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.01965 to 0.01837, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.01837 to 0.01782, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.01782 to 0.01670, saving model to ../result\gru_AE_not_ema\2\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss did not improve from 0.01670
#
# Epoch 18: loss did not improve from 0.01670
#
# Epoch 19: loss did not improve from 0.01670
#
# Epoch 20: loss did not improve from 0.01670
#
# Epoch 21: loss did not improve from 0.01670
# Epoch 21: early stopping
# 4th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.06535, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.06535 to 0.02746, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.02746 to 0.02627, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02627 to 0.02552, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02552 to 0.02521, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02521 to 0.02484, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02484 to 0.02476, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02476 to 0.02470, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02470 to 0.02463, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss did not improve from 0.02463
#
# Epoch 11: loss improved from 0.02463 to 0.02459, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02459 to 0.02411, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02411 to 0.02202, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02202 to 0.01807, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.01807 to 0.01786, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.01786 to 0.01715, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss did not improve from 0.01715
#
# Epoch 18: loss improved from 0.01715 to 0.01712, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.01712 to 0.01683, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss did not improve from 0.01683
#
# Epoch 21: loss did not improve from 0.01683
#
# Epoch 22: loss did not improve from 0.01683
#
# Epoch 23: loss improved from 0.01683 to 0.01651, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss improved from 0.01651 to 0.01633, saving model to ../result\gru_AE_not_ema\3\best_gru_AE_m2m_model.keras
#
# Epoch 25: loss did not improve from 0.01633
#
# Epoch 26: loss did not improve from 0.01633
#
# Epoch 27: loss did not improve from 0.01633
#
# Epoch 28: loss did not improve from 0.01633
#
# Epoch 29: loss did not improve from 0.01633
# Epoch 29: early stopping
# 5th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.07682, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.07682 to 0.03480, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03480 to 0.03247, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03247 to 0.03157, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.03157 to 0.03115, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.03115 to 0.03074, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.03074 to 0.03064, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.03064 to 0.02986, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02986 to 0.02304, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02304 to 0.02289, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02289 to 0.02180, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss did not improve from 0.02180
#
# Epoch 13: loss improved from 0.02180 to 0.02164, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02164 to 0.02109, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss did not improve from 0.02109
#
# Epoch 16: loss improved from 0.02109 to 0.02104, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss did not improve from 0.02104
#
# Epoch 18: loss improved from 0.02104 to 0.02053, saving model to ../result\gru_AE_not_ema\4\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss did not improve from 0.02053
#
# Epoch 20: loss did not improve from 0.02053
#
# Epoch 21: loss did not improve from 0.02053
#
# Epoch 22: loss did not improve from 0.02053
#
# Epoch 23: loss did not improve from 0.02053
# Epoch 23: early stopping
# 6th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.07852, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.07852 to 0.02957, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.02957 to 0.02744, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02744 to 0.02612, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02612 to 0.02547, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02547 to 0.02529, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02529 to 0.02497, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02497 to 0.02454, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02454 to 0.02342, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02342 to 0.01903, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.01903 to 0.01818, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.01818 to 0.01706, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.01706 to 0.01660, saving model to ../result\gru_AE_not_ema\5\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss did not improve from 0.01660
#
# Epoch 15: loss did not improve from 0.01660
#
# Epoch 16: loss did not improve from 0.01660
#
# Epoch 17: loss did not improve from 0.01660
#
# Epoch 18: loss did not improve from 0.01660
# Epoch 18: early stopping
# 7th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.08747, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.08747 to 0.03036, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03036 to 0.02823, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02823 to 0.02717, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02717 to 0.02632, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02632 to 0.02575, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02575 to 0.02543, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02543 to 0.02496, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02496 to 0.02480, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss did not improve from 0.02480
#
# Epoch 11: loss improved from 0.02480 to 0.02479, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02479 to 0.02476, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02476 to 0.02466, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss did not improve from 0.02466
#
# Epoch 15: loss did not improve from 0.02466
#
# Epoch 16: loss improved from 0.02466 to 0.02455, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.02455 to 0.02408, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.02408 to 0.02174, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.02174 to 0.01784, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss improved from 0.01784 to 0.01711, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss improved from 0.01711 to 0.01709, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss improved from 0.01709 to 0.01683, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss improved from 0.01683 to 0.01681, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss did not improve from 0.01681
#
# Epoch 25: loss did not improve from 0.01681
#
# Epoch 26: loss improved from 0.01681 to 0.01665, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 27: loss did not improve from 0.01665
#
# Epoch 28: loss did not improve from 0.01665
#
# Epoch 29: loss did not improve from 0.01665
#
# Epoch 30: loss did not improve from 0.01665
#
# Epoch 31: loss improved from 0.01665 to 0.01647, saving model to ../result\gru_AE_not_ema\6\best_gru_AE_m2m_model.keras
#
# Epoch 32: loss did not improve from 0.01647
#
# Epoch 33: loss did not improve from 0.01647
#
# Epoch 34: loss did not improve from 0.01647
#
# Epoch 35: loss did not improve from 0.01647
#
# Epoch 36: loss did not improve from 0.01647
# Epoch 36: early stopping
# 8th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.09051, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.09051 to 0.02982, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.02982 to 0.02804, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02804 to 0.02742, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02742 to 0.02639, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02639 to 0.02601, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02601 to 0.02546, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02546 to 0.02529, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02529 to 0.02506, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02506 to 0.02490, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02490 to 0.02479, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02479 to 0.02444, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02444 to 0.02434, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02434 to 0.02349, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.02349 to 0.02010, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.02010 to 0.01790, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss did not improve from 0.01790
#
# Epoch 18: loss did not improve from 0.01790
#
# Epoch 19: loss did not improve from 0.01790
#
# Epoch 20: loss improved from 0.01790 to 0.01738, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss improved from 0.01738 to 0.01660, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss did not improve from 0.01660
#
# Epoch 23: loss did not improve from 0.01660
#
# Epoch 24: loss did not improve from 0.01660
#
# Epoch 25: loss improved from 0.01660 to 0.01655, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 26: loss improved from 0.01655 to 0.01621, saving model to ../result\gru_AE_not_ema\7\best_gru_AE_m2m_model.keras
#
# Epoch 27: loss did not improve from 0.01621
#
# Epoch 28: loss did not improve from 0.01621
#
# Epoch 29: loss did not improve from 0.01621
#
# Epoch 30: loss did not improve from 0.01621
#
# Epoch 31: loss did not improve from 0.01621
# Epoch 31: early stopping
# 9th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.09838, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.09838 to 0.03765, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03765 to 0.03495, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03495 to 0.03376, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.03376 to 0.03263, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.03263 to 0.03179, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.03179 to 0.03114, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.03114 to 0.03073, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.03073 to 0.03056, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.03056 to 0.02957, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02957 to 0.02717, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02717 to 0.02447, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02447 to 0.02210, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss did not improve from 0.02210
#
# Epoch 15: loss improved from 0.02210 to 0.02194, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss did not improve from 0.02194
#
# Epoch 17: loss did not improve from 0.02194
#
# Epoch 18: loss improved from 0.02194 to 0.02171, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.02171 to 0.02145, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss improved from 0.02145 to 0.02075, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss improved from 0.02075 to 0.02069, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss did not improve from 0.02069
#
# Epoch 23: loss improved from 0.02069 to 0.02062, saving model to ../result\gru_AE_not_ema\8\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss did not improve from 0.02062
#
# Epoch 25: loss did not improve from 0.02062
#
# Epoch 26: loss did not improve from 0.02062
#
# Epoch 27: loss did not improve from 0.02062
#
# Epoch 28: loss did not improve from 0.02062
# Epoch 28: early stopping
# 10th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.11542, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.11542 to 0.03456, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03456 to 0.02965, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02965 to 0.02859, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02859 to 0.02729, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02729 to 0.02663, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02663 to 0.02627, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02627 to 0.02562, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02562 to 0.02555, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02555 to 0.02528, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02528 to 0.02492, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss did not improve from 0.02492
#
# Epoch 13: loss improved from 0.02492 to 0.02489, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02489 to 0.02476, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss did not improve from 0.02476
#
# Epoch 16: loss improved from 0.02476 to 0.02439, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss did not improve from 0.02439
#
# Epoch 18: loss improved from 0.02439 to 0.02381, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.02381 to 0.02215, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss improved from 0.02215 to 0.01880, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss improved from 0.01880 to 0.01721, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss did not improve from 0.01721
#
# Epoch 23: loss did not improve from 0.01721
#
# Epoch 24: loss did not improve from 0.01721
#
# Epoch 25: loss improved from 0.01721 to 0.01653, saving model to ../result\gru_AE_not_ema\9\best_gru_AE_m2m_model.keras
#
# Epoch 26: loss did not improve from 0.01653
#
# Epoch 27: loss did not improve from 0.01653
#
# Epoch 28: loss did not improve from 0.01653
#
# Epoch 29: loss did not improve from 0.01653
#
# Epoch 30: loss did not improve from 0.01653
# Epoch 30: early stopping
# 11th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.14455, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.14455 to 0.04893, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.04893 to 0.03107, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03107 to 0.02947, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02947 to 0.02832, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02832 to 0.02790, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02790 to 0.02733, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02733 to 0.02683, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02683 to 0.02625, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02625 to 0.02582, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02582 to 0.02550, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02550 to 0.02526, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02526 to 0.02505, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02505 to 0.02491, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.02491 to 0.02473, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss did not improve from 0.02473
#
# Epoch 17: loss improved from 0.02473 to 0.02467, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss did not improve from 0.02467
#
# Epoch 19: loss improved from 0.02467 to 0.02466, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss did not improve from 0.02466
#
# Epoch 21: loss improved from 0.02466 to 0.02427, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss improved from 0.02427 to 0.02359, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss improved from 0.02359 to 0.02055, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss improved from 0.02055 to 0.01807, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 25: loss did not improve from 0.01807
#
# Epoch 26: loss did not improve from 0.01807
#
# Epoch 27: loss improved from 0.01807 to 0.01708, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 28: loss improved from 0.01708 to 0.01701, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 29: loss did not improve from 0.01701
#
# Epoch 30: loss did not improve from 0.01701
#
# Epoch 31: loss improved from 0.01701 to 0.01669, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 32: loss did not improve from 0.01669
#
# Epoch 33: loss did not improve from 0.01669
#
# Epoch 34: loss did not improve from 0.01669
#
# Epoch 35: loss did not improve from 0.01669
#
# Epoch 36: loss improved from 0.01669 to 0.01632, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 37: loss did not improve from 0.01632
#
# Epoch 38: loss did not improve from 0.01632
#
# Epoch 39: loss did not improve from 0.01632
#
# Epoch 40: loss did not improve from 0.01632
#
# Epoch 41: loss improved from 0.01632 to 0.01602, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 42: loss improved from 0.01602 to 0.01592, saving model to ../result\gru_AE_not_ema\10\best_gru_AE_m2m_model.keras
#
# Epoch 43: loss did not improve from 0.01592
#
# Epoch 44: loss did not improve from 0.01592
#
# Epoch 45: loss did not improve from 0.01592
#
# Epoch 46: loss did not improve from 0.01592
#
# Epoch 47: loss did not improve from 0.01592
# Epoch 47: early stopping
# 12th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.14304, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.14304 to 0.04979, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.04979 to 0.03149, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03149 to 0.02974, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02974 to 0.02837, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02837 to 0.02783, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02783 to 0.02741, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02741 to 0.02698, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02698 to 0.02690, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02690 to 0.02613, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss did not improve from 0.02613
#
# Epoch 12: loss improved from 0.02613 to 0.02567, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02567 to 0.02547, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02547 to 0.02529, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.02529 to 0.02510, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.02510 to 0.02489, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.02489 to 0.02476, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.02476 to 0.02461, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.02461 to 0.02448, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss improved from 0.02448 to 0.02414, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss improved from 0.02414 to 0.02315, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss improved from 0.02315 to 0.01896, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss improved from 0.01896 to 0.01881, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss improved from 0.01881 to 0.01770, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 25: loss did not improve from 0.01770
#
# Epoch 26: loss did not improve from 0.01770
#
# Epoch 27: loss improved from 0.01770 to 0.01761, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 28: loss improved from 0.01761 to 0.01669, saving model to ../result\gru_AE_not_ema\11\best_gru_AE_m2m_model.keras
#
# Epoch 29: loss did not improve from 0.01669
#
# Epoch 30: loss did not improve from 0.01669
#
# Epoch 31: loss did not improve from 0.01669
#
# Epoch 32: loss did not improve from 0.01669
#
# Epoch 33: loss did not improve from 0.01669
# Epoch 33: early stopping
# 13th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.14582, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.14582 to 0.06531, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.06531 to 0.03977, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03977 to 0.03676, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.03676 to 0.03567, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.03567 to 0.03448, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.03448 to 0.03378, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.03378 to 0.03319, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.03319 to 0.03255, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.03255 to 0.03214, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.03214 to 0.03199, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.03199 to 0.03134, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.03134 to 0.03115, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.03115 to 0.03079, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.03079 to 0.03032, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.03032 to 0.02960, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.02960 to 0.02859, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.02859 to 0.02660, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.02660 to 0.02334, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss did not improve from 0.02334
#
# Epoch 21: loss did not improve from 0.02334
#
# Epoch 22: loss improved from 0.02334 to 0.02230, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss improved from 0.02230 to 0.02142, saving model to ../result\gru_AE_not_ema\12\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss did not improve from 0.02142
#
# Epoch 25: loss did not improve from 0.02142
#
# Epoch 26: loss did not improve from 0.02142
#
# Epoch 27: loss did not improve from 0.02142
#
# Epoch 28: loss did not improve from 0.02142
# Epoch 28: early stopping
# 14th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.15565, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.15565 to 0.07916, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.07916 to 0.03951, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03951 to 0.03347, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.03347 to 0.03085, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.03085 to 0.02989, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02989 to 0.02856, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02856 to 0.02809, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02809 to 0.02751, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02751 to 0.02721, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02721 to 0.02717, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02717 to 0.02655, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02655 to 0.02627, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02627 to 0.02581, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss did not improve from 0.02581
#
# Epoch 16: loss improved from 0.02581 to 0.02559, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.02559 to 0.02546, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.02546 to 0.02531, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.02531 to 0.02514, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss did not improve from 0.02514
#
# Epoch 21: loss improved from 0.02514 to 0.02508, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss improved from 0.02508 to 0.02502, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss improved from 0.02502 to 0.02497, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss did not improve from 0.02497
#
# Epoch 25: loss did not improve from 0.02497
#
# Epoch 26: loss improved from 0.02497 to 0.02489, saving model to ../result\gru_AE_not_ema\13\best_gru_AE_m2m_model.keras
#
# Epoch 27: loss did not improve from 0.02489
#
# Epoch 28: loss did not improve from 0.02489
#
# Epoch 29: loss did not improve from 0.02489
#
# Epoch 30: loss did not improve from 0.02489
#
# Epoch 31: loss did not improve from 0.02489
# Epoch 31: early stopping
# 15th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.15883, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.15883 to 0.07938, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.07938 to 0.03699, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03699 to 0.03311, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.03311 to 0.03082, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.03082 to 0.02999, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.02999 to 0.02912, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02912 to 0.02834, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02834 to 0.02790, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02790 to 0.02755, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02755 to 0.02722, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02722 to 0.02701, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02701 to 0.02679, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02679 to 0.02642, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.02642 to 0.02624, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.02624 to 0.02613, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.02613 to 0.02593, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.02593 to 0.02565, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss did not improve from 0.02565
#
# Epoch 20: loss improved from 0.02565 to 0.02564, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss improved from 0.02564 to 0.02521, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss improved from 0.02521 to 0.02516, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss improved from 0.02516 to 0.02497, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss improved from 0.02497 to 0.02494, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 25: loss improved from 0.02494 to 0.02471, saving model to ../result\gru_AE_not_ema\14\best_gru_AE_m2m_model.keras
#
# Epoch 26: loss did not improve from 0.02471
#
# Epoch 27: loss did not improve from 0.02471
#
# Epoch 28: loss did not improve from 0.02471
#
# Epoch 29: loss did not improve from 0.02471
#
# Epoch 30: loss did not improve from 0.02471
# Epoch 30: early stopping
# 16th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.16430, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.16430 to 0.09616, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.09616 to 0.04363, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.04363 to 0.03478, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.03478 to 0.03181, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.03181 to 0.03055, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.03055 to 0.02960, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.02960 to 0.02902, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02902 to 0.02845, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02845 to 0.02806, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02806 to 0.02770, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02770 to 0.02763, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.02763 to 0.02711, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.02711 to 0.02677, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss did not improve from 0.02677
#
# Epoch 16: loss improved from 0.02677 to 0.02637, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss did not improve from 0.02637
#
# Epoch 18: loss improved from 0.02637 to 0.02626, saving model to ../result\gru_AE_not_ema\15\best_gru_AE_m2m_model.keras
#
# ...
#
# Epoch 12: loss improved from 0.01264 to 0.01254, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss did not improve from 0.01254
#
# Epoch 14: loss improved from 0.01254 to 0.01218, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.01218 to 0.01091, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.01091 to 0.01069, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.01069 to 0.01010, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss did not improve from 0.01010
#
# Epoch 19: loss improved from 0.01010 to 0.00947, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss did not improve from 0.00947
#
# Epoch 21: loss did not improve from 0.00947
#
# Epoch 22: loss improved from 0.00947 to 0.00944, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss did not improve from 0.00944
#
# Epoch 24: loss did not improve from 0.00944
#
# Epoch 25: loss improved from 0.00944 to 0.00938, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 26: loss did not improve from 0.00938
#
# Epoch 27: loss improved from 0.00938 to 0.00923, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 28: loss improved from 0.00923 to 0.00904, saving model to ../result\gru_AE_not_ema\59\best_gru_AE_m2m_model.keras
#
# Epoch 29: loss did not improve from 0.00904
#
# Epoch 30: loss did not improve from 0.00904
#
# Epoch 31: loss did not improve from 0.00904
#
# Epoch 32: loss did not improve from 0.00904
#
# Epoch 33: loss did not improve from 0.00904
# Epoch 33: early stopping
# 61th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.10136, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.10136 to 0.03718, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03718 to 0.03103, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03103 to 0.02315, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02315 to 0.02012, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02012 to 0.01796, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.01796 to 0.01691, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.01691 to 0.01617, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.01617 to 0.01580, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.01580 to 0.01552, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.01552 to 0.01526, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.01526 to 0.01526, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.01526 to 0.01489, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.01489 to 0.01464, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.01464 to 0.01460, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.01460 to 0.01422, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.01422 to 0.01395, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.01395 to 0.01259, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.01259 to 0.01188, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss improved from 0.01188 to 0.01180, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss improved from 0.01180 to 0.01077, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss did not improve from 0.01077
#
# Epoch 23: loss did not improve from 0.01077
#
# Epoch 24: loss improved from 0.01077 to 0.01070, saving model to ../result\gru_AE_not_ema\60\best_gru_AE_m2m_model.keras
#
# Epoch 25: loss did not improve from 0.01070
#
# Epoch 26: loss did not improve from 0.01070
#
# Epoch 27: loss did not improve from 0.01070
#
# Epoch 28: loss did not improve from 0.01070
#
# Epoch 29: loss did not improve from 0.01070
# Epoch 29: early stopping
# 62th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.10547, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.10547 to 0.03637, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03637 to 0.02510, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02510 to 0.02112, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02112 to 0.01841, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.01841 to 0.01692, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.01692 to 0.01628, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.01628 to 0.01539, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss did not improve from 0.01539
#
# Epoch 10: loss improved from 0.01539 to 0.01443, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.01443 to 0.01407, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss did not improve from 0.01407
#
# Epoch 13: loss improved from 0.01407 to 0.01378, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.01378 to 0.01372, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.01372 to 0.01347, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.01347 to 0.01312, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.01312 to 0.01295, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.01295 to 0.01256, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss did not improve from 0.01256
#
# Epoch 20: loss improved from 0.01256 to 0.01244, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss did not improve from 0.01244
#
# Epoch 22: loss improved from 0.01244 to 0.01204, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss improved from 0.01204 to 0.01074, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss improved from 0.01074 to 0.01021, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 25: loss improved from 0.01021 to 0.01016, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 26: loss did not improve from 0.01016
#
# Epoch 27: loss did not improve from 0.01016
#
# Epoch 28: loss improved from 0.01016 to 0.00962, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 29: loss improved from 0.00962 to 0.00959, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 30: loss did not improve from 0.00959
#
# Epoch 31: loss did not improve from 0.00959
#
# Epoch 32: loss improved from 0.00959 to 0.00923, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 33: loss did not improve from 0.00923
#
# Epoch 34: loss improved from 0.00923 to 0.00914, saving model to ../result\gru_AE_not_ema\61\best_gru_AE_m2m_model.keras
#
# Epoch 35: loss did not improve from 0.00914
#
# Epoch 36: loss did not improve from 0.00914
#
# Epoch 37: loss did not improve from 0.00914
#
# Epoch 38: loss did not improve from 0.00914
#
# Epoch 39: loss did not improve from 0.00914
# Epoch 39: early stopping
# 63th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.11607, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.11607 to 0.03594, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03594 to 0.02737, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02737 to 0.02194, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02194 to 0.01953, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.01953 to 0.01796, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.01796 to 0.01704, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.01704 to 0.01668, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.01668 to 0.01602, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.01602 to 0.01536, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.01536 to 0.01483, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.01483 to 0.01435, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.01435 to 0.01405, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.01405 to 0.01397, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.01397 to 0.01382, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.01382 to 0.01319, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss did not improve from 0.01319
#
# Epoch 18: loss improved from 0.01319 to 0.01319, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.01319 to 0.01293, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss did not improve from 0.01293
#
# Epoch 21: loss did not improve from 0.01293
#
# Epoch 22: loss improved from 0.01293 to 0.01273, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss did not improve from 0.01273
#
# Epoch 24: loss improved from 0.01273 to 0.01230, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 25: loss improved from 0.01230 to 0.01212, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 26: loss improved from 0.01212 to 0.01212, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 27: loss improved from 0.01212 to 0.01181, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 28: loss improved from 0.01181 to 0.01009, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 29: loss improved from 0.01009 to 0.00972, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 30: loss did not improve from 0.00972
#
# Epoch 31: loss improved from 0.00972 to 0.00961, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 32: loss did not improve from 0.00961
#
# Epoch 33: loss did not improve from 0.00961
#
# Epoch 34: loss did not improve from 0.00961
#
# Epoch 35: loss improved from 0.00961 to 0.00959, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 36: loss improved from 0.00959 to 0.00945, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 37: loss improved from 0.00945 to 0.00923, saving model to ../result\gru_AE_not_ema\62\best_gru_AE_m2m_model.keras
#
# Epoch 38: loss did not improve from 0.00923
#
# Epoch 39: loss did not improve from 0.00923
#
# Epoch 40: loss did not improve from 0.00923
#
# Epoch 41: loss did not improve from 0.00923
#
# Epoch 42: loss did not improve from 0.00923
# Epoch 42: early stopping
# 64th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.11542, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.11542 to 0.03871, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.03871 to 0.03131, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.03131 to 0.02473, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02473 to 0.02113, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02113 to 0.01943, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.01943 to 0.01808, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.01808 to 0.01740, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.01740 to 0.01673, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.01673 to 0.01628, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.01628 to 0.01524, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss did not improve from 0.01524
#
# Epoch 13: loss improved from 0.01524 to 0.01519, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.01519 to 0.01445, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss improved from 0.01445 to 0.01429, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss improved from 0.01429 to 0.01398, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 17: loss improved from 0.01398 to 0.01389, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss improved from 0.01389 to 0.01311, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 19: loss improved from 0.01311 to 0.01309, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss improved from 0.01309 to 0.01279, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 21: loss improved from 0.01279 to 0.01260, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 22: loss improved from 0.01260 to 0.01229, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 23: loss improved from 0.01229 to 0.01141, saving model to ../result\gru_AE_not_ema\63\best_gru_AE_m2m_model.keras
#
# Epoch 24: loss did not improve from 0.01141
#
# Epoch 25: loss did not improve from 0.01141
#
# Epoch 26: loss did not improve from 0.01141
#
# Epoch 27: loss did not improve from 0.01141
#
# Epoch 28: loss did not improve from 0.01141
# Epoch 28: early stopping

# %%
from keras.models import load_model

model = load_model(r"D:\my_study\gr3\DATN\result\gru_AE_ema\59\best_gru_AE_m2m_model.keras")
df = read_data('../temp_data/influA_vietnam_last_10_days.csv',num_features=2)
trainX, trainY, testX, testY = prepare_data(df, 17, scaler, is_ema=True)
testY_hat = forecast(testX, model)
y_hat_inverse = inverse_transform(testY_hat, scaler)
y_inverse = inverse_transform(testY, scaler)
plot(y_inverse, y_hat_inverse)

# save_plot(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten(), 'abc.png')
# model.evaluate(testX, testY)

# %%
from sklearn.metrics import mean_squared_error
print(np.sqrt(mean_squared_error(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten())))
# Out:
# 2.4246304
