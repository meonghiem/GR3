# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler, RobustScaler
scaler = MinMaxScaler()
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM, TimeDistributed, Input, Dropout, GRU
from sklearn.model_selection import GridSearchCV
import tensorflow as tf
from keras.saving import register_keras_serializable
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(0, len(dataset)-2 *look_back+1, look_back):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back: i+ 2*look_back])
    return np.array(dataX), np.array(dataY)

def exponential_moving_average(data, span):
    return data.ewm(span=span, adjust=False).mean()

def read_data(file_path, num_features = 1):
    from pandas import read_csv
    series_influ_A_df = read_csv(file_path, index_col=0, engine='python')
    series_influ_A_df = series_influ_A_df.rename(columns= {"Influenza A - All types of surveillance": "case"})
    series_influ_A_df = series_influ_A_df[["case", "humidity", "temp", "dew","windspeed", "tempmax",][:num_features]]
    return series_influ_A_df.dropna()

def prepare_data(series, look_back, scaler, is_ema = False):
    if is_ema:
        span = 52  # Bạn có thể điều chỉnh độ dài span tùy ý
        series['case'] = exponential_moving_average(series['case'], span)
    series = series.astype('float32')
    series = series.values
    if scaler is not None:
        flattened_dataset = series.flatten()
        dataset = scaler.fit_transform(flattened_dataset.reshape(-1,1))
        dataset = dataset.reshape(series.shape)

    else: 
        dataset = series

    rest = len(dataset) % look_back
    dataset = dataset[rest:, :]
    trainsize = len(dataset) - look_back
    train = dataset[:trainsize, :]
    test = dataset[trainsize - look_back:, :]

    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)
    return trainX, trainY, testX, testY

def forecast(input, model):
    predicted = model.predict(input, verbose=0)
    return predicted

def plot_r2(x, y):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Create the scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, squared_error, color='red', marker="o", label=f'squared Error (R²={r2:.2f})')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title('Scatter Plot with R-squared Line')
    plt.legend()
    plt.grid()
    plt.show()

def save_plot(x,y, file_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Create the scatter plot
    plt.figure(figsize=(8, 6))
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, squared_error, color='red', marker="o", label=f'squared Error (R²={r2:.2f})')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title('Scatter Plot with R-squared Line')
    plt.legend()
    plt.grid()
    plt.savefig(file_path)
    plt.close()

def inverse_transform(data, scaler):
    flattened_data = data.flatten()
    inverse_flattened_data = scaler.inverse_transform(flattened_data.reshape(-1,1))
    return inverse_flattened_data.reshape(data.shape)

# %%
@register_keras_serializable()
class MyLSTM (Sequential):
    def __init__(self, look_back, dense_units =[],unit=64, optimizer='adam',name='lstm'):
        super().__init__(name=name)
        self.look_back = look_back
        self.add(Input(shape=(look_back,1)))
        self.add(LSTM(units=unit, activation='relu', return_sequences=True))
        for unit in dense_units:
            self.add(Dense(units=unit, activation='relu'))
        self.add(TimeDistributed(Dense(units=5, activation='sigmoid' )))
        self.compile(optimizer=optimizer, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    

def build_model(input_shape, dropout=0.2, dense_units = [], optimizer='adam'):
    model = Sequential()
    model.add(Input(shape=input_shape))

    #Encoder:
    # First GRU layer with Dropout regularisation
    model.add(GRU(units=dense_units[0], return_sequences=True))
    model.add(Dropout(dropout))
    # Second GRU layer
    model.add(GRU(units=dense_units[1], return_sequences=True))
    model.add(Dropout(dropout))
    # Third GRU layer
    model.add(GRU(units=dense_units[2], return_sequences=True))
    model.add(Dropout(dropout))

    #Decoder
    # Fourth GRU layer
    model.add(GRU(units=dense_units[2], return_sequences=True))
    model.add(Dropout(dropout))

    model.add(GRU(units=dense_units[1], return_sequences=True))
    model.add(Dropout(dropout))
    # Fourth GRU layer
    model.add(GRU(units=dense_units[0], return_sequences=True))
    model.add(Dropout(dropout))
    model.add(TimeDistributed(Dense(units=input_shape[1], activation='sigmoid' )))
    model.compile(optimizer=optimizer, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# %%
def plot(testY, forecasts):
    import matplotlib.pyplot as plt
    forecastsPlot = forecasts[:,:,0].reshape(-1)
    testPlot = testY[:,:,0].reshape(-1)
    plt.plot(testPlot, "-y", label="actual", marker= '.')
    plt.plot(forecastsPlot, color = 'green', marker = 'x', label="forecast")
    plt.ylabel("Number of infections")
    plt.legend(["actual", "forecast"])
    plt.show()

# %%
import itertools
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os, json
from keras.models import load_model


def LSTM_HyperParameter_Tuning(config, scaler):
    
    num_features, n_neurons, n_batch_sizes, dropouts, look_backs, is_emas = config
    possible_combinations = list(itertools.product(num_features, n_neurons, n_batch_sizes, dropouts, look_backs, is_emas))
    
    print(possible_combinations)
    print('\n')
    
    hist = []
    for i in range(0, len(possible_combinations)):
        print(f'{i+1}th combination: \n')
        print('--------------------------------------------------------------------')
        num_features, n_neurons, n_batch_size, dropout, look_back, is_ema = possible_combinations[i]

        df = read_data('../temp_data/influA_vietnam_last_10_days.csv',num_features=num_features)
        
        trainX, trainY, testX, testY = prepare_data(df, look_back, scaler, is_ema=is_ema)
        model = build_model(
            input_shape=(trainX.shape[1], trainX.shape[2]),
            dense_units=n_neurons,
            dropout=dropout)

        es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
        '''''
        From the mentioned article above --> If a validation dataset is specified to the fit() function via the validation_data or v
        alidation_split arguments,then the loss on the validation dataset will be made available via the name “val_loss.”
        '''''
        a = 'ema' if is_ema else 'not_ema'
        lstm_dir = os.path.join("../result", f"""gru_AE_{a}""")
        lstm_combination_dir = os.path.join(lstm_dir, str(i))
        os.makedirs(lstm_combination_dir, exist_ok=True)

        file_path = os.path.join(lstm_combination_dir, 'best_gru_AE_m2m_model.keras')

        mc = ModelCheckpoint(file_path, monitor='loss', mode='min', verbose=1, save_best_only=True)

        '''''
        cb = Callback(...)  # First, callbacks must be instantiated.
        cb_list = [cb, ...]  # Then, one or more callbacks that you intend to use must be added to a Python list.
        model.fit(..., callbacks=cb_list)  # Finally, the list of callbacks is provided to the callback argument when fitting the model.
        '''''

        model.fit(trainX, trainY,batch_size=n_batch_size, callbacks=[es, mc], verbose=0, epochs=200)        
        
        config= {
            "num_features": num_features,
            "units": n_neurons,
            "n_batch_size": n_batch_size,
            "dropout": dropout,
            "look_back": look_back,
            "is_ema": is_ema
        }
        with open(os.path.join(lstm_combination_dir,'config.json'), 'w') as f:
            json.dump(config, f)

        

        # print(f'{str(i)}-th combination = {possible_combinations[i]} \n train accuracy: {train_accuracy}')
        
        # print('--------------------------------------------------------------------')
        # print('--------------------------------------------------------------------')
        # print('--------------------------------------------------------------------')
        # print('--------------------------------------------------------------------')
    for i in range(0, len(possible_combinations)):

        num_features, n_neurons, n_batch_size, dropout, look_back, is_ema = possible_combinations[i]
        df = read_data('../temp_data/influA_vietnam_last_10_days.csv',num_features=num_features)
        trainX, trainY, testX, testY = prepare_data(df, look_back, scaler, is_ema=is_ema)

        a = 'ema' if is_ema else 'not_ema'
        lstm_dir = os.path.join("../result", f"""gru_AE_{a}""")
        lstm_combination_dir = os.path.join(lstm_dir, str(i))
        os.makedirs(lstm_combination_dir, exist_ok=True)

        file_path = os.path.join(lstm_combination_dir, 'best_gru_AE_m2m_model.keras')


        model = load_model(file_path)

        #TODO: save r square
        testY_hat = forecast(testX, model)
        y_hat_inverse = inverse_transform(testY_hat, scaler)
        y_inverse = inverse_transform(testY, scaler)

        r2 = r2_score(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten())
        test_loss = np.sqrt(mean_squared_error(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten()))
        hist.append(list((n_neurons, n_batch_size, dropout,look_back,
                          test_loss, r2, num_features, is_ema)))

        r2_image_path = os.path.join(lstm_combination_dir, 'r2_image.png')
        save_plot(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten(), r2_image_path)
        
    import pandas as pd
    hist_df = pd.DataFrame(hist)
    hist_df = hist_df.rename(columns={0: 'units', 1: 'batch_size', 2: 'dropout', 3: 'look_back', 4: 'test_loss', 5: 'r2_score', 6:'num_features', 7: 'is_ema'})
    hist_df = hist_df.sort_values(by=['r2_score'], ascending=False)
    hist_df.to_csv(os.path.join(lstm_dir, 'history.csv'))
    return hist_df

# %%
num_features = [1,2]
units = [[64, 32, 16]] # shape: (None,3)
batch_sizes = [1] # shape(n,)
dropouts = [0.2] # shape(n,)
look_backs = [17] # shape(n,)
is_emas = [False]  # [False, True]
config = [num_features, units, batch_sizes, dropouts,look_backs, is_emas] 
hist = LSTM_HyperParameter_Tuning(config, scaler)
# Out:
# [(1, [64, 32, 16], 1, 0.2, 17, False), (2, [64, 32, 16], 1, 0.2, 17, False)]
#
#
# 1th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05930, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.05930 to 0.02798, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.02798 to 0.02653, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.02653 to 0.02570, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.02570 to 0.02525, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.02525 to 0.02486, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss did not improve from 0.02486
#
# Epoch 8: loss improved from 0.02486 to 0.02462, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.02462 to 0.02455, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.02455 to 0.02445, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.02445 to 0.02395, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.02395 to 0.01928, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss improved from 0.01928 to 0.01867, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 14: loss improved from 0.01867 to 0.01720, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 15: loss did not improve from 0.01720
#
# Epoch 16: loss did not improve from 0.01720
#
# Epoch 17: loss improved from 0.01720 to 0.01669, saving model to ../result\gru_AE_not_ema\0\best_gru_AE_m2m_model.keras
#
# Epoch 18: loss did not improve from 0.01669
#
# Epoch 19: loss did not improve from 0.01669
#
# Epoch 20: loss did not improve from 0.01669
#
# Epoch 21: loss did not improve from 0.01669
#
# Epoch 22: loss did not improve from 0.01669
# Epoch 22: early stopping
# 2th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.04430, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 2: loss improved from 0.04430 to 0.01837, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 3: loss improved from 0.01837 to 0.01551, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 4: loss improved from 0.01551 to 0.01244, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 5: loss improved from 0.01244 to 0.01120, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 6: loss improved from 0.01120 to 0.01095, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 7: loss improved from 0.01095 to 0.01071, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 8: loss improved from 0.01071 to 0.01021, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 9: loss improved from 0.01021 to 0.00989, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 10: loss improved from 0.00989 to 0.00987, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 11: loss improved from 0.00987 to 0.00971, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 12: loss improved from 0.00971 to 0.00961, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 13: loss did not improve from 0.00961
#
# Epoch 14: loss did not improve from 0.00961
#
# Epoch 15: loss improved from 0.00961 to 0.00924, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 16: loss did not improve from 0.00924
#
# Epoch 17: loss did not improve from 0.00924
#
# Epoch 18: loss did not improve from 0.00924
#
# Epoch 19: loss improved from 0.00924 to 0.00911, saving model to ../result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras
#
# Epoch 20: loss did not improve from 0.00911
#
# Epoch 21: loss did not improve from 0.00911
#
# Epoch 22: loss did not improve from 0.00911
#
# Epoch 23: loss did not improve from 0.00911
#
# Epoch 24: loss did not improve from 0.00911
# Epoch 24: early stopping

# %%
# from keras.models import load_model

# model = load_model(r"C:\Users\nghiemxuan\Desktop\nghiem\GR3\GR3\result\gru_AE_not_ema\1\best_gru_AE_m2m_model.keras")
# df = read_data('../temp_data/influA_vietnam_last_10_days.csv',num_features=2)
# trainX, trainY, testX, testY = prepare_data(df, 17, scaler, is_ema=False)
# testY_hat = forecast(testX, model)
# y_hat_inverse = inverse_transform(testY_hat, scaler)
# y_inverse = inverse_transform(testY, scaler)
# plot(y_inverse, y_hat_inverse)

# %%
# from sklearn.metrics import mean_squared_error
# print(np.sqrt(mean_squared_error(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten())))

# r2 = r2_score(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten())
# print("r2_score: ", r2)

# %%
# plot_r2(y_inverse[:,:,0].flatten(), y_hat_inverse[:,:,0].flatten())
