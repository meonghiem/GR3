# %%
from pandas import read_csv

def read_data(file_path, num_features = 2, have_time = False):
    series_influ_A_df = read_csv(file_path, engine='python')
    series_influ_A_df = series_influ_A_df.rename(columns= {"Influenza A - All types of surveillance": "case"})

    # because since 2011-03-01 It was announced that the H1N12009 flu had been controlled and treated as regular seasonal flu and
    # since 2020-02-01, it's time for covid 
    
    series_influ_A_df = series_influ_A_df.loc [(series_influ_A_df['Month'] >='2011-04-01') & (series_influ_A_df['Month'] <='2020-02-01')]
    if not have_time:
        return series_influ_A_df.dropna()[["case", "temp", "dew", "tempmax", "humidity","tempmin","windspeed"][:num_features]]
    return series_influ_A_df.dropna()[["Month", "case", "temp", "dew", "tempmax", "humidity","tempmin","windspeed"][:num_features+1]]

file_path = '../../temp_data/influA_japan_temp_month.csv'
#Load data set
df = read_data(file_path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error

def calculate_errors(y_true, y_pred):
    # Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_true, y_pred)
    
    # Mean Squared Error (MSE)
    mse = mean_squared_error(y_true, y_pred)
    
    # Root Mean Squared Error (RMSE)
    rmse = np.sqrt(mse)
    
    # Mean Absolute Percentage Error (MAPE)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    # Root Mean Squared Percentage Error (RMSPE)
    rmspe = np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))) * 100
    
    # Mean Absolute Residual (MARE)
    mare = np.mean(np.abs(y_true - y_pred))
    
    # Nash-Sutcliffe Efficiency (NSE)
    nse = 1 - (np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    
    # Normalized Nash-Sutcliffe Efficiency (NNSE)
    nnse = 1 - (np.sum((y_true - y_pred) ** 2) / np.sum((np.abs(y_true - np.mean(y_true)) + np.abs(y_pred - np.mean(y_true))) ** 2))
    
    return mae, mse, rmse, mape, rmspe, mare, nse, nnse

# %%
import numpy as np
from sklearn.metrics import r2_score

# def create_dataset(dataset, look_back=2, num_predict=1):
#     dataX, dataY = [], []
#     for i in range(0, len(dataset)-2 *look_back+1, look_back - num_predict):
#         a = dataset[i:(i+look_back)]
#         dataX.append(a)
#         dataY.append(dataset[i + look_back - num_predict : i+ 2*look_back-num_predict])
#     return np.array(dataX), np.array(dataY)

def create_dataset(dataset, look_back=1, num_predict = 1):
    dataX, dataY = [], []
    for i in range(0, len(dataset)-look_back, num_predict):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back: i+ look_back +num_predict])
    return np.array(dataX), np.array(dataY)

def forecast(input, model):
    input = input.reshape(1, input.shape[0], input.shape[1])
    predicted = model.predict(input, verbose=0)
    return predicted[0]

def make_forecasts(test, model):
    forecasts = []
    inputStart = test[0]
    inputX = inputStart.reshape(1, inputStart.shape[0], inputStart.shape[1])
    for i in range(len(test)):
        predicted = forecast(inputX[i], model)
        print(predicted.shape)
        forecasts.append(predicted)
        inputXContinue = np.vstack((inputX[-1][predicted.shape[0]:], predicted))
        inputX = np.append(inputX, [inputXContinue], axis=0)
    
    return np.array(forecasts)
def evaluate_forecasts(test, forecasts):
    from sklearn.metrics import mean_squared_error
    testScore = np.sqrt(mean_squared_error(test, forecasts))
    print('Test Score: %.2f RMSE' % (testScore))

def plot_r2(x,y, file_path=None):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Print error metrics
    mae, mse, rmse, mape, rmspe, mare, nse, nnse = calculate_errors(x, y)
    print(f'MAE: {mae:.2f}')
    print(f'MSE: {mse:.2f}')
    print(f'RMSE: {rmse:.2f}')
    print(f'MAPE: {mape:.2f}%')
    print(f'RMSPE: {rmspe:.2f}%')
    print(f'MARE: {mare:.2f}')
    print(f'NSE: {nse:.2f}')
    print(f'NNSE: {nnse:.2f}')

    # Create the scatter plot
    plt.figure(figsize=(10, 12))

    # Subplot 1: Scatter plot and regression line
    plt.subplot(3, 1, 1)
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, r2_line, color='red', marker="o", label=f'Regression line')
    plt.title('Correlation ')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title(f'Scatter Plot with R-squared Line\nCorrelation: {r_value:.2f}, R^2: {r2_pearson:.2f}')
    plt.legend()
    plt.grid()

    # Subplot 2: Real values over time
    plt.subplot(3, 1, 2)
    plt.plot( x, color='blue', label='Real_values')
    plt.xlabel('Time')
    plt.ylabel('Real_values')
    plt.title('Real Values over Time')
    plt.legend()
    plt.grid(True)
    
    # Subplot 3: Forecast values over time
    plt.subplot(3, 1, 3)
    plt.plot(y, color='green', label='Forecast_values')
    plt.xlabel('Time')
    plt.ylabel('Forecast_values')
    plt.title('Forecast Values over Time')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    # plt.savefig(file_path)
    # plt.close()
    plt.show()

def save_plot(x,y, file_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Print error metrics
    mae, mse, rmse, mape, rmspe, mare, nse, nnse = calculate_errors(x, y)

    # Create the scatter plot
    plt.figure(figsize=(10, 12))

    # Subplot 1: Scatter plot and regression line
    plt.subplot(3, 1, 1)
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, r2_line, color='red', marker="o", label=f'Regression line')
    plt.title('Correlation ')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title(f'Scatter Plot with R-squared Line\nCorrelation: {r_value:.2f}, R^2: {r2_pearson:.2f}')
    plt.legend()
    plt.grid()

    # Subplot 2: Real values over time
    plt.subplot(3, 1, 2)
    plt.plot( x, color='blue', label='Real_values')
    plt.xlabel('Time')
    plt.ylabel('Real_values')
    plt.title('Real Values over Time')
    plt.legend()
    plt.grid(True)
    
    # Subplot 3: Forecast values over time
    plt.subplot(3, 1, 3)
    plt.plot(y, color='green', label='Forecast_values')
    plt.xlabel('Time')
    plt.ylabel('Forecast_values')
    plt.title('Forecast Values over Time')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(file_path)
    plt.close()
    return mae, mse, rmse, mape, rmspe, mare, nse, nnse, r2_pearson, r_value

def plot(testY, forecasts):
    import matplotlib.pyplot as plt
    forecastsPlot = np.empty([forecasts.shape[0]])
    forecastsPlot[:] = np.nan
    forecastsPlot[:] = forecasts[:,0].reshape(-1)
    testPlot = np.empty([testY.shape[0]])
    testPlot[:] = np.nan
    testPlot[:] = testY[:,0].reshape(-1)
    plt.plot(testPlot, "-y", label="actual", marker= '.')
    plt.plot(forecastsPlot, color = 'green', label="forecast", marker='x')
    plt.ylabel("Number of infections")
    plt.legend(["actual", "forecast"])
    plt.show()

def save(testY, forecasts, file_path):
    import matplotlib.pyplot as plt
    forecastsPlot = np.empty([forecasts.shape[0]])
    forecastsPlot[:] = np.nan
    forecastsPlot[:] = forecasts[:,0].reshape(-1)
    testPlot = np.empty([testY.shape[0]])
    testPlot[:] = np.nan
    testPlot[:] = testY[:,0].reshape(-1)
    plt.plot(testPlot, "-y", label="actual", marker= '.')
    plt.plot(forecastsPlot, color = 'green', label="forecast", marker='x')
    plt.ylabel("Number of infections")
    plt.legend(["actual", "forecast"])
    plt.savefig(file_path)
    plt.close()
    
def plot_month_per_year(df, key):
    import plotly.graph_objects as go
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df['Month'], y=df[key], mode='lines+markers', name=f'Influenza A Cases in month'))
    fig.update_layout(
        title='Influenza A Cases Over Time',
        xaxis=dict(
            title='Month',
            tickvals=df['Month'],  
            tickformat='%Y-%m',
            tickangle=90,
        ),
        yaxis=dict(title='Number of Cases'),
        showlegend=True,
    )
 
    # Show plot
    fig.show()
def inverse_transform(data, scaler):
    flattened_data = data.flatten()
    inverse_flattened_data = scaler.inverse_transform(flattened_data.reshape(-1,1))
    return inverse_flattened_data.reshape(data.shape)

# %%
# Preprocessing
def find_outliers_IQR(df):

    q1=df.quantile(0.25)

    q3=df.quantile(0.75)

    IQR=q3-q1

    outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

    return outliers

outliers = find_outliers_IQR(df['case'])

print('number of outliers: '+ str(len(outliers)))

print('max outlier value: '+ str(outliers.max()))

print('min outlier value: '+ str(outliers.min()))
# Out:
# number of outliers: 12
# max outlier value: 3158.0
# min outlier value: 1595.0

# %%
def remove_outlier_IQR(df):

    q1=df.quantile(0.25)

    q3=df.quantile(0.75)

    IQR=q3-q1

    upper = df[~(df>(q3+1.5*IQR))].max()

    lower = df[~(df<(q1-1.5*IQR))].min()

    df = np.where(
        df > upper,
        np.nan,
        np.where(df < lower,np.nan,df)
        )
    return df
impute_df = df.copy()
impute_df['case'] = remove_outlier_IQR(impute_df['case'])
# plot_month_per_year(impute_df, 'case')

# %%
linear_df = impute_df.copy()
linear_df['case'] = linear_df['case'].interpolate(method='linear')
# plot_month_per_year(linear_df, 'case')

# %%
spline_order_df = impute_df.copy()
spline_order_df['case'] = spline_order_df['case'].interpolate(method='spline', order=3)
# plot_month_per_year(spline_order_df, 'case')

# %%
def remove_outlier_impute(df, impute_method= 'linear'):
    output_df = df.copy()
    output_df["case"] = remove_outlier_IQR(output_df['case'])
    match impute_method:
        case 'linear':
            output_df['case'] = output_df['case'].interpolate(method='linear')
        case 'spline':
            output_df['case'] = output_df['case'].interpolate(method='spline', order=3)
        case _:
            pass
    return output_df

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
def moving_average(data, window_size):
    return data.rolling(window=window_size).mean()

def exponential_moving_average(data, span):
    return data.ewm(span=span, adjust=False).mean()

def prepare_data(df, is_ma=False, scaler =None):
    import pandas as pd
    df_ = pd.DataFrame()
    df_ = df.copy()
    if is_ma:
        # Apply Moving Average Filter
        window_size = 2
        
        df_['case'] = exponential_moving_average(df_['case'], window_size)
        df_ = df_.dropna()
    dataset = df_.values
    if scaler:
        flattened_dataset = dataset.flatten()
        dataset_trans = scaler.fit_transform(flattened_dataset.reshape(-1,1))
        dataset = dataset_trans.reshape(dataset.shape)
    return  dataset

scaler = MinMaxScaler()
dataset = prepare_data(df = linear_df, scaler=scaler, is_ma=True)

# %%
#process data
num_predict = 8
look_back = 8
test_size = num_predict
length = len(dataset)
dataset_length = length - (length -look_back) % num_predict
rest = length - dataset_length
dataset = dataset[rest:]
train = dataset[: -test_size,:]
test = dataset[-test_size - look_back:,:]

trainX, trainY = create_dataset(train, look_back, num_predict)
testX, testY = create_dataset(test, look_back, num_predict)

# %%
# i = 86
# print(trainX[i], trainY[i])
# len(trainX)
# j=0
# print(testX[j], testY[j])
import tensorflow as tf
from keras.losses import mean_squared_error, huber
def custom_loss(y_true, y_pred):
    return tf.sqrt(mean_squared_error(y_true, y_pred)/2)

# def custom_loss(y_true, y_pred):
#     """
#     Custom loss function that penalizes high losses.
#     """
#     # Calculate the standard loss
#     standard_loss = mean_squared_error(y_true ,y_pred)

#     # Apply a penalty function to the loss
#     penalty_factor = 3.0  # Adjust this value to control the penalty strength
#     penalty = tf.maximum(standard_loss - 0.05, 0.0) * penalty_factor

#     # Combine the standard loss and the penalty
#     total_loss = tf.sqrt(standard_loss) + penalty

#     return total_loss
def trend_loss(y_true, y_pred):
    """
    Custom loss function that focuses on capturing the trend of the time series.
    """
    true_trend = tf.math.subtract(y_true[:, 1:], y_true[:, :-1])
    pred_trend = tf.math.subtract(y_pred[:, 1:], y_pred[:, :-1])

    # Calculate the mean squared error of the trends
    trend_mse = tf.sqrt(mean_squared_error(true_trend, pred_trend))

    return trend_mse

def custom_loss_hubber_loss(y_true, y_pred):
    print(y_true.shape)
    hubber_loss = huber(y_true, y_pred, 0.1)
    trend_weight = 0
    trend_loss_value = trend_loss(y_true, y_pred)
    return (1 - trend_weight) *hubber_loss + trend_weight * trend_loss_value

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM, TimeDistributed, Input, Dropout, GRU,concatenate, Bidirectional
from sklearn.model_selection import GridSearchCV
from keras.saving import register_keras_serializable
from sklearn.metrics import r2_score


# hybrid model

# def build_model(input_shape, dropout=None, dense_units = [], unit=64, optimizer='adam'):
#     input = Input(shape=input_shape)
#     # LSTM Model
#     lstm_model = Sequential([
#         LSTM(unit, activation='relu'),
#     ])

#     # GRU Model
#     gru_model = Sequential([
#         # Input(input_shape=input_shape),
#         GRU(unit, activation='relu'),
#     ])

#     gru_model1 = Sequential([
#         # Input(input_shape=input_shape),
#         GRU(unit, activation='relu'),
#     ])

#     # GRU Model
#     rnn_model = Sequential([
#         # Input(input_shape=input_shape),
#         SimpleRNN(unit, activation='relu'),
#     ])

#     gru_output = gru_model(input)
#     gru_output1 = gru_model1(input)
#     # lstm_output = lstm_model(input)
#     rnn_output = rnn_model(input)
#     # gru_output1 = gru_model1(input)

#     combined_output = concatenate([ rnn_output, gru_output, gru_output1])

#     dense_layers = Sequential([
#     Dense(units=input_shape[1], activation='sigmoid' )
#     ])

#     final_output = dense_layers(combined_output)
#     model = tf.keras.Model(inputs=input, outputs=final_output)
#     model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.1), metrics=[tf.keras.metrics.RootMeanSquaredError()])
#     return model

#loss=tf.keras.losses.Huber(delta=0.1)

# def build_model(input_shape, dropout=None, unit=64, optimizer='adam'):
#     model = Sequential()
#     model.add(Input(shape=input_shape))
#     # model.add(GRU(units=unit, activation='relu', return_sequences=True))
#     model.add(SimpleRNN(units=unit, activation='relu'))
#     # model.add(LSTM(units=unit, activation='relu'))
#     model.add(Dense(units=input_shape[1], activation='sigmoid' ))
#     model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.15), metrics=[tf.keras.metrics.RootMeanSquaredError()])
#     return model

def build_model(input_shape, use_layer= "RNN", dropout=None, unit=64, optimizer='adam'):
    input = Input(shape=input_shape)

    # GRU Model
    match use_layer:
        case "LSTM":
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                LSTM(unit, activation='relu', return_sequences=True),
            ])
        case "GRU":
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                GRU(unit, activation='relu', return_sequences=True),
            ])
        case _:
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                SimpleRNN(unit, activation='relu', return_sequences=True),
            ])

    nn_output = nn_model(input)

    dense_layers = Sequential([
    TimeDistributed(Dense(units=input_shape[1], activation='sigmoid' ))
    ])

    output = dense_layers(nn_output[:,-num_predict:])
    model = tf.keras.Model(inputs=input, outputs=output)
    model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.15), metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os
# model = build_model(input_shape=(trainX.shape[1], trainX.shape[2]), unit=32)
# es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
# file_path = os.path.join('../model', 'test.keras')

# mc = ModelCheckpoint(file_path, monitor='loss', mode='min', verbose=1, save_best_only=True)

# model.fit(trainX, trainY,batch_size=1, callbacks=[es, mc], verbose=0, epochs=200)

# %%
# from keras.models import load_model
# import os
# file_path = os.path.join('../model', 'test.keras')
# model = load_model(file_path, custom_objects={"custom_loss": custom_loss})


# forecasts = make_forecasts(testX, model)
# # invert predictions
# forecasts = inverse_transform(forecasts, scaler)
# testY_ = inverse_transform(testY, scaler)
# # evaluate_forecasts(testY_[:,0].reshape(-1), forecasts[:, 0].reshape(-1))

# %%
# new_shape = (testY_.shape[0] * testY_.shape[1], testY_.shape[2])
# plot(testY_.reshape(new_shape), forecasts.reshape(new_shape))

# %%
# plot_r2(testY_.reshape(new_shape)[:,0].flatten(), forecasts.reshape(new_shape)[:,0].flatten())

# %%
# trainY_hat = model.predict(trainX)
# trainY_hat_inverse = inverse_transform(trainY_hat, scaler)
# trainY_inverse = inverse_transform(trainY, scaler)
# new_shape_train = (trainY_inverse.shape[0] * trainY_inverse.shape[1], trainY_inverse.shape[2])
# plot(trainY_inverse.reshape(new_shape_train), trainY_hat_inverse.reshape(new_shape_train))

# %%
import itertools
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os, json
from keras.models import load_model

def Month_HyperParameter_Tuning(config, scaler):
    impute_methods, look_backs, num_features, n_neurons, use_layers, is_mas = config
    possible_combinations = list(itertools.product(impute_methods, look_backs, num_features, n_neurons, use_layers, is_mas))
    print(possible_combinations)
    print('\n')

    hist = []
    for i in range(0, len(possible_combinations)):
        print(f'{i+1}th combination: \n')
        print('--------------------------------------------------------------------')
        impute_method, look_back, num_feature, n_neuron, use_layer, is_ma = possible_combinations[i]
        file_path = '../../temp_data/influA_japan_temp_month.csv'
        #Load data set
        df = read_data(file_path, num_features=num_feature)
        output_df = remove_outlier_impute(df, impute_method)

        scaler = MinMaxScaler()
        dataset = prepare_data(df = output_df, scaler=scaler, is_ma=is_ma)

        num_predict = 8
        # look_back = 8
        test_size = num_predict
        length = len(dataset)
        dataset_length = length - (length -look_back) % num_predict
        rest = length - dataset_length
        dataset = dataset[rest:]
        train = dataset[: -test_size,:]
        test = dataset[-test_size - look_back:,:]

        trainX, trainY = create_dataset(train, look_back, num_predict)
        testX, testY = create_dataset(test, look_back, num_predict)
        model = build_model(
            input_shape=(trainX.shape[1], trainX.shape[2]),
            use_layer=use_layer,
            unit=n_neuron
            )
        es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
        result_dir = os.path.join("../../result", f"""month_min_max_m2o_japan""", "RNN_LSTM_GRU")
        result_combination_dir = os.path.join(result_dir, str(i))
        os.makedirs(result_combination_dir, exist_ok=True)
        file_path = os.path.join(result_combination_dir, 'best_month_model.keras')
        mc = ModelCheckpoint(file_path, monitor='loss', mode='min', verbose=1, save_best_only=True)
        model.fit(trainX, trainY, batch_size=1, callbacks=[es, mc], verbose=0, epochs=200) 
        config = {
            "num_feature": num_feature,
            "use_layer": use_layer,
            "unit": n_neuron,
            "look_back": look_back,
            "is_ma": is_ma,
            "impute_method": impute_method,
        } 
        with open(os.path.join(result_combination_dir,'config.json'), 'w') as f:
            json.dump(config, f)

    for i in range(0, len(possible_combinations)):
        impute_method, look_back, num_feature, n_neuron, use_layer, is_ma = possible_combinations[i]

        file_path = '../../temp_data/influA_japan_temp_month.csv'
        #Load data set
        df = read_data(file_path, num_features=num_feature)
        output_df = remove_outlier_impute(df, impute_method)

        scaler = MinMaxScaler()
        dataset = prepare_data(df = output_df, scaler=scaler, is_ma=is_ma)

        num_predict = 8
        # look_back = 8
        test_size = num_predict
        length = len(dataset)
        dataset_length = length - (length -look_back) % num_predict
        rest = length - dataset_length
        dataset = dataset[rest:]
        train = dataset[: -test_size,:]
        test = dataset[-test_size - look_back:,:]

        trainX, trainY = create_dataset(train, look_back, num_predict)
        testX, testY = create_dataset(test, look_back, num_predict)


        result_dir = os.path.join("../../result", f"""month_min_max_m2o_japan""", "RNN_LSTM_GRU")
        result_combination_dir = os.path.join(result_dir, str(i))
        os.makedirs(result_combination_dir, exist_ok=True)
        file_path = os.path.join(result_combination_dir, 'best_month_model.keras')

        model = load_model(file_path)

        forecasts = make_forecasts(testX, model)
        # invert predictions
        forecasts = inverse_transform(forecasts,scaler)
        testY_ = inverse_transform(testY,scaler)
        # evaluate_forecasts(testY_[:,0].reshape(-1), forecasts[:, 0].reshape(-1))
        new_shape = (testY_.shape[0] * testY_.shape[1], testY_.shape[2])
        
        r2_image_path = os.path.join(result_combination_dir, 'r2_image.png')
        mae, mse, rmse, mape, rmspe, mare, nse, nnse, r2_pearson, r_value = save_plot(testY_.reshape(new_shape)[:,0].flatten(), forecasts.reshape(new_shape)[:,0].flatten(), r2_image_path)
        hist.append(list((impute_method, look_back, num_feature, n_neuron, use_layer, is_ma, rmse, r2_pearson,r_value, mae, mse, mape, rmspe, mare, nse, nnse)))
        test_image_path = os.path.join(result_combination_dir, 'test.png')
        train_image_path = os.path.join(result_combination_dir, 'train.png')
        save(testY_.reshape(new_shape), forecasts.reshape(new_shape), test_image_path)

        trainY_hat = model.predict(trainX)
        trainY_hat_inverse = inverse_transform(trainY_hat, scaler)
        trainY_inverse = inverse_transform(trainY, scaler)
        new_shape_train = (trainY_inverse.shape[0] * trainY_inverse.shape[1], trainY_inverse.shape[2])
        save(trainY_inverse.reshape(new_shape_train), trainY_hat_inverse.reshape(new_shape_train), train_image_path)
    import pandas as pd
    hist_df = pd.DataFrame(hist)
    hist_df = hist_df.rename(columns={
        0: 'impute_method', 
        1: 'look_back', 
        2: 'num_feature', 
        3: 'unit', 
        4: 'use_layer', 
        5: 'is_ma', 
        6:'rmse', 
        7: 'r2_score', 
        8: 'correlation', 
        9:'mae', 
        10: 'mse', 
        11:'mape', 
        12:'rmspe', 
        13:'mare', 
        14:'nse', 
        15:'nnse'
        })
    hist_df = hist_df.sort_values(by=['r2_score'], ascending=False)
    hist_df.to_csv(os.path.join(result_dir, 'history.csv'))
    return hist_df

# %%
num_features = [2,3]
use_layers = ["GRU", "LSTM", "RNN"]
units = [64]
look_backs = [8,10]
is_mas = [True, False]
impute_methods = ["linear", "spline"]

config = [impute_methods, look_backs, num_features, units, use_layers, is_mas]
hist = Month_HyperParameter_Tuning(config, scaler)
# Out:
# [('linear', 8, 2, 64, 'GRU', True), ('linear', 8, 2, 64, 'GRU', False), ('linear', 8, 2, 64, 'LSTM', True), ('linear', 8, 2, 64, 'LSTM', False), ('linear', 8, 2, 64, 'RNN', True), ('linear', 8, 2, 64, 'RNN', False), ('linear', 8, 3, 64, 'GRU', True), ('linear', 8, 3, 64, 'GRU', False), ('linear', 8, 3, 64, 'LSTM', True), ('linear', 8, 3, 64, 'LSTM', False), ('linear', 8, 3, 64, 'RNN', True), ('linear', 8, 3, 64, 'RNN', False), ('linear', 10, 2, 64, 'GRU', True), ('linear', 10, 2, 64, 'GRU', False), ('linear', 10, 2, 64, 'LSTM', True), ('linear', 10, 2, 64, 'LSTM', False), ('linear', 10, 2, 64, 'RNN', True), ('linear', 10, 2, 64, 'RNN', False), ('linear', 10, 3, 64, 'GRU', True), ('linear', 10, 3, 64, 'GRU', False), ('linear', 10, 3, 64, 'LSTM', True), ('linear', 10, 3, 64, 'LSTM', False), ('linear', 10, 3, 64, 'RNN', True), ('linear', 10, 3, 64, 'RNN', False), ('spline', 8, 2, 64, 'GRU', True), ('spline', 8, 2, 64, 'GRU', False), ('spline', 8, 2, 64, 'LSTM', True), ('spline', 8, 2, 64, 'LSTM', False), ('spline', 8, 2, 64, 'RNN', True), ('spline', 8, 2, 64, 'RNN', False), ('spline', 8, 3, 64, 'GRU', True), ('spline', 8, 3, 64, 'GRU', False), ('spline', 8, 3, 64, 'LSTM', True), ('spline', 8, 3, 64, 'LSTM', False), ('spline', 8, 3, 64, 'RNN', True), ('spline', 8, 3, 64, 'RNN', False), ('spline', 10, 2, 64, 'GRU', True), ('spline', 10, 2, 64, 'GRU', False), ('spline', 10, 2, 64, 'LSTM', True), ('spline', 10, 2, 64, 'LSTM', False), ('spline', 10, 2, 64, 'RNN', True), ('spline', 10, 2, 64, 'RNN', False), ('spline', 10, 3, 64, 'GRU', True), ('spline', 10, 3, 64, 'GRU', False), ('spline', 10, 3, 64, 'LSTM', True), ('spline', 10, 3, 64, 'LSTM', False), ('spline', 10, 3, 64, 'RNN', True), ('spline', 10, 3, 64, 'RNN', False)]
#
#
# 1th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.04963, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 2: loss improved from 0.04963 to 0.04755, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 3: loss improved from 0.04755 to 0.04448, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 4: loss improved from 0.04448 to 0.03918, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 5: loss improved from 0.03918 to 0.02933, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 6: loss improved from 0.02933 to 0.02019, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 7: loss improved from 0.02019 to 0.01772, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 8: loss improved from 0.01772 to 0.01700, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 9: loss improved from 0.01700 to 0.01660, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 10: loss improved from 0.01660 to 0.01607, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 11: loss improved from 0.01607 to 0.01570, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 12: loss improved from 0.01570 to 0.01543, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 13: loss improved from 0.01543 to 0.01514, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 14: loss improved from 0.01514 to 0.01491, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 15: loss improved from 0.01491 to 0.01469, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 16: loss improved from 0.01469 to 0.01460, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 17: loss improved from 0.01460 to 0.01317, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 18: loss did not improve from 0.01317
#
# Epoch 19: loss improved from 0.01317 to 0.01317, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 20: loss improved from 0.01317 to 0.01293, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 21: loss improved from 0.01293 to 0.01246, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 22: loss improved from 0.01246 to 0.01229, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 23: loss improved from 0.01229 to 0.01199, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 24: loss improved from 0.01199 to 0.01173, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 25: loss improved from 0.01173 to 0.01144, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 26: loss improved from 0.01144 to 0.01123, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 27: loss did not improve from 0.01123
#
# Epoch 28: loss improved from 0.01123 to 0.01061, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 29: loss did not improve from 0.01061
#
# Epoch 30: loss improved from 0.01061 to 0.01032, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 31: loss improved from 0.01032 to 0.00989, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 32: loss improved from 0.00989 to 0.00962, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 33: loss improved from 0.00962 to 0.00916, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 34: loss improved from 0.00916 to 0.00911, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 35: loss improved from 0.00911 to 0.00874, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 36: loss did not improve from 0.00874
#
# Epoch 37: loss improved from 0.00874 to 0.00858, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 38: loss improved from 0.00858 to 0.00843, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 39: loss improved from 0.00843 to 0.00810, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 40: loss did not improve from 0.00810
#
# Epoch 41: loss did not improve from 0.00810
#
# Epoch 42: loss improved from 0.00810 to 0.00788, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 43: loss did not improve from 0.00788
#
# Epoch 44: loss improved from 0.00788 to 0.00763, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 45: loss did not improve from 0.00763
#
# Epoch 46: loss improved from 0.00763 to 0.00759, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 47: loss did not improve from 0.00759
#
# Epoch 48: loss improved from 0.00759 to 0.00740, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 49: loss improved from 0.00740 to 0.00736, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 50: loss improved from 0.00736 to 0.00733, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 51: loss did not improve from 0.00733
#
# Epoch 52: loss improved from 0.00733 to 0.00712, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 53: loss did not improve from 0.00712
#
# Epoch 54: loss improved from 0.00712 to 0.00706, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 55: loss did not improve from 0.00706
#
# Epoch 56: loss did not improve from 0.00706
#
# Epoch 57: loss did not improve from 0.00706
#
# Epoch 58: loss improved from 0.00706 to 0.00701, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 59: loss improved from 0.00701 to 0.00666, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 60: loss improved from 0.00666 to 0.00648, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 61: loss improved from 0.00648 to 0.00644, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 62: loss improved from 0.00644 to 0.00627, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 63: loss did not improve from 0.00627
#
# Epoch 64: loss did not improve from 0.00627
#
# Epoch 65: loss improved from 0.00627 to 0.00614, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 66: loss improved from 0.00614 to 0.00598, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 67: loss improved from 0.00598 to 0.00584, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 68: loss did not improve from 0.00584
#
# Epoch 69: loss improved from 0.00584 to 0.00563, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 70: loss did not improve from 0.00563
#
# Epoch 71: loss improved from 0.00563 to 0.00549, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 72: loss improved from 0.00549 to 0.00548, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 73: loss did not improve from 0.00548
#
# Epoch 74: loss improved from 0.00548 to 0.00533, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 75: loss did not improve from 0.00533
#
# Epoch 76: loss did not improve from 0.00533
#
# Epoch 77: loss improved from 0.00533 to 0.00513, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 78: loss did not improve from 0.00513
#
# Epoch 79: loss improved from 0.00513 to 0.00498, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 80: loss improved from 0.00498 to 0.00496, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 81: loss improved from 0.00496 to 0.00483, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 82: loss did not improve from 0.00483
#
# Epoch 83: loss did not improve from 0.00483
#
# Epoch 84: loss improved from 0.00483 to 0.00474, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 85: loss improved from 0.00474 to 0.00453, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 86: loss did not improve from 0.00453
#
# Epoch 87: loss did not improve from 0.00453
#
# Epoch 88: loss did not improve from 0.00453
#
# Epoch 89: loss improved from 0.00453 to 0.00453, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 90: loss improved from 0.00453 to 0.00441, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 91: loss did not improve from 0.00441
#
# Epoch 92: loss did not improve from 0.00441
#
# Epoch 93: loss did not improve from 0.00441
#
# Epoch 94: loss improved from 0.00441 to 0.00414, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 95: loss did not improve from 0.00414
#
# Epoch 96: loss did not improve from 0.00414
#
# Epoch 97: loss did not improve from 0.00414
#
# Epoch 98: loss improved from 0.00414 to 0.00411, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 99: loss did not improve from 0.00411
#
# Epoch 100: loss improved from 0.00411 to 0.00399, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 101: loss did not improve from 0.00399
#
# Epoch 102: loss did not improve from 0.00399
#
# Epoch 103: loss did not improve from 0.00399
#
# Epoch 104: loss did not improve from 0.00399
#
# Epoch 105: loss did not improve from 0.00399
# Epoch 105: early stopping
# 2th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05122, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 2: loss improved from 0.05122 to 0.04809, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 3: loss improved from 0.04809 to 0.04339, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 4: loss improved from 0.04339 to 0.03529, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 5: loss improved from 0.03529 to 0.02419, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 6: loss improved from 0.02419 to 0.01889, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 7: loss improved from 0.01889 to 0.01737, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 8: loss improved from 0.01737 to 0.01660, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 9: loss improved from 0.01660 to 0.01614, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 10: loss improved from 0.01614 to 0.01565, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 11: loss improved from 0.01565 to 0.01532, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 12: loss improved from 0.01532 to 0.01503, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 13: loss improved from 0.01503 to 0.01476, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 14: loss improved from 0.01476 to 0.01452, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 15: loss improved from 0.01452 to 0.01432, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 16: loss improved from 0.01432 to 0.01415, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 17: loss improved from 0.01415 to 0.01399, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 18: loss improved from 0.01399 to 0.01387, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 19: loss improved from 0.01387 to 0.01371, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 20: loss improved from 0.01371 to 0.01361, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 21: loss improved from 0.01361 to 0.01352, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 22: loss improved from 0.01352 to 0.01339, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 23: loss improved from 0.01339 to 0.01326, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 24: loss improved from 0.01326 to 0.01314, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 25: loss improved from 0.01314 to 0.01304, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 26: loss improved from 0.01304 to 0.01290, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 27: loss improved from 0.01290 to 0.01283, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 28: loss improved from 0.01283 to 0.01245, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 29: loss improved from 0.01245 to 0.01208, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 30: loss did not improve from 0.01208
#
# Epoch 31: loss improved from 0.01208 to 0.01140, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 32: loss improved from 0.01140 to 0.01123, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 33: loss improved from 0.01123 to 0.01101, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 34: loss improved from 0.01101 to 0.01042, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 35: loss did not improve from 0.01042
#
# Epoch 36: loss did not improve from 0.01042
#
# Epoch 37: loss did not improve from 0.01042
#
# Epoch 38: loss did not improve from 0.01042
#
# Epoch 39: loss improved from 0.01042 to 0.01016, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 40: loss did not improve from 0.01016
#
# Epoch 41: loss improved from 0.01016 to 0.00990, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 42: loss did not improve from 0.00990
#
# Epoch 43: loss improved from 0.00990 to 0.00953, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 44: loss improved from 0.00953 to 0.00930, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 45: loss improved from 0.00930 to 0.00906, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 46: loss improved from 0.00906 to 0.00900, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 47: loss improved from 0.00900 to 0.00883, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 48: loss improved from 0.00883 to 0.00853, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 49: loss did not improve from 0.00853
#
# Epoch 50: loss improved from 0.00853 to 0.00800, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 51: loss improved from 0.00800 to 0.00785, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 52: loss did not improve from 0.00785
#
# Epoch 53: loss improved from 0.00785 to 0.00776, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 54: loss improved from 0.00776 to 0.00749, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 55: loss did not improve from 0.00749
#
# Epoch 56: loss did not improve from 0.00749
#
# Epoch 57: loss improved from 0.00749 to 0.00740, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 58: loss improved from 0.00740 to 0.00736, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 59: loss improved from 0.00736 to 0.00730, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 60: loss did not improve from 0.00730
#
# Epoch 61: loss did not improve from 0.00730
#
# Epoch 62: loss did not improve from 0.00730
#
# Epoch 63: loss improved from 0.00730 to 0.00730, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 64: loss improved from 0.00730 to 0.00721, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 65: loss improved from 0.00721 to 0.00710, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 66: loss improved from 0.00710 to 0.00707, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 67: loss did not improve from 0.00707
#
# Epoch 68: loss did not improve from 0.00707
#
# Epoch 69: loss improved from 0.00707 to 0.00699, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 70: loss improved from 0.00699 to 0.00696, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 71: loss did not improve from 0.00696
#
# Epoch 72: loss did not improve from 0.00696
#
# Epoch 73: loss improved from 0.00696 to 0.00682, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 74: loss improved from 0.00682 to 0.00680, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 75: loss did not improve from 0.00680
#
# Epoch 76: loss improved from 0.00680 to 0.00675, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 77: loss did not improve from 0.00675
#
# Epoch 78: loss did not improve from 0.00675
#
# Epoch 79: loss did not improve from 0.00675
#
# Epoch 80: loss did not improve from 0.00675
#
# Epoch 81: loss improved from 0.00675 to 0.00671, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 82: loss did not improve from 0.00671
#
# Epoch 83: loss improved from 0.00671 to 0.00656, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 84: loss improved from 0.00656 to 0.00650, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 85: loss did not improve from 0.00650
#
# Epoch 86: loss did not improve from 0.00650
#
# Epoch 87: loss improved from 0.00650 to 0.00649, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 88: loss did not improve from 0.00649
#
# Epoch 89: loss improved from 0.00649 to 0.00645, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 90: loss did not improve from 0.00645
#
# Epoch 91: loss improved from 0.00645 to 0.00630, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 92: loss improved from 0.00630 to 0.00614, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 93: loss improved from 0.00614 to 0.00604, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 94: loss did not improve from 0.00604
#
# Epoch 95: loss improved from 0.00604 to 0.00593, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 96: loss did not improve from 0.00593
#
# Epoch 97: loss did not improve from 0.00593
#
# Epoch 98: loss did not improve from 0.00593
#
# Epoch 99: loss did not improve from 0.00593
#
# Epoch 100: loss did not improve from 0.00593
# Epoch 100: early stopping
# 3th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05019, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 2: loss improved from 0.05019 to 0.04869, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 3: loss improved from 0.04869 to 0.04667, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 4: loss improved from 0.04667 to 0.04304, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 5: loss improved from 0.04304 to 0.03602, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 6: loss improved from 0.03602 to 0.02771, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 7: loss improved from 0.02771 to 0.02350, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 8: loss improved from 0.02350 to 0.02211, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 9: loss improved from 0.02211 to 0.02134, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 10: loss improved from 0.02134 to 0.02051, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 11: loss improved from 0.02051 to 0.01989, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 12: loss improved from 0.01989 to 0.01939, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 13: loss improved from 0.01939 to 0.01898, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 14: loss improved from 0.01898 to 0.01856, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 15: loss improved from 0.01856 to 0.01818, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 16: loss improved from 0.01818 to 0.01787, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 17: loss improved from 0.01787 to 0.01756, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 18: loss improved from 0.01756 to 0.01733, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 19: loss improved from 0.01733 to 0.01709, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 20: loss improved from 0.01709 to 0.01687, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 21: loss improved from 0.01687 to 0.01670, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 22: loss improved from 0.01670 to 0.01649, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 23: loss improved from 0.01649 to 0.01631, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 24: loss improved from 0.01631 to 0.01616, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 25: loss improved from 0.01616 to 0.01602, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 26: loss improved from 0.01602 to 0.01587, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 27: loss improved from 0.01587 to 0.01573, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 28: loss improved from 0.01573 to 0.01562, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 29: loss improved from 0.01562 to 0.01550, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 30: loss improved from 0.01550 to 0.01540, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 31: loss improved from 0.01540 to 0.01531, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 32: loss improved from 0.01531 to 0.01521, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 33: loss improved from 0.01521 to 0.01511, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 34: loss improved from 0.01511 to 0.01504, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 35: loss improved from 0.01504 to 0.01496, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 36: loss improved from 0.01496 to 0.01488, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 37: loss improved from 0.01488 to 0.01482, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 38: loss improved from 0.01482 to 0.01474, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 39: loss improved from 0.01474 to 0.01464, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 40: loss improved from 0.01464 to 0.01457, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 41: loss improved from 0.01457 to 0.01449, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 42: loss improved from 0.01449 to 0.01441, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 43: loss improved from 0.01441 to 0.01432, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 44: loss improved from 0.01432 to 0.01425, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 45: loss improved from 0.01425 to 0.01415, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 46: loss improved from 0.01415 to 0.01405, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 47: loss improved from 0.01405 to 0.01395, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 48: loss improved from 0.01395 to 0.01381, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 49: loss did not improve from 0.01381
#
# Epoch 50: loss improved from 0.01381 to 0.01359, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 51: loss improved from 0.01359 to 0.01291, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 52: loss did not improve from 0.01291
#
# Epoch 53: loss did not improve from 0.01291
#
# Epoch 54: loss did not improve from 0.01291
#
# Epoch 55: loss did not improve from 0.01291
#
# Epoch 56: loss did not improve from 0.01291
# Epoch 56: early stopping
# 4th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05185, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 2: loss improved from 0.05185 to 0.05055, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 3: loss improved from 0.05055 to 0.04857, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 4: loss improved from 0.04857 to 0.04476, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 5: loss improved from 0.04476 to 0.03711, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 6: loss improved from 0.03711 to 0.02837, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 7: loss improved from 0.02837 to 0.02322, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 8: loss improved from 0.02322 to 0.02159, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 9: loss improved from 0.02159 to 0.02030, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 10: loss improved from 0.02030 to 0.01970, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 11: loss improved from 0.01970 to 0.01918, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 12: loss improved from 0.01918 to 0.01865, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 13: loss improved from 0.01865 to 0.01818, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 14: loss improved from 0.01818 to 0.01784, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 15: loss improved from 0.01784 to 0.01746, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 16: loss improved from 0.01746 to 0.01721, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 17: loss improved from 0.01721 to 0.01691, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 18: loss improved from 0.01691 to 0.01666, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 19: loss improved from 0.01666 to 0.01644, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 20: loss improved from 0.01644 to 0.01618, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 21: loss improved from 0.01618 to 0.01597, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 22: loss improved from 0.01597 to 0.01574, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 23: loss improved from 0.01574 to 0.01558, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 24: loss improved from 0.01558 to 0.01540, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 25: loss improved from 0.01540 to 0.01519, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 26: loss improved from 0.01519 to 0.01505, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 27: loss improved from 0.01505 to 0.01493, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 28: loss improved from 0.01493 to 0.01481, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 29: loss improved from 0.01481 to 0.01472, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 30: loss improved from 0.01472 to 0.01460, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 31: loss improved from 0.01460 to 0.01452, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 32: loss improved from 0.01452 to 0.01442, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 33: loss improved from 0.01442 to 0.01435, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 34: loss improved from 0.01435 to 0.01427, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 35: loss improved from 0.01427 to 0.01419, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 36: loss improved from 0.01419 to 0.01412, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 37: loss improved from 0.01412 to 0.01406, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 38: loss improved from 0.01406 to 0.01398, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 39: loss improved from 0.01398 to 0.01391, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 40: loss improved from 0.01391 to 0.01384, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 41: loss improved from 0.01384 to 0.01376, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 42: loss improved from 0.01376 to 0.01368, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 43: loss improved from 0.01368 to 0.01362, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 44: loss improved from 0.01362 to 0.01353, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 45: loss improved from 0.01353 to 0.01346, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 46: loss improved from 0.01346 to 0.01337, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 47: loss improved from 0.01337 to 0.01330, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 48: loss improved from 0.01330 to 0.01321, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 49: loss improved from 0.01321 to 0.01313, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 50: loss improved from 0.01313 to 0.01306, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 51: loss improved from 0.01306 to 0.01299, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 52: loss improved from 0.01299 to 0.01291, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 53: loss improved from 0.01291 to 0.01284, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 54: loss improved from 0.01284 to 0.01278, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 55: loss improved from 0.01278 to 0.01272, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 56: loss improved from 0.01272 to 0.01265, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 57: loss improved from 0.01265 to 0.01260, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 58: loss improved from 0.01260 to 0.01254, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 59: loss improved from 0.01254 to 0.01248, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 60: loss improved from 0.01248 to 0.01242, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 61: loss improved from 0.01242 to 0.01237, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 62: loss improved from 0.01237 to 0.01232, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 63: loss improved from 0.01232 to 0.01226, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 64: loss improved from 0.01226 to 0.01222, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 65: loss improved from 0.01222 to 0.01215, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 66: loss improved from 0.01215 to 0.01209, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 67: loss improved from 0.01209 to 0.01202, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 68: loss improved from 0.01202 to 0.01196, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 69: loss improved from 0.01196 to 0.01186, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 70: loss improved from 0.01186 to 0.01174, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 71: loss did not improve from 0.01174
#
# Epoch 72: loss improved from 0.01174 to 0.01163, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 73: loss improved from 0.01163 to 0.01158, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 74: loss did not improve from 0.01158
#
# Epoch 75: loss improved from 0.01158 to 0.01155, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 76: loss did not improve from 0.01155
#
# Epoch 77: loss did not improve from 0.01155
#
# Epoch 78: loss improved from 0.01155 to 0.01145, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 79: loss improved from 0.01145 to 0.01143, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 80: loss did not improve from 0.01143
#
# Epoch 81: loss improved from 0.01143 to 0.01107, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 82: loss did not improve from 0.01107
#
# Epoch 83: loss improved from 0.01107 to 0.01055, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 84: loss did not improve from 0.01055
#
# Epoch 85: loss did not improve from 0.01055
#
# Epoch 86: loss did not improve from 0.01055
#
# Epoch 87: loss did not improve from 0.01055
#
# Epoch 88: loss did not improve from 0.01055
# Epoch 88: early stopping
# 5th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.04700, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 2: loss improved from 0.04700 to 0.04147, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 3: loss improved from 0.04147 to 0.02998, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 4: loss improved from 0.02998 to 0.02200, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 5: loss improved from 0.02200 to 0.01949, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 6: loss improved from 0.01949 to 0.01834, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 7: loss improved from 0.01834 to 0.01762, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 8: loss improved from 0.01762 to 0.01711, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 9: loss improved from 0.01711 to 0.01658, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 10: loss improved from 0.01658 to 0.01619, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 11: loss improved from 0.01619 to 0.01586, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 12: loss improved from 0.01586 to 0.01556, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 13: loss improved from 0.01556 to 0.01524, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 14: loss improved from 0.01524 to 0.01488, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 15: loss improved from 0.01488 to 0.01397, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 16: loss did not improve from 0.01397
#
# Epoch 17: loss improved from 0.01397 to 0.01396, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 18: loss improved from 0.01396 to 0.01299, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 19: loss improved from 0.01299 to 0.01293, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 20: loss improved from 0.01293 to 0.01226, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 21: loss improved from 0.01226 to 0.01064, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 22: loss improved from 0.01064 to 0.00989, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 23: loss did not improve from 0.00989
#
# Epoch 24: loss did not improve from 0.00989
#
# Epoch 25: loss improved from 0.00989 to 0.00881, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 26: loss improved from 0.00881 to 0.00851, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 27: loss did not improve from 0.00851
#
# Epoch 28: loss improved from 0.00851 to 0.00762, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 29: loss improved from 0.00762 to 0.00761, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 30: loss improved from 0.00761 to 0.00665, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 31: loss did not improve from 0.00665
#
# Epoch 32: loss did not improve from 0.00665
#
# Epoch 33: loss improved from 0.00665 to 0.00583, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 34: loss improved from 0.00583 to 0.00546, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 35: loss improved from 0.00546 to 0.00519, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 36: loss improved from 0.00519 to 0.00513, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 37: loss improved from 0.00513 to 0.00500, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 38: loss did not improve from 0.00500
#
# Epoch 39: loss did not improve from 0.00500
#
# Epoch 40: loss did not improve from 0.00500
#
# Epoch 41: loss improved from 0.00500 to 0.00463, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 42: loss improved from 0.00463 to 0.00454, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 43: loss improved from 0.00454 to 0.00431, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\4\best_month_model.keras
#
# ...
#
# Epoch 25: loss improved from 0.00867 to 0.00865, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 26: loss improved from 0.00865 to 0.00864, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 27: loss improved from 0.00864 to 0.00862, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 28: loss improved from 0.00862 to 0.00862, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 29: loss improved from 0.00862 to 0.00861, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 30: loss improved from 0.00861 to 0.00860, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 31: loss improved from 0.00860 to 0.00860, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 32: loss improved from 0.00860 to 0.00859, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 33: loss improved from 0.00859 to 0.00858, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 34: loss improved from 0.00858 to 0.00858, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 35: loss improved from 0.00858 to 0.00858, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 36: loss improved from 0.00858 to 0.00857, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 37: loss improved from 0.00857 to 0.00857, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 38: loss improved from 0.00857 to 0.00857, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 39: loss improved from 0.00857 to 0.00856, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 40: loss improved from 0.00856 to 0.00855, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 41: loss improved from 0.00855 to 0.00855, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 42: loss improved from 0.00855 to 0.00854, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 43: loss did not improve from 0.00854
#
# Epoch 44: loss did not improve from 0.00854
#
# Epoch 45: loss improved from 0.00854 to 0.00853, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 46: loss improved from 0.00853 to 0.00853, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 47: loss did not improve from 0.00853
#
# Epoch 48: loss improved from 0.00853 to 0.00851, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 49: loss improved from 0.00851 to 0.00850, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 50: loss improved from 0.00850 to 0.00849, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 51: loss improved from 0.00849 to 0.00848, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 52: loss did not improve from 0.00848
#
# Epoch 53: loss improved from 0.00848 to 0.00842, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 54: loss did not improve from 0.00842
#
# Epoch 55: loss improved from 0.00842 to 0.00837, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 56: loss did not improve from 0.00837
#
# Epoch 57: loss did not improve from 0.00837
#
# Epoch 58: loss did not improve from 0.00837
#
# Epoch 59: loss did not improve from 0.00837
#
# Epoch 60: loss did not improve from 0.00837
# Epoch 60: early stopping
# 47th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05252, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 2: loss improved from 0.05252 to 0.04763, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 3: loss improved from 0.04763 to 0.03379, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 4: loss improved from 0.03379 to 0.01710, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 5: loss improved from 0.01710 to 0.01209, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 6: loss improved from 0.01209 to 0.01095, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 7: loss improved from 0.01095 to 0.01028, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 8: loss improved from 0.01028 to 0.00998, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 9: loss improved from 0.00998 to 0.00973, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 10: loss improved from 0.00973 to 0.00956, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 11: loss improved from 0.00956 to 0.00941, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 12: loss improved from 0.00941 to 0.00933, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 13: loss improved from 0.00933 to 0.00894, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 14: loss did not improve from 0.00894
#
# Epoch 15: loss did not improve from 0.00894
#
# Epoch 16: loss improved from 0.00894 to 0.00869, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 17: loss improved from 0.00869 to 0.00801, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 18: loss improved from 0.00801 to 0.00676, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 19: loss improved from 0.00676 to 0.00599, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 20: loss did not improve from 0.00599
#
# Epoch 21: loss did not improve from 0.00599
#
# Epoch 22: loss improved from 0.00599 to 0.00579, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 23: loss improved from 0.00579 to 0.00507, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 24: loss improved from 0.00507 to 0.00449, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 25: loss improved from 0.00449 to 0.00365, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 26: loss did not improve from 0.00365
#
# Epoch 27: loss did not improve from 0.00365
#
# Epoch 28: loss did not improve from 0.00365
#
# Epoch 29: loss did not improve from 0.00365
#
# Epoch 30: loss improved from 0.00365 to 0.00336, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 31: loss improved from 0.00336 to 0.00304, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 32: loss improved from 0.00304 to 0.00253, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 33: loss improved from 0.00253 to 0.00244, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 34: loss improved from 0.00244 to 0.00223, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 35: loss improved from 0.00223 to 0.00212, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 36: loss did not improve from 0.00212
#
# Epoch 37: loss improved from 0.00212 to 0.00210, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 38: loss improved from 0.00210 to 0.00209, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 39: loss did not improve from 0.00209
#
# Epoch 40: loss did not improve from 0.00209
#
# Epoch 41: loss did not improve from 0.00209
#
# Epoch 42: loss did not improve from 0.00209
#
# Epoch 43: loss did not improve from 0.00209
# Epoch 43: early stopping
# 48th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05420, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 2: loss improved from 0.05420 to 0.04950, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 3: loss improved from 0.04950 to 0.03541, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 4: loss improved from 0.03541 to 0.01616, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 5: loss improved from 0.01616 to 0.01131, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 6: loss improved from 0.01131 to 0.00982, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 7: loss improved from 0.00982 to 0.00921, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 8: loss improved from 0.00921 to 0.00882, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 9: loss improved from 0.00882 to 0.00869, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 10: loss improved from 0.00869 to 0.00859, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 11: loss improved from 0.00859 to 0.00854, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 12: loss improved from 0.00854 to 0.00850, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 13: loss improved from 0.00850 to 0.00846, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 14: loss improved from 0.00846 to 0.00842, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 15: loss improved from 0.00842 to 0.00837, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 16: loss improved from 0.00837 to 0.00834, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 17: loss improved from 0.00834 to 0.00819, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 18: loss improved from 0.00819 to 0.00800, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 19: loss did not improve from 0.00800
#
# Epoch 20: loss improved from 0.00800 to 0.00749, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 21: loss did not improve from 0.00749
#
# Epoch 22: loss improved from 0.00749 to 0.00661, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 23: loss improved from 0.00661 to 0.00640, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 24: loss did not improve from 0.00640
#
# Epoch 25: loss did not improve from 0.00640
#
# Epoch 26: loss did not improve from 0.00640
#
# Epoch 27: loss did not improve from 0.00640
#
# Epoch 28: loss improved from 0.00640 to 0.00584, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 29: loss improved from 0.00584 to 0.00507, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 30: loss improved from 0.00507 to 0.00483, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 31: loss improved from 0.00483 to 0.00459, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 32: loss improved from 0.00459 to 0.00439, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 33: loss did not improve from 0.00439
#
# Epoch 34: loss improved from 0.00439 to 0.00427, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 35: loss improved from 0.00427 to 0.00403, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 36: loss improved from 0.00403 to 0.00346, saving model to ../../result\month_min_max_m2o_japan\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 37: loss did not improve from 0.00346
#
# Epoch 38: loss did not improve from 0.00346
#
# Epoch 39: loss did not improve from 0.00346
#
# Epoch 40: loss did not improve from 0.00346
#
# Epoch 41: loss did not improve from 0.00346
# Epoch 41: early stopping
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step

# %%
file_path = '../../temp_data/influA_japan_temp_month.csv'
#Load data set
df = read_data(file_path, 7)
df.corr()
# plot_month_per_year(df, 'case')
# Out:
#                case      temp       dew   tempmax  humidity   tempmin  \
# case       1.000000 -0.753157 -0.748362 -0.761420 -0.649675 -0.702533
# temp      -0.753157  1.000000  0.988932  0.968969  0.821897  0.981712
# dew       -0.748362  0.988932  1.000000  0.965072  0.896600  0.972406
# tempmax   -0.761420  0.968969  0.965072  1.000000  0.824712  0.943047
# humidity  -0.649675  0.821897  0.896600  0.824712  1.000000  0.810564
# tempmin   -0.702533  0.981712  0.972406  0.943047  0.810564  1.000000
# windspeed -0.072700  0.098091  0.023414  0.122642 -0.170920  0.035026
#
#            windspeed
# case       -0.072700
# temp        0.098091
# dew         0.023414
# tempmax     0.122642
# humidity   -0.170920
# tempmin     0.035026
# windspeed   1.000000
