# %%
from pandas import read_csv

def read_data(file_path, num_features = 2, have_time = False):
    series_influ_A_df = read_csv(file_path, engine='python')
    series_influ_A_df = series_influ_A_df.rename(columns= {"Influenza A - All types of surveillance": "case"})

    # because since 2011-03-01 It was announced that the H1N12009 flu had been controlled and treated as regular seasonal flu and
    # since 2020-02-01, it's time for covid 
    
    series_influ_A_df = series_influ_A_df.loc [(series_influ_A_df['Month'] >='2011-04-01') & (series_influ_A_df['Month'] <='2020-02-01')]
    if not have_time:
        return series_influ_A_df.dropna()[["case", "temp", "dew", "tempmax", "humidity","tempmin","windspeed"][:num_features]]
    return series_influ_A_df.dropna()[["Month", "case", "temp", "dew", "tempmax", "humidity","tempmin","windspeed"][:num_features+1]]

file_path = '../../temp_data/influA_japan_temp_month.csv'
#Load data set
df = read_data(file_path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error

def calculate_errors(y_true, y_pred):
    # Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_true, y_pred)
    
    # Mean Squared Error (MSE)
    mse = mean_squared_error(y_true, y_pred)
    
    # Root Mean Squared Error (RMSE)
    rmse = np.sqrt(mse)
    
    # Mean Absolute Percentage Error (MAPE)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    # Root Mean Squared Percentage Error (RMSPE)
    rmspe = np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))) * 100
    
    # Mean Absolute Residual (MARE)
    mare = np.mean(np.abs(y_true - y_pred))
    
    # Nash-Sutcliffe Efficiency (NSE)
    nse = 1 - (np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    
    # Normalized Nash-Sutcliffe Efficiency (NNSE)
    nnse = 1 - (np.sum((y_true - y_pred) ** 2) / np.sum((np.abs(y_true - np.mean(y_true)) + np.abs(y_pred - np.mean(y_true))) ** 2))
    
    return mae, mse, rmse, mape, rmspe, mare, nse, nnse

# %%
import numpy as np
from sklearn.metrics import r2_score

# def create_dataset(dataset, look_back=2, num_predict=1):
#     dataX, dataY = [], []
#     for i in range(0, len(dataset)-2 *look_back+1, look_back - num_predict):
#         a = dataset[i:(i+look_back)]
#         dataX.append(a)
#         dataY.append(dataset[i + look_back - num_predict : i+ 2*look_back-num_predict])
#     return np.array(dataX), np.array(dataY)

def create_dataset(dataset, look_back=1, num_predict = 1):
    dataX, dataY = [], []
    for i in range(0, len(dataset)-look_back, num_predict):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back: i+ look_back +num_predict, 0, None].tolist())
    return np.array(dataX), np.array(dataY)

def forecast(input, model):
    input = input.reshape(1, input.shape[0], input.shape[1])
    predicted = model.predict(input, verbose=0)
    return predicted[0]

def make_forecasts(test, model):
    forecasts = []
    inputStart = test[0]
    inputX = inputStart.reshape(1, inputStart.shape[0], inputStart.shape[1])
    for i in range(len(test)):
        predicted = forecast(inputX[i], model)
        print(predicted.shape)
        forecasts.append(predicted)
        if i != len(test) -1:
            inputXContinue = np.vstack((inputX[-1][predicted.shape[0]:], predicted))
            inputX = np.append(inputX, [inputXContinue], axis=0)
    
    return np.array(forecasts)
def evaluate_forecasts(test, forecasts):
    from sklearn.metrics import mean_squared_error
    testScore = np.sqrt(mean_squared_error(test, forecasts))
    print('Test Score: %.2f RMSE' % (testScore))

def plot_r2(x,y, file_path=None):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Print error metrics
    mae, mse, rmse, mape, rmspe, mare, nse, nnse = calculate_errors(x, y)
    print(f'MAE: {mae:.2f}')
    print(f'MSE: {mse:.2f}')
    print(f'RMSE: {rmse:.2f}')
    print(f'MAPE: {mape:.2f}%')
    print(f'RMSPE: {rmspe:.2f}%')
    print(f'MARE: {mare:.2f}')
    print(f'NSE: {nse:.2f}')
    print(f'NNSE: {nnse:.2f}')

    # Create the scatter plot
    plt.figure(figsize=(10, 12))

    # Subplot 1: Scatter plot and regression line
    plt.subplot(3, 1, 1)
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, r2_line, color='red', marker="o", label=f'Regression line')
    plt.title('Correlation ')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title(f'Scatter Plot with R-squared Line\nCorrelation: {r_value:.2f}, R^2: {r2_pearson:.2f}')
    plt.legend()
    plt.grid()

    # Subplot 2: Real values over time
    plt.subplot(3, 1, 2)
    plt.plot( x, color='blue', label='Real_values')
    plt.xlabel('Time')
    plt.ylabel('Real_values')
    plt.title('Real Values over Time')
    plt.legend()
    plt.grid(True)
    
    # Subplot 3: Forecast values over time
    plt.subplot(3, 1, 3)
    plt.plot(y, color='green', label='Forecast_values')
    plt.xlabel('Time')
    plt.ylabel('Forecast_values')
    plt.title('Forecast Values over Time')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    # plt.savefig(file_path)
    # plt.close()
    plt.show()

def save_plot(x,y, file_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Print error metrics
    mae, mse, rmse, mape, rmspe, mare, nse, nnse = calculate_errors(x, y)

    # Create the scatter plot
    plt.figure(figsize=(10, 12))

    # Subplot 1: Scatter plot and regression line
    plt.subplot(3, 1, 1)
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, r2_line, color='red', marker="o", label=f'Regression line')
    plt.title('Correlation ')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title(f'Scatter Plot with R-squared Line\nCorrelation: {r_value:.2f}, R^2: {r2_pearson:.2f}')
    plt.legend()
    plt.grid()

    # Subplot 2: Real values over time
    plt.subplot(3, 1, 2)
    plt.plot( x, color='blue', label='Real_values')
    plt.xlabel('Time')
    plt.ylabel('Real_values')
    plt.title('Real Values over Time')
    plt.legend()
    plt.grid(True)
    
    # Subplot 3: Forecast values over time
    plt.subplot(3, 1, 3)
    plt.plot(y, color='green', label='Forecast_values')
    plt.xlabel('Time')
    plt.ylabel('Forecast_values')
    plt.title('Forecast Values over Time')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(file_path)
    plt.close()
    return mae, mse, rmse, mape, rmspe, mare, nse, nnse, r2_pearson, r_value

def plot(testY, forecasts):
    import matplotlib.pyplot as plt
    forecastsPlot = np.empty([forecasts.shape[0]])
    forecastsPlot[:] = np.nan
    forecastsPlot[:] = forecasts[:,0].reshape(-1)
    testPlot = np.empty([testY.shape[0]])
    testPlot[:] = np.nan
    testPlot[:] = testY[:,0].reshape(-1)
    plt.plot(testPlot, "-y", label="actual", marker= '.')
    plt.plot(forecastsPlot, color = 'green', label="forecast", marker='x')
    plt.ylabel("Number of infections")
    plt.legend(["actual", "forecast"])
    plt.show()

def save(testY, forecasts, file_path):
    import matplotlib.pyplot as plt
    forecastsPlot = np.empty([forecasts.shape[0]])
    forecastsPlot[:] = np.nan
    forecastsPlot[:] = forecasts[:,0].reshape(-1)
    testPlot = np.empty([testY.shape[0]])
    testPlot[:] = np.nan
    testPlot[:] = testY[:,0].reshape(-1)
    plt.plot(testPlot, "-y", label="actual", marker= '.')
    plt.plot(forecastsPlot, color = 'green', label="forecast", marker='x')
    plt.ylabel("Number of infections")
    plt.legend(["actual", "forecast"])
    plt.savefig(file_path)
    plt.close()
    
def plot_month_per_year(df, key):
    import plotly.graph_objects as go
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df['Month'], y=df[key], mode='lines+markers', name=f'Influenza A Cases in month'))
    fig.update_layout(
        title='Influenza A Cases Over Time',
        xaxis=dict(
            title='Month',
            tickvals=df['Month'],  
            tickformat='%Y-%m',
            tickangle=90,
        ),
        yaxis=dict(title='Number of Cases'),
        showlegend=True,
    )
 
    # Show plot
    fig.show()
def inverse_transform(data, scaler):
    flattened_data = data.flatten()
    inverse_flattened_data = scaler.inverse_transform(flattened_data.reshape(-1,1))
    return inverse_flattened_data.reshape(data.shape)

# %%
# Preprocessing
def find_outliers_IQR(df):

    q1=df.quantile(0.25)

    q3=df.quantile(0.75)

    IQR=q3-q1

    outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

    return outliers

outliers = find_outliers_IQR(df['case'])

print('number of outliers: '+ str(len(outliers)))

print('max outlier value: '+ str(outliers.max()))

print('min outlier value: '+ str(outliers.min()))
# Out:
# number of outliers: 12
# max outlier value: 3158.0
# min outlier value: 1595.0

# %%
def remove_outlier_IQR(df):

    q1=df.quantile(0.25)

    q3=df.quantile(0.75)

    IQR=q3-q1

    upper = df[~(df>(q3+1.5*IQR))].max()

    lower = df[~(df<(q1-1.5*IQR))].min()

    df = np.where(
        df > upper,
        np.nan,
        np.where(df < lower,np.nan,df)
        )
    return df
impute_df = df.copy()
impute_df['case'] = remove_outlier_IQR(impute_df['case'])
# plot_month_per_year(impute_df, 'case')

# %%
linear_df = impute_df.copy()
linear_df['case'] = linear_df['case'].interpolate(method='linear')
# plot_month_per_year(linear_df, 'case')

# %%
spline_order_df = impute_df.copy()
spline_order_df['case'] = spline_order_df['case'].interpolate(method='spline', order=3)
# plot_month_per_year(spline_order_df, 'case')

# %%
def remove_outlier_impute(df, impute_method= 'linear'):
    output_df = df.copy()
    output_df["case"] = remove_outlier_IQR(output_df['case'])
    match impute_method:
        case 'linear':
            output_df['case'] = output_df['case'].interpolate(method='linear')
        case 'spline':
            output_df['case'] = output_df['case'].interpolate(method='spline', order=3)
        case _:
            pass
    return output_df

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
def moving_average(data, window_size):
    return data.rolling(window=window_size).mean()

def exponential_moving_average(data, span):
    return data.ewm(span=span, adjust=False).mean()

def prepare_data(df, is_ma=False, scaler =None):
    import pandas as pd
    df_ = pd.DataFrame()
    df_ = df.copy()
    if is_ma:
        # Apply Moving Average Filter
        window_size = 2
        
        df_['case'] = exponential_moving_average(df_['case'], window_size)
        df_ = df_.dropna()
    dataset = df_.values
    if scaler:
        flattened_dataset = dataset.flatten()
        dataset_trans = scaler.fit_transform(flattened_dataset.reshape(-1,1))
        dataset = dataset_trans.reshape(dataset.shape)
    return  dataset

scaler = MinMaxScaler()
dataset = prepare_data(df = linear_df, scaler=scaler, is_ma=True)

# %%
#process data
num_predict = 8
look_back = 8
test_size = num_predict
length = len(dataset)
dataset_length = length - (length -look_back) % num_predict
rest = length - dataset_length
dataset = dataset[rest:]
train = dataset[: -test_size,:]
test = dataset[-test_size - look_back:,:]

trainX, trainY = create_dataset(train, look_back, num_predict)
testX, testY = create_dataset(test, look_back, num_predict)

# %%
# i = 86
# print(trainX[i], trainY[i])
# len(trainX)
# j=0
# print(testX[j], testY[j])
import tensorflow as tf
from keras.losses import mean_squared_error, huber
def custom_loss(y_true, y_pred):
    return tf.sqrt(mean_squared_error(y_true, y_pred)/2)

# def custom_loss(y_true, y_pred):
#     """
#     Custom loss function that penalizes high losses.
#     """
#     # Calculate the standard loss
#     standard_loss = mean_squared_error(y_true ,y_pred)

#     # Apply a penalty function to the loss
#     penalty_factor = 3.0  # Adjust this value to control the penalty strength
#     penalty = tf.maximum(standard_loss - 0.05, 0.0) * penalty_factor

#     # Combine the standard loss and the penalty
#     total_loss = tf.sqrt(standard_loss) + penalty

#     return total_loss
def trend_loss(y_true, y_pred):
    """
    Custom loss function that focuses on capturing the trend of the time series.
    """
    true_trend = tf.math.subtract(y_true[:, 1:], y_true[:, :-1])
    pred_trend = tf.math.subtract(y_pred[:, 1:], y_pred[:, :-1])

    # Calculate the mean squared error of the trends
    trend_mse = tf.sqrt(mean_squared_error(true_trend, pred_trend))

    return trend_mse

def custom_loss_hubber_loss(y_true, y_pred):
    print(y_true.shape)
    hubber_loss = huber(y_true, y_pred, 0.1)
    trend_weight = 0
    trend_loss_value = trend_loss(y_true, y_pred)
    return (1 - trend_weight) *hubber_loss + trend_weight * trend_loss_value

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM, TimeDistributed, Input, Dropout, GRU,concatenate, Bidirectional
from sklearn.model_selection import GridSearchCV
from keras.saving import register_keras_serializable
from sklearn.metrics import r2_score


# hybrid model

def build_model(input_shape, output_units, use_layer='RNN', dropout=None, unit=64, optimizer='adam'):
    input = Input(shape=input_shape)
    # LSTM Model
    lstm_model = Sequential([
        LSTM(unit, activation='relu', return_sequences=True),
    ])

    match use_layer:
        case "LSTM":
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                LSTM(unit, activation='relu', return_sequences=True),
            ])
        case "GRU":
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                GRU(unit, activation='relu', return_sequences=True),
            ])
        case _:
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                SimpleRNN(unit, activation='relu', return_sequences=True),
            ])

    nn_output = nn_model(input)


    lstm_output = lstm_model(input)

    combined_output = concatenate([lstm_output, nn_output])

    dense_layers = Sequential([
    TimeDistributed(Dense(units=output_units, activation='sigmoid' ))
    ])

    output = dense_layers(combined_output[:,-num_predict:])
    model = tf.keras.Model(inputs=input, outputs=output)

    model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.15), metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

#loss=tf.keras.losses.Huber(delta=0.1)

# def build_model(input_shape, dropout=None, unit=64, optimizer='adam'):
#     model = Sequential()
#     model.add(Input(shape=input_shape))
#     # model.add(GRU(units=unit, activation='relu', return_sequences=True))
#     model.add(SimpleRNN(units=unit, activation='relu'))
#     # model.add(LSTM(units=unit, activation='relu'))
#     model.add(Dense(units=input_shape[1], activation='sigmoid' ))
#     model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.15), metrics=[tf.keras.metrics.RootMeanSquaredError()])
#     return model

# def build_model(input_shape,output_units, use_layer= "RNN", dropout=None, unit=64, optimizer='adam'):
#     input = Input(shape=input_shape)

#     # GRU Model
#     match use_layer:
#         case "LSTM":
#             nn_model = Sequential([
#                 # Input(input_shape=input_shape),
#                 LSTM(unit, activation='relu', return_sequences=True),
#             ])
#         case "GRU":
#             nn_model = Sequential([
#                 # Input(input_shape=input_shape),
#                 GRU(unit, activation='relu', return_sequences=True),
#             ])
#         case _:
#             nn_model = Sequential([
#                 # Input(input_shape=input_shape),
#                 SimpleRNN(unit, activation='relu', return_sequences=True),
#             ])

#     nn_output = nn_model(input)

#     dense_layers = Sequential([
#     TimeDistributed(Dense(units=output_units, activation='sigmoid' ))
#     ])

#     output = dense_layers(nn_output[:,-num_predict:])
#     model = tf.keras.Model(inputs=input, outputs=output)
#     model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.15), metrics=[tf.keras.metrics.RootMeanSquaredError()])
#     return model

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os
# model = build_model(input_shape=(trainX.shape[1], trainX.shape[2]), unit=32)
# es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
# file_path = os.path.join('../model', 'test.keras')

# mc = ModelCheckpoint(file_path, monitor='loss', mode='min', verbose=1, save_best_only=True)

# model.fit(trainX, trainY,batch_size=1, callbacks=[es, mc], verbose=0, epochs=200)

# %%
# from keras.models import load_model
# import os
# file_path = os.path.join('../model', 'test.keras')
# model = load_model(file_path, custom_objects={"custom_loss": custom_loss})


# forecasts = make_forecasts(testX, model)
# # invert predictions
# forecasts = inverse_transform(forecasts, scaler)
# testY_ = inverse_transform(testY, scaler)
# # evaluate_forecasts(testY_[:,0].reshape(-1), forecasts[:, 0].reshape(-1))

# %%
# new_shape = (testY_.shape[0] * testY_.shape[1], testY_.shape[2])
# plot(testY_.reshape(new_shape), forecasts.reshape(new_shape))

# %%
# plot_r2(testY_.reshape(new_shape)[:,0].flatten(), forecasts.reshape(new_shape)[:,0].flatten())

# %%
# trainY_hat = model.predict(trainX)
# trainY_hat_inverse = inverse_transform(trainY_hat, scaler)
# trainY_inverse = inverse_transform(trainY, scaler)
# new_shape_train = (trainY_inverse.shape[0] * trainY_inverse.shape[1], trainY_inverse.shape[2])
# plot(trainY_inverse.reshape(new_shape_train), trainY_hat_inverse.reshape(new_shape_train))

# %%
import itertools
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os, json
from keras.models import load_model

def Month_HyperParameter_Tuning(config, scaler):
    impute_methods, look_backs, num_features, n_neurons, use_layers, is_mas = config
    possible_combinations = list(itertools.product(impute_methods, look_backs, num_features, n_neurons, use_layers, is_mas))
    print(possible_combinations)
    print('\n')

    hist = []
    for i in range(0, len(possible_combinations)):
        print(f'{i+1}th combination: \n')
        print('--------------------------------------------------------------------')
        impute_method, look_back, num_feature, n_neuron, use_layer, is_ma = possible_combinations[i]
        file_path = '../../temp_data/influA_japan_temp_month.csv'
        #Load data set
        df = read_data(file_path, num_features=num_feature)
        output_df = remove_outlier_impute(df, impute_method)

        scaler = MinMaxScaler()
        dataset = prepare_data(df = output_df, scaler=scaler, is_ma=is_ma)

        num_predict = 8
        # look_back = 8
        test_size = num_predict
        length = len(dataset)
        dataset_length = length - (length -look_back) % num_predict
        rest = length - dataset_length
        dataset = dataset[rest:]
        train = dataset[: -test_size,:]
        test = dataset[-test_size - look_back:,:]

        trainX, trainY = create_dataset(train, look_back, num_predict)
        testX, testY = create_dataset(test, look_back, num_predict)
        model = build_model(
            input_shape=(trainX.shape[1], trainX.shape[2]),
            output_units = trainY.shape[2],
            use_layer=use_layer,
            unit=n_neuron
            )
        es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
        result_dir = os.path.join("../../result", f"""month_min_max_m2o_japan""", "hybrid")
        result_combination_dir = os.path.join(result_dir, str(i))
        os.makedirs(result_combination_dir, exist_ok=True)
        file_path = os.path.join(result_combination_dir, 'best_month_model.keras')
        mc = ModelCheckpoint(file_path, monitor='loss', mode='min', verbose=1, save_best_only=True)
        model.fit(trainX, trainY, batch_size=1, callbacks=[es, mc], verbose=0, epochs=200) 
        config = {
            "num_feature": num_feature,
            "use_layer": use_layer,
            "unit": n_neuron,
            "look_back": look_back,
            "is_ma": is_ma,
            "impute_method": impute_method,
        } 
        with open(os.path.join(result_combination_dir,'config.json'), 'w') as f:
            json.dump(config, f)

    for i in range(0, len(possible_combinations)):
        impute_method, look_back, num_feature, n_neuron, use_layer, is_ma = possible_combinations[i]

        file_path = '../../temp_data/influA_japan_temp_month.csv'
        #Load data set
        df = read_data(file_path, num_features=num_feature)
        output_df = remove_outlier_impute(df, impute_method)

        scaler = MinMaxScaler()
        dataset = prepare_data(df = output_df, scaler=scaler, is_ma=is_ma)

        num_predict = 8
        # look_back = 8
        test_size = num_predict
        length = len(dataset)
        dataset_length = length - (length -look_back) % num_predict
        rest = length - dataset_length
        dataset = dataset[rest:]
        train = dataset[: -test_size,:]
        test = dataset[-test_size - look_back:,:]

        trainX, trainY = create_dataset(train, look_back, num_predict)
        testX, testY = create_dataset(test, look_back, num_predict)


        result_dir = os.path.join("../../result", f"""month_min_max_m2o_japan""", "hybrid")
        result_combination_dir = os.path.join(result_dir, str(i))
        os.makedirs(result_combination_dir, exist_ok=True)
        file_path = os.path.join(result_combination_dir, 'best_month_model.keras')

        model = load_model(file_path)

        forecasts = make_forecasts(testX, model)
        # invert predictions
        forecasts = inverse_transform(forecasts,scaler)
        testY_ = inverse_transform(testY,scaler)
        # evaluate_forecasts(testY_[:,0].reshape(-1), forecasts[:, 0].reshape(-1))
        new_shape = (testY_.shape[0] * testY_.shape[1], testY_.shape[2])
        
        r2_image_path = os.path.join(result_combination_dir, 'r2_image.png')
        mae, mse, rmse, mape, rmspe, mare, nse, nnse, r2_pearson, r_value = save_plot(testY_.reshape(new_shape)[:,0].flatten(), forecasts.reshape(new_shape)[:,0].flatten(), r2_image_path)
        hist.append(list((impute_method, look_back, num_feature, n_neuron, use_layer, is_ma, rmse, r2_pearson,r_value, mae, mse, mape, rmspe, mare, nse, nnse)))
        test_image_path = os.path.join(result_combination_dir, 'test.png')
        train_image_path = os.path.join(result_combination_dir, 'train.png')
        save(testY_.reshape(new_shape), forecasts.reshape(new_shape), test_image_path)

        trainY_hat = model.predict(trainX)
        trainY_hat_inverse = inverse_transform(trainY_hat, scaler)
        trainY_inverse = inverse_transform(trainY, scaler)
        new_shape_train = (trainY_inverse.shape[0] * trainY_inverse.shape[1], trainY_inverse.shape[2])
        save(trainY_inverse.reshape(new_shape_train), trainY_hat_inverse.reshape(new_shape_train), train_image_path)
    import pandas as pd
    hist_df = pd.DataFrame(hist)
    hist_df = hist_df.rename(columns={
        0: 'impute_method', 
        1: 'look_back', 
        2: 'num_feature', 
        3: 'unit', 
        4: 'use_layer', 
        5: 'is_ma', 
        6:'rmse', 
        7: 'r2_score', 
        8: 'correlation', 
        9:'mae', 
        10: 'mse', 
        11:'mape', 
        12:'rmspe', 
        13:'mare', 
        14:'nse', 
        15:'nnse'
        })
    hist_df = hist_df.sort_values(by=['r2_score'], ascending=False)
    hist_df.to_csv(os.path.join(result_dir, 'history.csv'))
    return hist_df

# %%
num_features = [2,3]
use_layers = ["GRU", "LSTM", "RNN"]
units = [64]
look_backs = [8,10]
is_mas = [True, False]
impute_methods = ["linear", "spline"]

config = [impute_methods, look_backs, num_features, units, use_layers, is_mas]
hist = Month_HyperParameter_Tuning(config, scaler)
# Out:
# [('linear', 8, 2, 64, 'GRU', True), ('linear', 8, 2, 64, 'GRU', False), ('linear', 8, 2, 64, 'LSTM', True), ('linear', 8, 2, 64, 'LSTM', False), ('linear', 8, 2, 64, 'RNN', True), ('linear', 8, 2, 64, 'RNN', False), ('linear', 8, 3, 64, 'GRU', True), ('linear', 8, 3, 64, 'GRU', False), ('linear', 8, 3, 64, 'LSTM', True), ('linear', 8, 3, 64, 'LSTM', False), ('linear', 8, 3, 64, 'RNN', True), ('linear', 8, 3, 64, 'RNN', False), ('linear', 10, 2, 64, 'GRU', True), ('linear', 10, 2, 64, 'GRU', False), ('linear', 10, 2, 64, 'LSTM', True), ('linear', 10, 2, 64, 'LSTM', False), ('linear', 10, 2, 64, 'RNN', True), ('linear', 10, 2, 64, 'RNN', False), ('linear', 10, 3, 64, 'GRU', True), ('linear', 10, 3, 64, 'GRU', False), ('linear', 10, 3, 64, 'LSTM', True), ('linear', 10, 3, 64, 'LSTM', False), ('linear', 10, 3, 64, 'RNN', True), ('linear', 10, 3, 64, 'RNN', False), ('spline', 8, 2, 64, 'GRU', True), ('spline', 8, 2, 64, 'GRU', False), ('spline', 8, 2, 64, 'LSTM', True), ('spline', 8, 2, 64, 'LSTM', False), ('spline', 8, 2, 64, 'RNN', True), ('spline', 8, 2, 64, 'RNN', False), ('spline', 8, 3, 64, 'GRU', True), ('spline', 8, 3, 64, 'GRU', False), ('spline', 8, 3, 64, 'LSTM', True), ('spline', 8, 3, 64, 'LSTM', False), ('spline', 8, 3, 64, 'RNN', True), ('spline', 8, 3, 64, 'RNN', False), ('spline', 10, 2, 64, 'GRU', True), ('spline', 10, 2, 64, 'GRU', False), ('spline', 10, 2, 64, 'LSTM', True), ('spline', 10, 2, 64, 'LSTM', False), ('spline', 10, 2, 64, 'RNN', True), ('spline', 10, 2, 64, 'RNN', False), ('spline', 10, 3, 64, 'GRU', True), ('spline', 10, 3, 64, 'GRU', False), ('spline', 10, 3, 64, 'LSTM', True), ('spline', 10, 3, 64, 'LSTM', False), ('spline', 10, 3, 64, 'RNN', True), ('spline', 10, 3, 64, 'RNN', False)]
#
#
# 1th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.03796, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 2: loss improved from 0.03796 to 0.03606, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 3: loss improved from 0.03606 to 0.03349, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 4: loss improved from 0.03349 to 0.03089, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 5: loss improved from 0.03089 to 0.02790, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 6: loss improved from 0.02790 to 0.02495, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 7: loss improved from 0.02495 to 0.02337, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 8: loss improved from 0.02337 to 0.02306, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 9: loss improved from 0.02306 to 0.02278, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 10: loss improved from 0.02278 to 0.02248, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 11: loss improved from 0.02248 to 0.02207, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 12: loss improved from 0.02207 to 0.02174, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 13: loss improved from 0.02174 to 0.02135, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 14: loss improved from 0.02135 to 0.02098, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 15: loss improved from 0.02098 to 0.02051, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 16: loss improved from 0.02051 to 0.01987, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 17: loss improved from 0.01987 to 0.01909, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 18: loss improved from 0.01909 to 0.01828, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 19: loss improved from 0.01828 to 0.01742, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 20: loss improved from 0.01742 to 0.01573, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 21: loss improved from 0.01573 to 0.01500, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 22: loss improved from 0.01500 to 0.01428, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 23: loss did not improve from 0.01428
#
# Epoch 24: loss improved from 0.01428 to 0.01376, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 25: loss improved from 0.01376 to 0.01362, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 26: loss did not improve from 0.01362
#
# Epoch 27: loss improved from 0.01362 to 0.01334, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 28: loss improved from 0.01334 to 0.01312, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 29: loss improved from 0.01312 to 0.01310, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 30: loss improved from 0.01310 to 0.01292, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 31: loss improved from 0.01292 to 0.01264, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 32: loss improved from 0.01264 to 0.01257, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 33: loss improved from 0.01257 to 0.01256, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 34: loss improved from 0.01256 to 0.01232, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 35: loss improved from 0.01232 to 0.01228, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 36: loss improved from 0.01228 to 0.01166, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 37: loss improved from 0.01166 to 0.01166, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 38: loss improved from 0.01166 to 0.01163, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 39: loss improved from 0.01163 to 0.01121, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 40: loss improved from 0.01121 to 0.01119, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 41: loss improved from 0.01119 to 0.01079, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 42: loss improved from 0.01079 to 0.01064, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 43: loss improved from 0.01064 to 0.01036, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 44: loss did not improve from 0.01036
#
# Epoch 45: loss did not improve from 0.01036
#
# Epoch 46: loss improved from 0.01036 to 0.01002, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 47: loss improved from 0.01002 to 0.00989, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 48: loss improved from 0.00989 to 0.00949, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 49: loss did not improve from 0.00949
#
# Epoch 50: loss improved from 0.00949 to 0.00915, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 51: loss improved from 0.00915 to 0.00907, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 52: loss did not improve from 0.00907
#
# Epoch 53: loss improved from 0.00907 to 0.00889, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 54: loss improved from 0.00889 to 0.00876, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 55: loss improved from 0.00876 to 0.00858, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 56: loss improved from 0.00858 to 0.00834, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 57: loss improved from 0.00834 to 0.00802, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 58: loss improved from 0.00802 to 0.00798, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 59: loss improved from 0.00798 to 0.00777, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 60: loss improved from 0.00777 to 0.00764, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 61: loss improved from 0.00764 to 0.00753, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 62: loss did not improve from 0.00753
#
# Epoch 63: loss improved from 0.00753 to 0.00725, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 64: loss did not improve from 0.00725
#
# Epoch 65: loss improved from 0.00725 to 0.00717, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 66: loss improved from 0.00717 to 0.00699, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 67: loss did not improve from 0.00699
#
# Epoch 68: loss did not improve from 0.00699
#
# Epoch 69: loss did not improve from 0.00699
#
# Epoch 70: loss improved from 0.00699 to 0.00676, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 71: loss did not improve from 0.00676
#
# Epoch 72: loss improved from 0.00676 to 0.00657, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 73: loss improved from 0.00657 to 0.00654, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 74: loss improved from 0.00654 to 0.00642, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 75: loss did not improve from 0.00642
#
# Epoch 76: loss did not improve from 0.00642
#
# Epoch 77: loss did not improve from 0.00642
#
# Epoch 78: loss improved from 0.00642 to 0.00630, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 79: loss did not improve from 0.00630
#
# Epoch 80: loss did not improve from 0.00630
#
# Epoch 81: loss improved from 0.00630 to 0.00620, saving model to ../../result\month_min_max_m2o_japan\hybrid\0\best_month_model.keras
#
# Epoch 82: loss did not improve from 0.00620
#
# Epoch 83: loss did not improve from 0.00620
#
# Epoch 84: loss did not improve from 0.00620
#
# Epoch 85: loss did not improve from 0.00620
#
# Epoch 86: loss did not improve from 0.00620
# Epoch 86: early stopping
# 2th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.04126, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 2: loss improved from 0.04126 to 0.03883, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 3: loss improved from 0.03883 to 0.03590, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 4: loss improved from 0.03590 to 0.03251, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 5: loss improved from 0.03251 to 0.02913, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 6: loss improved from 0.02913 to 0.02480, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 7: loss improved from 0.02480 to 0.02385, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 8: loss improved from 0.02385 to 0.02341, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 9: loss improved from 0.02341 to 0.02303, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 10: loss improved from 0.02303 to 0.02275, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 11: loss improved from 0.02275 to 0.02244, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 12: loss improved from 0.02244 to 0.02220, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 13: loss improved from 0.02220 to 0.02164, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 14: loss improved from 0.02164 to 0.02139, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 15: loss improved from 0.02139 to 0.02082, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 16: loss improved from 0.02082 to 0.02081, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 17: loss improved from 0.02081 to 0.01996, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 18: loss improved from 0.01996 to 0.01936, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 19: loss improved from 0.01936 to 0.01733, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 20: loss improved from 0.01733 to 0.01603, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 21: loss improved from 0.01603 to 0.01552, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 22: loss improved from 0.01552 to 0.01497, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 23: loss improved from 0.01497 to 0.01466, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 24: loss improved from 0.01466 to 0.01465, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 25: loss improved from 0.01465 to 0.01447, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 26: loss did not improve from 0.01447
#
# Epoch 27: loss did not improve from 0.01447
#
# Epoch 28: loss improved from 0.01447 to 0.01425, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 29: loss did not improve from 0.01425
#
# Epoch 30: loss did not improve from 0.01425
#
# Epoch 31: loss improved from 0.01425 to 0.01406, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 32: loss did not improve from 0.01406
#
# Epoch 33: loss did not improve from 0.01406
#
# Epoch 34: loss did not improve from 0.01406
#
# Epoch 35: loss improved from 0.01406 to 0.01406, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 36: loss improved from 0.01406 to 0.01396, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 37: loss did not improve from 0.01396
#
# Epoch 38: loss improved from 0.01396 to 0.01392, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 39: loss improved from 0.01392 to 0.01390, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 40: loss did not improve from 0.01390
#
# Epoch 41: loss improved from 0.01390 to 0.01377, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 42: loss improved from 0.01377 to 0.01373, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 43: loss improved from 0.01373 to 0.01367, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 44: loss did not improve from 0.01367
#
# Epoch 45: loss improved from 0.01367 to 0.01365, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 46: loss improved from 0.01365 to 0.01361, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 47: loss improved from 0.01361 to 0.01361, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 48: loss improved from 0.01361 to 0.01355, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 49: loss did not improve from 0.01355
#
# Epoch 50: loss improved from 0.01355 to 0.01349, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 51: loss improved from 0.01349 to 0.01344, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 52: loss improved from 0.01344 to 0.01337, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 53: loss improved from 0.01337 to 0.01328, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 54: loss improved from 0.01328 to 0.01326, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 55: loss did not improve from 0.01326
#
# Epoch 56: loss improved from 0.01326 to 0.01309, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 57: loss improved from 0.01309 to 0.01301, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 58: loss did not improve from 0.01301
#
# Epoch 59: loss did not improve from 0.01301
#
# Epoch 60: loss did not improve from 0.01301
#
# Epoch 61: loss improved from 0.01301 to 0.01278, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 62: loss improved from 0.01278 to 0.01268, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 63: loss improved from 0.01268 to 0.01258, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 64: loss did not improve from 0.01258
#
# Epoch 65: loss improved from 0.01258 to 0.01244, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 66: loss improved from 0.01244 to 0.01232, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 67: loss improved from 0.01232 to 0.01207, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 68: loss improved from 0.01207 to 0.01201, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 69: loss improved from 0.01201 to 0.01197, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 70: loss improved from 0.01197 to 0.01193, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 71: loss improved from 0.01193 to 0.01159, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 72: loss did not improve from 0.01159
#
# Epoch 73: loss did not improve from 0.01159
#
# Epoch 74: loss did not improve from 0.01159
#
# Epoch 75: loss improved from 0.01159 to 0.01135, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 76: loss improved from 0.01135 to 0.01133, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 77: loss did not improve from 0.01133
#
# Epoch 78: loss did not improve from 0.01133
#
# Epoch 79: loss improved from 0.01133 to 0.01121, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 80: loss improved from 0.01121 to 0.01105, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 81: loss did not improve from 0.01105
#
# Epoch 82: loss improved from 0.01105 to 0.01094, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 83: loss improved from 0.01094 to 0.01075, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 84: loss improved from 0.01075 to 0.01069, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 85: loss did not improve from 0.01069
#
# Epoch 86: loss did not improve from 0.01069
#
# Epoch 87: loss did not improve from 0.01069
#
# Epoch 88: loss improved from 0.01069 to 0.01055, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 89: loss did not improve from 0.01055
#
# Epoch 90: loss improved from 0.01055 to 0.01045, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 91: loss did not improve from 0.01045
#
# Epoch 92: loss improved from 0.01045 to 0.01021, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 93: loss improved from 0.01021 to 0.01014, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 94: loss improved from 0.01014 to 0.01001, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 95: loss did not improve from 0.01001
#
# Epoch 96: loss improved from 0.01001 to 0.00989, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 97: loss improved from 0.00989 to 0.00973, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 98: loss did not improve from 0.00973
#
# Epoch 99: loss did not improve from 0.00973
#
# Epoch 100: loss did not improve from 0.00973
#
# Epoch 101: loss did not improve from 0.00973
#
# Epoch 102: loss improved from 0.00973 to 0.00952, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 103: loss improved from 0.00952 to 0.00946, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 104: loss improved from 0.00946 to 0.00935, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 105: loss improved from 0.00935 to 0.00933, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 106: loss did not improve from 0.00933
#
# Epoch 107: loss improved from 0.00933 to 0.00916, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 108: loss improved from 0.00916 to 0.00904, saving model to ../../result\month_min_max_m2o_japan\hybrid\1\best_month_model.keras
#
# Epoch 109: loss did not improve from 0.00904
#
# Epoch 110: loss did not improve from 0.00904
#
# Epoch 111: loss did not improve from 0.00904
#
# Epoch 112: loss did not improve from 0.00904
#
# Epoch 113: loss did not improve from 0.00904
# Epoch 113: early stopping
# 3th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.03767, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 2: loss improved from 0.03767 to 0.03644, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 3: loss improved from 0.03644 to 0.03517, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 4: loss improved from 0.03517 to 0.03306, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 5: loss improved from 0.03306 to 0.03062, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 6: loss improved from 0.03062 to 0.02784, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 7: loss improved from 0.02784 to 0.02607, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 8: loss improved from 0.02607 to 0.02530, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 9: loss improved from 0.02530 to 0.02484, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 10: loss improved from 0.02484 to 0.02453, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 11: loss improved from 0.02453 to 0.02393, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 12: loss improved from 0.02393 to 0.02359, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 13: loss improved from 0.02359 to 0.02317, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 14: loss improved from 0.02317 to 0.02260, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 15: loss improved from 0.02260 to 0.02184, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 16: loss improved from 0.02184 to 0.02073, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 17: loss improved from 0.02073 to 0.01944, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 18: loss improved from 0.01944 to 0.01807, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 19: loss improved from 0.01807 to 0.01662, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 20: loss improved from 0.01662 to 0.01580, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 21: loss did not improve from 0.01580
#
# Epoch 22: loss improved from 0.01580 to 0.01496, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 23: loss did not improve from 0.01496
#
# Epoch 24: loss did not improve from 0.01496
#
# Epoch 25: loss did not improve from 0.01496
#
# Epoch 26: loss improved from 0.01496 to 0.01466, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 27: loss did not improve from 0.01466
#
# Epoch 28: loss did not improve from 0.01466
#
# Epoch 29: loss improved from 0.01466 to 0.01439, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 30: loss did not improve from 0.01439
#
# Epoch 31: loss improved from 0.01439 to 0.01435, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 32: loss improved from 0.01435 to 0.01381, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 33: loss improved from 0.01381 to 0.01375, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 34: loss improved from 0.01375 to 0.01354, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 35: loss improved from 0.01354 to 0.01349, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 36: loss improved from 0.01349 to 0.01335, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 37: loss improved from 0.01335 to 0.01306, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 38: loss did not improve from 0.01306
#
# Epoch 39: loss improved from 0.01306 to 0.01284, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 40: loss improved from 0.01284 to 0.01275, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 41: loss did not improve from 0.01275
#
# Epoch 42: loss did not improve from 0.01275
#
# Epoch 43: loss improved from 0.01275 to 0.01241, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 44: loss improved from 0.01241 to 0.01215, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 45: loss improved from 0.01215 to 0.01201, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 46: loss improved from 0.01201 to 0.01194, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 47: loss improved from 0.01194 to 0.01165, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 48: loss did not improve from 0.01165
#
# Epoch 49: loss improved from 0.01165 to 0.01133, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 50: loss improved from 0.01133 to 0.01110, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 51: loss did not improve from 0.01110
#
# Epoch 52: loss improved from 0.01110 to 0.01078, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 53: loss did not improve from 0.01078
#
# Epoch 54: loss improved from 0.01078 to 0.01051, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 55: loss improved from 0.01051 to 0.01047, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 56: loss improved from 0.01047 to 0.01016, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 57: loss improved from 0.01016 to 0.01013, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 58: loss improved from 0.01013 to 0.00986, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 59: loss improved from 0.00986 to 0.00960, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 60: loss improved from 0.00960 to 0.00940, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 61: loss improved from 0.00940 to 0.00937, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 62: loss improved from 0.00937 to 0.00918, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 63: loss improved from 0.00918 to 0.00893, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 64: loss did not improve from 0.00893
#
# Epoch 65: loss improved from 0.00893 to 0.00885, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 66: loss improved from 0.00885 to 0.00872, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 67: loss improved from 0.00872 to 0.00858, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 68: loss did not improve from 0.00858
#
# Epoch 69: loss improved from 0.00858 to 0.00846, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 70: loss improved from 0.00846 to 0.00839, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 71: loss improved from 0.00839 to 0.00821, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 72: loss improved from 0.00821 to 0.00813, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 73: loss improved from 0.00813 to 0.00803, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 74: loss improved from 0.00803 to 0.00799, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 75: loss improved from 0.00799 to 0.00790, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 76: loss did not improve from 0.00790
#
# Epoch 77: loss did not improve from 0.00790
#
# Epoch 78: loss improved from 0.00790 to 0.00773, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 79: loss improved from 0.00773 to 0.00767, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 80: loss improved from 0.00767 to 0.00760, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 81: loss improved from 0.00760 to 0.00754, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 82: loss improved from 0.00754 to 0.00751, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 83: loss improved from 0.00751 to 0.00744, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 84: loss improved from 0.00744 to 0.00730, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 85: loss did not improve from 0.00730
#
# Epoch 86: loss did not improve from 0.00730
#
# Epoch 87: loss did not improve from 0.00730
#
# Epoch 88: loss improved from 0.00730 to 0.00717, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 89: loss did not improve from 0.00717
#
# Epoch 90: loss did not improve from 0.00717
#
# Epoch 91: loss improved from 0.00717 to 0.00708, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 92: loss improved from 0.00708 to 0.00703, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 93: loss did not improve from 0.00703
#
# Epoch 94: loss improved from 0.00703 to 0.00695, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 95: loss improved from 0.00695 to 0.00683, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 96: loss did not improve from 0.00683
#
# Epoch 97: loss improved from 0.00683 to 0.00673, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 98: loss did not improve from 0.00673
#
# Epoch 99: loss improved from 0.00673 to 0.00670, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 100: loss did not improve from 0.00670
#
# Epoch 101: loss improved from 0.00670 to 0.00666, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 102: loss improved from 0.00666 to 0.00659, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 103: loss improved from 0.00659 to 0.00647, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 104: loss did not improve from 0.00647
#
# Epoch 105: loss improved from 0.00647 to 0.00646, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 106: loss improved from 0.00646 to 0.00639, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 107: loss improved from 0.00639 to 0.00627, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 108: loss did not improve from 0.00627
#
# Epoch 109: loss did not improve from 0.00627
#
# Epoch 110: loss improved from 0.00627 to 0.00615, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 111: loss did not improve from 0.00615
#
# Epoch 112: loss did not improve from 0.00615
#
# Epoch 113: loss improved from 0.00615 to 0.00604, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 114: loss did not improve from 0.00604
#
# Epoch 115: loss did not improve from 0.00604
#
# Epoch 116: loss improved from 0.00604 to 0.00594, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 117: loss improved from 0.00594 to 0.00593, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 118: loss did not improve from 0.00593
#
# Epoch 119: loss improved from 0.00593 to 0.00587, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 120: loss did not improve from 0.00587
#
# Epoch 121: loss improved from 0.00587 to 0.00582, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 122: loss did not improve from 0.00582
#
# Epoch 123: loss improved from 0.00582 to 0.00581, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 124: loss improved from 0.00581 to 0.00573, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 125: loss improved from 0.00573 to 0.00572, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 126: loss improved from 0.00572 to 0.00567, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 127: loss did not improve from 0.00567
#
# Epoch 128: loss improved from 0.00567 to 0.00562, saving model to ../../result\month_min_max_m2o_japan\hybrid\2\best_month_model.keras
#
# Epoch 129: loss did not improve from 0.00562
#
# Epoch 130: loss did not improve from 0.00562
#
# Epoch 131: loss did not improve from 0.00562
#
# Epoch 132: loss did not improve from 0.00562
#
# Epoch 133: loss did not improve from 0.00562
# Epoch 133: early stopping
# 4th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.04125, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 2: loss improved from 0.04125 to 0.03954, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 3: loss improved from 0.03954 to 0.03745, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 4: loss improved from 0.03745 to 0.03474, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 5: loss improved from 0.03474 to 0.03124, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 6: loss improved from 0.03124 to 0.02832, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 7: loss improved from 0.02832 to 0.02570, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 8: loss improved from 0.02570 to 0.02528, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 9: loss improved from 0.02528 to 0.02481, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 10: loss improved from 0.02481 to 0.02468, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 11: loss improved from 0.02468 to 0.02439, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 12: loss improved from 0.02439 to 0.02438, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 13: loss improved from 0.02438 to 0.02399, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 14: loss improved from 0.02399 to 0.02360, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 15: loss improved from 0.02360 to 0.02338, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 16: loss improved from 0.02338 to 0.02298, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 17: loss improved from 0.02298 to 0.02277, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 18: loss improved from 0.02277 to 0.02198, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 19: loss improved from 0.02198 to 0.02123, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 20: loss improved from 0.02123 to 0.02027, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 21: loss improved from 0.02027 to 0.01893, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 22: loss improved from 0.01893 to 0.01799, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 23: loss improved from 0.01799 to 0.01734, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 24: loss improved from 0.01734 to 0.01657, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 25: loss did not improve from 0.01657
#
# Epoch 26: loss improved from 0.01657 to 0.01602, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 27: loss improved from 0.01602 to 0.01555, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 28: loss improved from 0.01555 to 0.01523, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 29: loss improved from 0.01523 to 0.01518, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 30: loss improved from 0.01518 to 0.01507, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 31: loss improved from 0.01507 to 0.01502, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 32: loss did not improve from 0.01502
#
# Epoch 33: loss did not improve from 0.01502
#
# Epoch 34: loss improved from 0.01502 to 0.01492, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 35: loss improved from 0.01492 to 0.01486, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 36: loss did not improve from 0.01486
#
# Epoch 37: loss improved from 0.01486 to 0.01473, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 38: loss improved from 0.01473 to 0.01460, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 39: loss improved from 0.01460 to 0.01459, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 40: loss improved from 0.01459 to 0.01455, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 41: loss improved from 0.01455 to 0.01452, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 42: loss did not improve from 0.01452
#
# Epoch 43: loss improved from 0.01452 to 0.01442, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 44: loss improved from 0.01442 to 0.01440, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 45: loss improved from 0.01440 to 0.01425, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 46: loss improved from 0.01425 to 0.01417, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 47: loss improved from 0.01417 to 0.01410, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 48: loss improved from 0.01410 to 0.01401, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 49: loss did not improve from 0.01401
#
# Epoch 50: loss improved from 0.01401 to 0.01396, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 51: loss improved from 0.01396 to 0.01389, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 52: loss improved from 0.01389 to 0.01376, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 53: loss did not improve from 0.01376
#
# Epoch 54: loss improved from 0.01376 to 0.01368, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 55: loss improved from 0.01368 to 0.01360, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 56: loss did not improve from 0.01360
#
# Epoch 57: loss did not improve from 0.01360
#
# Epoch 58: loss improved from 0.01360 to 0.01358, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 59: loss improved from 0.01358 to 0.01357, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 60: loss improved from 0.01357 to 0.01325, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 61: loss improved from 0.01325 to 0.01314, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 62: loss improved from 0.01314 to 0.01311, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 63: loss did not improve from 0.01311
#
# Epoch 64: loss did not improve from 0.01311
#
# Epoch 65: loss improved from 0.01311 to 0.01285, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 66: loss improved from 0.01285 to 0.01278, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 67: loss improved from 0.01278 to 0.01261, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 68: loss improved from 0.01261 to 0.01256, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 69: loss improved from 0.01256 to 0.01241, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 70: loss improved from 0.01241 to 0.01235, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 71: loss did not improve from 0.01235
#
# Epoch 72: loss did not improve from 0.01235
#
# Epoch 73: loss improved from 0.01235 to 0.01232, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 74: loss improved from 0.01232 to 0.01193, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 75: loss did not improve from 0.01193
#
# Epoch 76: loss did not improve from 0.01193
#
# Epoch 77: loss improved from 0.01193 to 0.01192, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 78: loss improved from 0.01192 to 0.01181, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 79: loss improved from 0.01181 to 0.01170, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 80: loss improved from 0.01170 to 0.01160, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 81: loss improved from 0.01160 to 0.01131, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 82: loss improved from 0.01131 to 0.01120, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 83: loss did not improve from 0.01120
#
# Epoch 84: loss improved from 0.01120 to 0.01099, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# Epoch 85: loss did not improve from 0.01099
#
# Epoch 86: loss did not improve from 0.01099
#
# Epoch 87: loss improved from 0.01099 to 0.01096, saving model to ../../result\month_min_max_m2o_japan\hybrid\3\best_month_model.keras
#
# ...
#
# Epoch 39: loss improved from 0.00725 to 0.00722, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 40: loss did not improve from 0.00722
#
# Epoch 41: loss improved from 0.00722 to 0.00707, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 42: loss did not improve from 0.00707
#
# Epoch 43: loss improved from 0.00707 to 0.00680, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 44: loss did not improve from 0.00680
#
# Epoch 45: loss did not improve from 0.00680
#
# Epoch 46: loss improved from 0.00680 to 0.00657, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 47: loss did not improve from 0.00657
#
# Epoch 48: loss improved from 0.00657 to 0.00655, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 49: loss did not improve from 0.00655
#
# Epoch 50: loss did not improve from 0.00655
#
# Epoch 51: loss did not improve from 0.00655
#
# Epoch 52: loss improved from 0.00655 to 0.00639, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 53: loss improved from 0.00639 to 0.00619, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 54: loss improved from 0.00619 to 0.00611, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 55: loss did not improve from 0.00611
#
# Epoch 56: loss did not improve from 0.00611
#
# Epoch 57: loss improved from 0.00611 to 0.00589, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 58: loss improved from 0.00589 to 0.00579, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 59: loss did not improve from 0.00579
#
# Epoch 60: loss did not improve from 0.00579
#
# Epoch 61: loss improved from 0.00579 to 0.00550, saving model to ../../result\month_min_max_m2o_japan\hybrid\44\best_month_model.keras
#
# Epoch 62: loss did not improve from 0.00550
#
# Epoch 63: loss did not improve from 0.00550
#
# Epoch 64: loss did not improve from 0.00550
#
# Epoch 65: loss did not improve from 0.00550
#
# Epoch 66: loss did not improve from 0.00550
# Epoch 66: early stopping
# 46th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.04273, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 2: loss improved from 0.04273 to 0.04080, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 3: loss improved from 0.04080 to 0.03788, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 4: loss improved from 0.03788 to 0.03334, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 5: loss improved from 0.03334 to 0.02768, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 6: loss improved from 0.02768 to 0.02563, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 7: loss improved from 0.02563 to 0.02502, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 8: loss improved from 0.02502 to 0.02409, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 9: loss improved from 0.02409 to 0.02331, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 10: loss improved from 0.02331 to 0.02267, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 11: loss improved from 0.02267 to 0.02196, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 12: loss improved from 0.02196 to 0.02118, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 13: loss improved from 0.02118 to 0.02034, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 14: loss improved from 0.02034 to 0.01921, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 15: loss improved from 0.01921 to 0.01783, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 16: loss improved from 0.01783 to 0.01647, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 17: loss improved from 0.01647 to 0.01409, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 18: loss improved from 0.01409 to 0.01317, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 19: loss did not improve from 0.01317
#
# Epoch 20: loss did not improve from 0.01317
#
# Epoch 21: loss improved from 0.01317 to 0.01195, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 22: loss improved from 0.01195 to 0.01145, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 23: loss did not improve from 0.01145
#
# Epoch 24: loss did not improve from 0.01145
#
# Epoch 25: loss improved from 0.01145 to 0.01027, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 26: loss improved from 0.01027 to 0.00915, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 27: loss improved from 0.00915 to 0.00870, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 28: loss improved from 0.00870 to 0.00787, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 29: loss improved from 0.00787 to 0.00768, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 30: loss improved from 0.00768 to 0.00750, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 31: loss did not improve from 0.00750
#
# Epoch 32: loss improved from 0.00750 to 0.00693, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 33: loss improved from 0.00693 to 0.00680, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 34: loss improved from 0.00680 to 0.00656, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 35: loss improved from 0.00656 to 0.00642, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 36: loss improved from 0.00642 to 0.00618, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 37: loss improved from 0.00618 to 0.00596, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 38: loss did not improve from 0.00596
#
# Epoch 39: loss improved from 0.00596 to 0.00594, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 40: loss did not improve from 0.00594
#
# Epoch 41: loss improved from 0.00594 to 0.00573, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 42: loss did not improve from 0.00573
#
# Epoch 43: loss improved from 0.00573 to 0.00569, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 44: loss improved from 0.00569 to 0.00562, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 45: loss improved from 0.00562 to 0.00556, saving model to ../../result\month_min_max_m2o_japan\hybrid\45\best_month_model.keras
#
# Epoch 46: loss did not improve from 0.00556
#
# Epoch 47: loss did not improve from 0.00556
#
# Epoch 48: loss did not improve from 0.00556
#
# Epoch 49: loss did not improve from 0.00556
#
# Epoch 50: loss did not improve from 0.00556
# Epoch 50: early stopping
# 47th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.03671, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 2: loss improved from 0.03671 to 0.03305, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 3: loss improved from 0.03305 to 0.02833, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 4: loss improved from 0.02833 to 0.02317, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 5: loss improved from 0.02317 to 0.01815, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 6: loss improved from 0.01815 to 0.01368, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 7: loss improved from 0.01368 to 0.00884, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 8: loss did not improve from 0.00884
#
# Epoch 9: loss improved from 0.00884 to 0.00857, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 10: loss improved from 0.00857 to 0.00674, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 11: loss improved from 0.00674 to 0.00642, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 12: loss did not improve from 0.00642
#
# Epoch 13: loss improved from 0.00642 to 0.00584, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 14: loss improved from 0.00584 to 0.00565, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 15: loss improved from 0.00565 to 0.00549, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 16: loss improved from 0.00549 to 0.00544, saving model to ../../result\month_min_max_m2o_japan\hybrid\46\best_month_model.keras
#
# Epoch 17: loss did not improve from 0.00544
#
# Epoch 18: loss did not improve from 0.00544
#
# Epoch 19: loss did not improve from 0.00544
#
# Epoch 20: loss did not improve from 0.00544
#
# Epoch 21: loss did not improve from 0.00544
# Epoch 21: early stopping
# 48th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.03946, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 2: loss improved from 0.03946 to 0.03567, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 3: loss improved from 0.03567 to 0.02946, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 4: loss improved from 0.02946 to 0.02270, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 5: loss improved from 0.02270 to 0.01874, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 6: loss improved from 0.01874 to 0.01545, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 7: loss improved from 0.01545 to 0.01046, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 8: loss improved from 0.01046 to 0.00817, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 9: loss did not improve from 0.00817
#
# Epoch 10: loss improved from 0.00817 to 0.00700, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 11: loss improved from 0.00700 to 0.00603, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 12: loss improved from 0.00603 to 0.00602, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 13: loss improved from 0.00602 to 0.00520, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 14: loss did not improve from 0.00520
#
# Epoch 15: loss improved from 0.00520 to 0.00496, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 16: loss improved from 0.00496 to 0.00474, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 17: loss improved from 0.00474 to 0.00445, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 18: loss did not improve from 0.00445
#
# Epoch 19: loss improved from 0.00445 to 0.00444, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 20: loss improved from 0.00444 to 0.00443, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 21: loss improved from 0.00443 to 0.00437, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 22: loss improved from 0.00437 to 0.00425, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 23: loss improved from 0.00425 to 0.00424, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 24: loss improved from 0.00424 to 0.00408, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 25: loss improved from 0.00408 to 0.00396, saving model to ../../result\month_min_max_m2o_japan\hybrid\47\best_month_model.keras
#
# Epoch 26: loss did not improve from 0.00396
#
# Epoch 27: loss did not improve from 0.00396
#
# Epoch 28: loss did not improve from 0.00396
#
# Epoch 29: loss did not improve from 0.00396
#
# Epoch 30: loss did not improve from 0.00396
# Epoch 30: early stopping
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# (8, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step

# %%
# file_path = '../../temp_data/influA_japan_temp_month.csv'
# #Load data set
# df = read_data(file_path, 7)
# df.corr()
# # plot_month_per_year(df, 'case')

# %%
# tmp = load_model(r'D:\my_study\gr3\DATN\result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras')
# forecasts = make_forecasts(testX, tmp)
# # invert predictions
# forecasts = inverse_transform(forecasts,scaler)
# testY_ = inverse_transform(testY,scaler)
# new_shape = (testY_.shape[0] * testY_.shape[1], testY_.shape[2])
        
# r2_image_path = os.path.join('.', 'r2_image.png')
# mae, mse, rmse, mape, rmspe, mare, nse, nnse, r2_pearson, r_value = save_plot(testY_.reshape(new_shape)[:,0].flatten(), forecasts.reshape(new_shape)[:,0].flatten(), r2_image_path)
