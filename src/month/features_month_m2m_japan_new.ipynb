# %%
from pandas import read_csv

def read_data(file_path, num_features = 2, have_time = False):
    series_influ_A_df = read_csv(file_path, engine='python')
    series_influ_A_df = series_influ_A_df.rename(columns= {"Influenza A - All types of surveillance": "case"})

    # because since 2011-03-01 It was announced that the H1N12009 flu had been controlled and treated as regular seasonal flu and
    # since 2020-02-01, it's time for covid 
    
    series_influ_A_df = series_influ_A_df.loc [(series_influ_A_df['Month'] >='2011-04-01') & (series_influ_A_df['Month'] <='2020-02-01')]
    if not have_time:
        return series_influ_A_df.dropna()[["case", "temp", "dew", "tempmax", "humidity","tempmin","windspeed"][:num_features]]
    return series_influ_A_df.dropna()[["Month", "case", "temp", "dew", "tempmax", "humidity","tempmin","windspeed"][:num_features+1]]

file_path = '../../temp_data/influA_japan_temp_month.csv'
#Load data set
df = read_data(file_path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error

def calculate_errors(y_true, y_pred):
    # Mean Absolute Error (MAE)
    mae = mean_absolute_error(y_true, y_pred)
    
    # Mean Squared Error (MSE)
    mse = mean_squared_error(y_true, y_pred)
    
    # Root Mean Squared Error (RMSE)
    rmse = np.sqrt(mse)
    
    # Mean Absolute Percentage Error (MAPE)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    
    # Root Mean Squared Percentage Error (RMSPE)
    rmspe = np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))) * 100
    
    # Mean Absolute Residual (MARE)
    mare = np.mean(np.abs(y_true - y_pred))
    
    # Nash-Sutcliffe Efficiency (NSE)
    nse = 1 - (np.sum((y_true - y_pred) ** 2) / np.sum((y_true - np.mean(y_true)) ** 2))
    
    # Normalized Nash-Sutcliffe Efficiency (NNSE)
    nnse = 1 - (np.sum((y_true - y_pred) ** 2) / np.sum((np.abs(y_true - np.mean(y_true)) + np.abs(y_pred - np.mean(y_true))) ** 2))
    
    return mae, mse, rmse, mape, rmspe, mare, nse, nnse

# %%
import numpy as np
from sklearn.metrics import r2_score

# def create_dataset(dataset, look_back=2, num_predict=1):
#     dataX, dataY = [], []
#     for i in range(0, len(dataset)-2 *look_back+1, look_back - num_predict):
#         a = dataset[i:(i+look_back)]
#         dataX.append(a)
#         dataY.append(dataset[i + look_back - num_predict : i+ 2*look_back-num_predict])
#     return np.array(dataX), np.array(dataY)

def create_dataset(dataset, look_back=1, num_predict = 1):
    dataX, dataY = [], []
    for i in range(0, len(dataset)-look_back, num_predict):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i + look_back: i+ look_back +num_predict])
    return np.array(dataX), np.array(dataY)

def forecast(input, model):
    input = input.reshape(1, input.shape[0], input.shape[1])
    predicted = model.predict(input, verbose=0)
    return predicted[0]

def make_forecasts(test, model):
    forecasts = []
    inputStart = test[0]
    inputX = inputStart.reshape(1, inputStart.shape[0], inputStart.shape[1])
    for i in range(len(test)):
        predicted = forecast(inputX[i], model)
        print(predicted.shape)
        forecasts.append(predicted)
        if i != len(test) -1:
            inputXContinue = np.vstack((inputX[-1][predicted.shape[0]:], predicted))
            inputX = np.append(inputX, [inputXContinue], axis=0)
    
    return np.array(forecasts)
def evaluate_forecasts(test, forecasts):
    from sklearn.metrics import mean_squared_error
    testScore = np.sqrt(mean_squared_error(test, forecasts))
    print('Test Score: %.2f RMSE' % (testScore))

def plot_r2(x,y, file_path=None):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Print error metrics
    mae, mse, rmse, mape, rmspe, mare, nse, nnse = calculate_errors(x, y)
    print(f'MAE: {mae:.2f}')
    print(f'MSE: {mse:.2f}')
    print(f'RMSE: {rmse:.2f}')
    print(f'MAPE: {mape:.2f}%')
    print(f'RMSPE: {rmspe:.2f}%')
    print(f'MARE: {mare:.2f}')
    print(f'NSE: {nse:.2f}')
    print(f'NNSE: {nnse:.2f}')

    # Create the scatter plot
    plt.figure(figsize=(10, 12))

    # Subplot 1: Scatter plot and regression line
    plt.subplot(3, 1, 1)
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, r2_line, color='red', marker="o", label=f'Regression line')
    plt.title('Correlation ')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title(f'Scatter Plot with R-squared Line\nCorrelation: {r_value:.2f}, R^2: {r2_pearson:.2f}')
    plt.legend()
    plt.grid()

    # Subplot 2: Real values over time
    plt.subplot(3, 1, 2)
    plt.plot( x, color='blue', label='Real_values')
    plt.xlabel('Time')
    plt.ylabel('Real_values')
    plt.title('Real Values over Time')
    plt.legend()
    plt.grid(True)
    
    # Subplot 3: Forecast values over time
    plt.subplot(3, 1, 3)
    plt.plot(y, color='green', label='Forecast_values')
    plt.xlabel('Time')
    plt.ylabel('Forecast_values')
    plt.title('Forecast Values over Time')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    # plt.savefig(file_path)
    # plt.close()
    plt.show()

def save_plot(x,y, file_path):
    import numpy as np
    import matplotlib.pyplot as plt
    from scipy import stats

    # Generate some sample data
    # x = y_inverse.flatten()
    # y = y_hat_inverse.flatten()

    # Compute the linear regression line
    slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

    # Create the R-squared line
    r2_line = slope * x + intercept
    r2 = r2_score(x, y)
    r2_pearson = r_value**2
    squared_error = np.square(x-y)

    # Print error metrics
    mae, mse, rmse, mape, rmspe, mare, nse, nnse = calculate_errors(x, y)

    # Create the scatter plot
    plt.figure(figsize=(10, 12))

    # Subplot 1: Scatter plot and regression line
    plt.subplot(3, 1, 1)
    plt.scatter(x, y, label='Data Points')
    plt.plot(x, r2_line, color='red', marker="o", label=f'Regression line')
    plt.title('Correlation ')

    # Add labels and title
    plt.xlabel('actual number of infection')
    plt.ylabel('forecast number of infection')
    plt.title(f'Scatter Plot with R-squared Line\nCorrelation: {r_value:.2f}, R^2: {r2_pearson:.2f}')
    plt.legend()
    plt.grid()

    # Subplot 2: Real values over time
    plt.subplot(3, 1, 2)
    plt.plot( x, color='blue', label='Real_values')
    plt.xlabel('Time')
    plt.ylabel('Real_values')
    plt.title('Real Values over Time')
    plt.legend()
    plt.grid(True)
    
    # Subplot 3: Forecast values over time
    plt.subplot(3, 1, 3)
    plt.plot(y, color='green', label='Forecast_values')
    plt.xlabel('Time')
    plt.ylabel('Forecast_values')
    plt.title('Forecast Values over Time')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(file_path)
    plt.close()
    return mae, mse, rmse, mape, rmspe, mare, nse, nnse, r2_pearson, r_value

def plot(testY, forecasts):
    import matplotlib.pyplot as plt
    forecastsPlot = np.empty([forecasts.shape[0]])
    forecastsPlot[:] = np.nan
    forecastsPlot[:] = forecasts[:,0].reshape(-1)
    testPlot = np.empty([testY.shape[0]])
    testPlot[:] = np.nan
    testPlot[:] = testY[:,0].reshape(-1)
    plt.plot(testPlot, "-y", label="actual", marker= '.')
    plt.plot(forecastsPlot, color = 'green', label="forecast", marker='x')
    plt.ylabel("Number of infections")
    plt.legend(["actual", "forecast"])
    plt.show()

def save(testY, forecasts, file_path):
    import matplotlib.pyplot as plt
    forecastsPlot = np.empty([forecasts.shape[0]])
    forecastsPlot[:] = np.nan
    forecastsPlot[:] = forecasts[:,0].reshape(-1)
    testPlot = np.empty([testY.shape[0]])
    testPlot[:] = np.nan
    testPlot[:] = testY[:,0].reshape(-1)
    plt.plot(testPlot, "-y", label="actual", marker= '.')
    plt.plot(forecastsPlot, color = 'green', label="forecast", marker='x')
    plt.ylabel("Number of infections")
    plt.legend(["actual", "forecast"])
    plt.savefig(file_path)
    plt.close()
    
def plot_month_per_year(df, key):
    import plotly.graph_objects as go
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df['Month'], y=df[key], mode='lines+markers', name=f'Influenza A Cases in month'))
    fig.update_layout(
        title='Influenza A Cases Over Time',
        xaxis=dict(
            title='Month',
            tickvals=df['Month'],  
            tickformat='%Y-%m',
            tickangle=90,
        ),
        yaxis=dict(title='Number of Cases'),
        showlegend=True,
    )
 
    # Show plot
    fig.show()
def inverse_transform(data, scaler):
    flattened_data = data.flatten()
    inverse_flattened_data = scaler.inverse_transform(flattened_data.reshape(-1,1))
    return inverse_flattened_data.reshape(data.shape)

# %%
# Preprocessing
def find_outliers_IQR(df):

    q1=df.quantile(0.25)

    q3=df.quantile(0.75)

    IQR=q3-q1

    outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

    return outliers

outliers = find_outliers_IQR(df['case'])

print('number of outliers: '+ str(len(outliers)))

print('max outlier value: '+ str(outliers.max()))

print('min outlier value: '+ str(outliers.min()))
# Out:
# number of outliers: 12
# max outlier value: 3158.0
# min outlier value: 1595.0

# %%
def remove_outlier_IQR(df):

    q1=df.quantile(0.25)

    q3=df.quantile(0.75)

    IQR=q3-q1

    upper = df[~(df>(q3+1.5*IQR))].max()

    lower = df[~(df<(q1-1.5*IQR))].min()

    df = np.where(
        df > upper,
        np.nan,
        np.where(df < lower,np.nan,df)
        )
    return df
impute_df = df.copy()
impute_df['case'] = remove_outlier_IQR(impute_df['case'])
# plot_month_per_year(impute_df, 'case')

# %%
linear_df = impute_df.copy()
linear_df['case'] = linear_df['case'].interpolate(method='linear')
# plot_month_per_year(linear_df, 'case')

# %%
spline_order_df = impute_df.copy()
spline_order_df['case'] = spline_order_df['case'].interpolate(method='spline', order=3)
# plot_month_per_year(spline_order_df, 'case')

# %%
def remove_outlier_impute(df, impute_method= 'linear'):
    output_df = df.copy()
    output_df["case"] = remove_outlier_IQR(output_df['case'])
    match impute_method:
        case 'linear':
            output_df['case'] = output_df['case'].interpolate(method='linear')
        case 'spline':
            output_df['case'] = output_df['case'].interpolate(method='spline', order=3)
        case _:
            pass
    return output_df

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
def moving_average(data, window_size):
    return data.rolling(window=window_size).mean()

def exponential_moving_average(data, span):
    return data.ewm(span=span, adjust=False).mean()

def prepare_data(df, is_ma=False, scaler =None):
    import pandas as pd
    df_ = pd.DataFrame()
    df_ = df.copy()
    if is_ma:
        # Apply Moving Average Filter
        window_size = 2
        
        df_['case'] = exponential_moving_average(df_['case'], window_size)
        df_ = df_.dropna()
    dataset = df_.values
    if scaler:
        flattened_dataset = dataset.flatten()
        dataset_trans = scaler.fit_transform(flattened_dataset.reshape(-1,1))
        dataset = dataset_trans.reshape(dataset.shape)
    return  dataset

scaler = MinMaxScaler()
dataset = prepare_data(df = linear_df, scaler=scaler, is_ma=True)

# %%
#process data
num_predict = 8
look_back = 8
test_size = num_predict
length = len(dataset)
dataset_length = length - (length -look_back) % num_predict
rest = length - dataset_length
dataset = dataset[rest:]
train = dataset[: -test_size,:]
test = dataset[-test_size - look_back:,:]

trainX, trainY = create_dataset(train, look_back, num_predict)
testX, testY = create_dataset(test, look_back, num_predict)

# %%
# i = 86
# print(trainX[i], trainY[i])
# len(trainX)
# j=0
# print(testX[j], testY[j])
import tensorflow as tf
from keras.losses import mean_squared_error, huber
def custom_loss(y_true, y_pred):
    return tf.sqrt(mean_squared_error(y_true, y_pred)/2)

# def custom_loss(y_true, y_pred):
#     """
#     Custom loss function that penalizes high losses.
#     """
#     # Calculate the standard loss
#     standard_loss = mean_squared_error(y_true ,y_pred)

#     # Apply a penalty function to the loss
#     penalty_factor = 3.0  # Adjust this value to control the penalty strength
#     penalty = tf.maximum(standard_loss - 0.05, 0.0) * penalty_factor

#     # Combine the standard loss and the penalty
#     total_loss = tf.sqrt(standard_loss) + penalty

#     return total_loss
def trend_loss(y_true, y_pred):
    """
    Custom loss function that focuses on capturing the trend of the time series.
    """
    true_trend = tf.math.subtract(y_true[:, 1:], y_true[:, :-1])
    pred_trend = tf.math.subtract(y_pred[:, 1:], y_pred[:, :-1])

    # Calculate the mean squared error of the trends
    trend_mse = tf.sqrt(mean_squared_error(true_trend, pred_trend))

    return trend_mse

def custom_loss_hubber_loss(y_true, y_pred):
    print(y_true.shape)
    hubber_loss = huber(y_true, y_pred, 0.1)
    trend_weight = 0
    trend_loss_value = trend_loss(y_true, y_pred)
    return (1 - trend_weight) *hubber_loss + trend_weight * trend_loss_value

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM, TimeDistributed, Input, Dropout, GRU,concatenate, Bidirectional
from sklearn.model_selection import GridSearchCV
from keras.saving import register_keras_serializable
from sklearn.metrics import r2_score


# hybrid model

def build_model(input_shape, output_units, use_layer='RNN', dropout=None, unit=64, optimizer='adam'):
    input = Input(shape=input_shape)
    # LSTM Model
    lstm_model = Sequential([
        LSTM(unit, activation='relu', return_sequences=True),
    ])

    match use_layer:
        case "LSTM":
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                LSTM(unit, activation='relu', return_sequences=True),
            ])
        case "GRU":
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                GRU(unit, activation='relu', return_sequences=True),
            ])
        case _:
            nn_model = Sequential([
                # Input(input_shape=input_shape),
                SimpleRNN(unit, activation='relu', return_sequences=True),
            ])

    nn_output = nn_model(input)


    lstm_output = lstm_model(input)

    combined_output = concatenate([lstm_output, nn_output])

    dense_layers = Sequential([
    TimeDistributed(Dense(units=output_units, activation='sigmoid' ))
    ])

    output = dense_layers(combined_output[:,-num_predict:])
    model = tf.keras.Model(inputs=input, outputs=output)

    model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.15), metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

#loss=tf.keras.losses.Huber(delta=0.1)

# def build_model(input_shape, dropout=None, unit=64, optimizer='adam'):
#     model = Sequential()
#     model.add(Input(shape=input_shape))
#     # model.add(GRU(units=unit, activation='relu', return_sequences=True))
#     model.add(SimpleRNN(units=unit, activation='relu'))
#     # model.add(LSTM(units=unit, activation='relu'))
#     model.add(Dense(units=input_shape[1], activation='sigmoid' ))
#     model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.15), metrics=[tf.keras.metrics.RootMeanSquaredError()])
#     return model

# def build_model(input_shape,output_units, use_layer= "RNN", dropout=None, unit=64, optimizer='adam'):
#     input = Input(shape=input_shape)

#     # GRU Model
#     match use_layer:
#         case "LSTM":
#             nn_model = Sequential([
#                 # Input(input_shape=input_shape),
#                 LSTM(unit, activation='relu', return_sequences=True),
#             ])
#         case "GRU":
#             nn_model = Sequential([
#                 # Input(input_shape=input_shape),
#                 GRU(unit, activation='relu', return_sequences=True),
#             ])
#         case _:
#             nn_model = Sequential([
#                 # Input(input_shape=input_shape),
#                 SimpleRNN(unit, activation='relu', return_sequences=True),
#             ])

#     nn_output = nn_model(input)

#     dense_layers = Sequential([
#     TimeDistributed(Dense(units=output_units, activation='sigmoid' ))
#     ])

#     output = dense_layers(nn_output[:,-num_predict:])
#     model = tf.keras.Model(inputs=input, outputs=output)
#     model.compile(optimizer=optimizer, loss=tf.keras.losses.Huber(delta=0.15), metrics=[tf.keras.metrics.RootMeanSquaredError()])
#     return model

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os
# model = build_model(input_shape=(trainX.shape[1], trainX.shape[2]), unit=32)
# es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
# file_path = os.path.join('../model', 'test.keras')

# mc = ModelCheckpoint(file_path, monitor='loss', mode='min', verbose=1, save_best_only=True)

# model.fit(trainX, trainY,batch_size=1, callbacks=[es, mc], verbose=0, epochs=200)

# %%
# from keras.models import load_model
# import os
# file_path = os.path.join('../model', 'test.keras')
# model = load_model(file_path, custom_objects={"custom_loss": custom_loss})


# forecasts = make_forecasts(testX, model)
# # invert predictions
# forecasts = inverse_transform(forecasts, scaler)
# testY_ = inverse_transform(testY, scaler)
# # evaluate_forecasts(testY_[:,0].reshape(-1), forecasts[:, 0].reshape(-1))

# %%
# new_shape = (testY_.shape[0] * testY_.shape[1], testY_.shape[2])
# plot(testY_.reshape(new_shape), forecasts.reshape(new_shape))

# %%
# plot_r2(testY_.reshape(new_shape)[:,0].flatten(), forecasts.reshape(new_shape)[:,0].flatten())

# %%
# trainY_hat = model.predict(trainX)
# trainY_hat_inverse = inverse_transform(trainY_hat, scaler)
# trainY_inverse = inverse_transform(trainY, scaler)
# new_shape_train = (trainY_inverse.shape[0] * trainY_inverse.shape[1], trainY_inverse.shape[2])
# plot(trainY_inverse.reshape(new_shape_train), trainY_hat_inverse.reshape(new_shape_train))

# %%
import itertools
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import os, json
from keras.models import load_model

def Month_HyperParameter_Tuning(config, scaler):
    impute_methods, look_backs, num_features, n_neurons, use_layers, is_mas = config
    possible_combinations = list(itertools.product(impute_methods, look_backs, num_features, n_neurons, use_layers, is_mas))
    print(possible_combinations)
    print('\n')

    hist = []
    for i in range(0, len(possible_combinations)):
        print(f'{i+1}th combination: \n')
        print('--------------------------------------------------------------------')
        impute_method, look_back, num_feature, n_neuron, use_layer, is_ma = possible_combinations[i]
        file_path = '../../temp_data/influA_japan_temp_month.csv'
        #Load data set
        df = read_data(file_path, num_features=num_feature)
        output_df = remove_outlier_impute(df, impute_method)

        scaler = MinMaxScaler()
        dataset = prepare_data(df = output_df, scaler=scaler, is_ma=is_ma)

        num_predict = 8
        # look_back = 8
        test_size = num_predict
        length = len(dataset)
        dataset_length = length - (length -look_back) % num_predict
        rest = length - dataset_length
        dataset = dataset[rest:]
        train = dataset[: -test_size,:]
        test = dataset[-test_size - look_back:,:]

        trainX, trainY = create_dataset(train, look_back, num_predict)
        testX, testY = create_dataset(test, look_back, num_predict)
        model = build_model(
            input_shape=(trainX.shape[1], trainX.shape[2]),
            output_units = trainX.shape[2],
            use_layer=use_layer,
            unit=n_neuron
            )
        es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
        result_dir = os.path.join("../../result", f"""month_min_max_m2o_japan_out_m_hybrid""", "RNN_LSTM_GRU")
        result_combination_dir = os.path.join(result_dir, str(i))
        os.makedirs(result_combination_dir, exist_ok=True)
        file_path = os.path.join(result_combination_dir, 'best_month_model.keras')
        mc = ModelCheckpoint(file_path, monitor='loss', mode='min', verbose=1, save_best_only=True)
        model.fit(trainX, trainY, batch_size=1, callbacks=[es, mc], verbose=0, epochs=200) 
        config = {
            "num_feature": num_feature,
            "use_layer": use_layer,
            "unit": n_neuron,
            "look_back": look_back,
            "is_ma": is_ma,
            "impute_method": impute_method,
        } 
        with open(os.path.join(result_combination_dir,'config.json'), 'w') as f:
            json.dump(config, f)

    for i in range(0, len(possible_combinations)):
        impute_method, look_back, num_feature, n_neuron, use_layer, is_ma = possible_combinations[i]

        file_path = '../../temp_data/influA_japan_temp_month.csv'
        #Load data set
        df = read_data(file_path, num_features=num_feature)
        output_df = remove_outlier_impute(df, impute_method)

        scaler = MinMaxScaler()
        dataset = prepare_data(df = output_df, scaler=scaler, is_ma=is_ma)

        num_predict = 8
        # look_back = 8
        test_size = num_predict
        length = len(dataset)
        dataset_length = length - (length -look_back) % num_predict
        rest = length - dataset_length
        dataset = dataset[rest:]
        train = dataset[: -test_size,:]
        test = dataset[-test_size - look_back:,:]

        trainX, trainY = create_dataset(train, look_back, num_predict)
        testX, testY = create_dataset(test, look_back, num_predict)


        result_dir = os.path.join("../../result", f"""month_min_max_m2o_japan_out_m_hybrid""", "RNN_LSTM_GRU")
        result_combination_dir = os.path.join(result_dir, str(i))
        os.makedirs(result_combination_dir, exist_ok=True)
        file_path = os.path.join(result_combination_dir, 'best_month_model.keras')

        model = load_model(file_path)

        forecasts = make_forecasts(testX, model)
        # invert predictions
        forecasts = inverse_transform(forecasts,scaler)
        testY_ = inverse_transform(testY,scaler)
        # evaluate_forecasts(testY_[:,0].reshape(-1), forecasts[:, 0].reshape(-1))
        new_shape = (testY_.shape[0] * testY_.shape[1], testY_.shape[2])
        
        r2_image_path = os.path.join(result_combination_dir, 'r2_image.png')
        mae, mse, rmse, mape, rmspe, mare, nse, nnse, r2_pearson, r_value = save_plot(testY_.reshape(new_shape)[:,0].flatten(), forecasts.reshape(new_shape)[:,0].flatten(), r2_image_path)
        hist.append(list((impute_method, look_back, num_feature, n_neuron, use_layer, is_ma, rmse, r2_pearson,r_value, mae, mse, mape, rmspe, mare, nse, nnse)))
        test_image_path = os.path.join(result_combination_dir, 'test.png')
        train_image_path = os.path.join(result_combination_dir, 'train.png')
        save(testY_.reshape(new_shape), forecasts.reshape(new_shape), test_image_path)

        trainY_hat = model.predict(trainX)
        trainY_hat_inverse = inverse_transform(trainY_hat, scaler)
        trainY_inverse = inverse_transform(trainY, scaler)
        new_shape_train = (trainY_inverse.shape[0] * trainY_inverse.shape[1], trainY_inverse.shape[2])
        save(trainY_inverse.reshape(new_shape_train), trainY_hat_inverse.reshape(new_shape_train), train_image_path)
    import pandas as pd
    hist_df = pd.DataFrame(hist)
    hist_df = hist_df.rename(columns={
        0: 'impute_method', 
        1: 'look_back', 
        2: 'num_feature', 
        3: 'unit', 
        4: 'use_layer', 
        5: 'is_ma', 
        6:'rmse', 
        7: 'r2_score', 
        8: 'correlation', 
        9:'mae', 
        10: 'mse', 
        11:'mape', 
        12:'rmspe', 
        13:'mare', 
        14:'nse', 
        15:'nnse'
        })
    hist_df = hist_df.sort_values(by=['r2_score'], ascending=False)
    hist_df.to_csv(os.path.join(result_dir, 'history.csv'))
    return hist_df

# %%
num_features = [2,3]
use_layers = ["GRU", "LSTM", "RNN"]
units = [64]
look_backs = [8,10]
is_mas = [True, False]
impute_methods = ["linear", "spline"]

config = [impute_methods, look_backs, num_features, units, use_layers, is_mas]
hist = Month_HyperParameter_Tuning(config, scaler)
# Out:
# [('linear', 8, 2, 64, 'GRU', True), ('linear', 8, 2, 64, 'GRU', False), ('linear', 8, 2, 64, 'LSTM', True), ('linear', 8, 2, 64, 'LSTM', False), ('linear', 8, 2, 64, 'RNN', True), ('linear', 8, 2, 64, 'RNN', False), ('linear', 8, 3, 64, 'GRU', True), ('linear', 8, 3, 64, 'GRU', False), ('linear', 8, 3, 64, 'LSTM', True), ('linear', 8, 3, 64, 'LSTM', False), ('linear', 8, 3, 64, 'RNN', True), ('linear', 8, 3, 64, 'RNN', False), ('linear', 10, 2, 64, 'GRU', True), ('linear', 10, 2, 64, 'GRU', False), ('linear', 10, 2, 64, 'LSTM', True), ('linear', 10, 2, 64, 'LSTM', False), ('linear', 10, 2, 64, 'RNN', True), ('linear', 10, 2, 64, 'RNN', False), ('linear', 10, 3, 64, 'GRU', True), ('linear', 10, 3, 64, 'GRU', False), ('linear', 10, 3, 64, 'LSTM', True), ('linear', 10, 3, 64, 'LSTM', False), ('linear', 10, 3, 64, 'RNN', True), ('linear', 10, 3, 64, 'RNN', False), ('spline', 8, 2, 64, 'GRU', True), ('spline', 8, 2, 64, 'GRU', False), ('spline', 8, 2, 64, 'LSTM', True), ('spline', 8, 2, 64, 'LSTM', False), ('spline', 8, 2, 64, 'RNN', True), ('spline', 8, 2, 64, 'RNN', False), ('spline', 8, 3, 64, 'GRU', True), ('spline', 8, 3, 64, 'GRU', False), ('spline', 8, 3, 64, 'LSTM', True), ('spline', 8, 3, 64, 'LSTM', False), ('spline', 8, 3, 64, 'RNN', True), ('spline', 8, 3, 64, 'RNN', False), ('spline', 10, 2, 64, 'GRU', True), ('spline', 10, 2, 64, 'GRU', False), ('spline', 10, 2, 64, 'LSTM', True), ('spline', 10, 2, 64, 'LSTM', False), ('spline', 10, 2, 64, 'RNN', True), ('spline', 10, 2, 64, 'RNN', False), ('spline', 10, 3, 64, 'GRU', True), ('spline', 10, 3, 64, 'GRU', False), ('spline', 10, 3, 64, 'LSTM', True), ('spline', 10, 3, 64, 'LSTM', False), ('spline', 10, 3, 64, 'RNN', True), ('spline', 10, 3, 64, 'RNN', False)]
#
#
# 1th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.04835, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 2: loss improved from 0.04835 to 0.04492, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 3: loss improved from 0.04492 to 0.03968, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 4: loss improved from 0.03968 to 0.03108, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 5: loss improved from 0.03108 to 0.02204, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 6: loss improved from 0.02204 to 0.01836, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 7: loss improved from 0.01836 to 0.01755, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 8: loss improved from 0.01755 to 0.01656, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 9: loss improved from 0.01656 to 0.01609, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 10: loss improved from 0.01609 to 0.01569, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 11: loss improved from 0.01569 to 0.01538, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 12: loss improved from 0.01538 to 0.01509, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 13: loss improved from 0.01509 to 0.01484, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 14: loss improved from 0.01484 to 0.01455, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 15: loss improved from 0.01455 to 0.01409, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 16: loss improved from 0.01409 to 0.01313, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 17: loss did not improve from 0.01313
#
# Epoch 18: loss improved from 0.01313 to 0.01246, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 19: loss improved from 0.01246 to 0.01223, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 20: loss improved from 0.01223 to 0.01169, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 21: loss did not improve from 0.01169
#
# Epoch 22: loss improved from 0.01169 to 0.01114, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 23: loss improved from 0.01114 to 0.01093, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 24: loss improved from 0.01093 to 0.01085, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 25: loss improved from 0.01085 to 0.01044, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 26: loss improved from 0.01044 to 0.01023, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 27: loss improved from 0.01023 to 0.01010, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 28: loss improved from 0.01010 to 0.00991, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 29: loss improved from 0.00991 to 0.00979, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 30: loss improved from 0.00979 to 0.00918, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 31: loss improved from 0.00918 to 0.00888, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 32: loss improved from 0.00888 to 0.00881, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 33: loss improved from 0.00881 to 0.00865, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 34: loss improved from 0.00865 to 0.00833, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 35: loss did not improve from 0.00833
#
# Epoch 36: loss improved from 0.00833 to 0.00778, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 37: loss did not improve from 0.00778
#
# Epoch 38: loss did not improve from 0.00778
#
# Epoch 39: loss improved from 0.00778 to 0.00762, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 40: loss did not improve from 0.00762
#
# Epoch 41: loss did not improve from 0.00762
#
# Epoch 42: loss did not improve from 0.00762
#
# Epoch 43: loss improved from 0.00762 to 0.00743, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 44: loss improved from 0.00743 to 0.00724, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 45: loss did not improve from 0.00724
#
# Epoch 46: loss did not improve from 0.00724
#
# Epoch 47: loss did not improve from 0.00724
#
# Epoch 48: loss did not improve from 0.00724
#
# Epoch 49: loss improved from 0.00724 to 0.00685, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 50: loss did not improve from 0.00685
#
# Epoch 51: loss did not improve from 0.00685
#
# Epoch 52: loss did not improve from 0.00685
#
# Epoch 53: loss improved from 0.00685 to 0.00663, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 54: loss did not improve from 0.00663
#
# Epoch 55: loss did not improve from 0.00663
#
# Epoch 56: loss improved from 0.00663 to 0.00645, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 57: loss did not improve from 0.00645
#
# Epoch 58: loss improved from 0.00645 to 0.00639, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 59: loss improved from 0.00639 to 0.00617, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 60: loss improved from 0.00617 to 0.00617, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 61: loss did not improve from 0.00617
#
# Epoch 62: loss did not improve from 0.00617
#
# Epoch 63: loss improved from 0.00617 to 0.00609, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 64: loss improved from 0.00609 to 0.00574, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 65: loss improved from 0.00574 to 0.00559, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 66: loss did not improve from 0.00559
#
# Epoch 67: loss improved from 0.00559 to 0.00553, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 68: loss improved from 0.00553 to 0.00540, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 69: loss did not improve from 0.00540
#
# Epoch 70: loss improved from 0.00540 to 0.00506, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 71: loss did not improve from 0.00506
#
# Epoch 72: loss did not improve from 0.00506
#
# Epoch 73: loss did not improve from 0.00506
#
# Epoch 74: loss improved from 0.00506 to 0.00498, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 75: loss improved from 0.00498 to 0.00496, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 76: loss improved from 0.00496 to 0.00455, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 77: loss did not improve from 0.00455
#
# Epoch 78: loss did not improve from 0.00455
#
# Epoch 79: loss improved from 0.00455 to 0.00442, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 80: loss improved from 0.00442 to 0.00432, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 81: loss did not improve from 0.00432
#
# Epoch 82: loss improved from 0.00432 to 0.00419, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 83: loss did not improve from 0.00419
#
# Epoch 84: loss did not improve from 0.00419
#
# Epoch 85: loss improved from 0.00419 to 0.00402, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 86: loss improved from 0.00402 to 0.00401, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 87: loss did not improve from 0.00401
#
# Epoch 88: loss improved from 0.00401 to 0.00391, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 89: loss improved from 0.00391 to 0.00388, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 90: loss did not improve from 0.00388
#
# Epoch 91: loss did not improve from 0.00388
#
# Epoch 92: loss improved from 0.00388 to 0.00377, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 93: loss improved from 0.00377 to 0.00371, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 94: loss did not improve from 0.00371
#
# Epoch 95: loss did not improve from 0.00371
#
# Epoch 96: loss improved from 0.00371 to 0.00362, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 97: loss did not improve from 0.00362
#
# Epoch 98: loss did not improve from 0.00362
#
# Epoch 99: loss improved from 0.00362 to 0.00359, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 100: loss improved from 0.00359 to 0.00358, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 101: loss did not improve from 0.00358
#
# Epoch 102: loss improved from 0.00358 to 0.00353, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 103: loss improved from 0.00353 to 0.00352, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 104: loss improved from 0.00352 to 0.00345, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 105: loss improved from 0.00345 to 0.00334, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 106: loss did not improve from 0.00334
#
# Epoch 107: loss improved from 0.00334 to 0.00331, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 108: loss improved from 0.00331 to 0.00330, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 109: loss did not improve from 0.00330
#
# Epoch 110: loss did not improve from 0.00330
#
# Epoch 111: loss improved from 0.00330 to 0.00322, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 112: loss improved from 0.00322 to 0.00321, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 113: loss did not improve from 0.00321
#
# Epoch 114: loss improved from 0.00321 to 0.00313, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 115: loss did not improve from 0.00313
#
# Epoch 116: loss did not improve from 0.00313
#
# Epoch 117: loss did not improve from 0.00313
#
# Epoch 118: loss did not improve from 0.00313
#
# Epoch 119: loss improved from 0.00313 to 0.00306, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\0\best_month_model.keras
#
# Epoch 120: loss did not improve from 0.00306
#
# Epoch 121: loss did not improve from 0.00306
#
# Epoch 122: loss did not improve from 0.00306
#
# Epoch 123: loss did not improve from 0.00306
#
# Epoch 124: loss did not improve from 0.00306
# Epoch 124: early stopping
# 2th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05111, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 2: loss improved from 0.05111 to 0.04862, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 3: loss improved from 0.04862 to 0.04489, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 4: loss improved from 0.04489 to 0.03889, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 5: loss improved from 0.03889 to 0.02893, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 6: loss improved from 0.02893 to 0.02064, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 7: loss improved from 0.02064 to 0.01752, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 8: loss improved from 0.01752 to 0.01663, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 9: loss improved from 0.01663 to 0.01606, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 10: loss improved from 0.01606 to 0.01560, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 11: loss improved from 0.01560 to 0.01522, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 12: loss improved from 0.01522 to 0.01491, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 13: loss improved from 0.01491 to 0.01464, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 14: loss improved from 0.01464 to 0.01449, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 15: loss improved from 0.01449 to 0.01418, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 16: loss improved from 0.01418 to 0.01400, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 17: loss improved from 0.01400 to 0.01383, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 18: loss improved from 0.01383 to 0.01367, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 19: loss improved from 0.01367 to 0.01352, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 20: loss improved from 0.01352 to 0.01341, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 21: loss improved from 0.01341 to 0.01323, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 22: loss improved from 0.01323 to 0.01310, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 23: loss improved from 0.01310 to 0.01297, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 24: loss improved from 0.01297 to 0.01288, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 25: loss improved from 0.01288 to 0.01267, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 26: loss improved from 0.01267 to 0.01252, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 27: loss improved from 0.01252 to 0.01230, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 28: loss improved from 0.01230 to 0.01193, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 29: loss improved from 0.01193 to 0.01153, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 30: loss did not improve from 0.01153
#
# Epoch 31: loss improved from 0.01153 to 0.01111, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 32: loss improved from 0.01111 to 0.01078, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 33: loss improved from 0.01078 to 0.00998, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 34: loss improved from 0.00998 to 0.00980, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 35: loss improved from 0.00980 to 0.00974, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 36: loss improved from 0.00974 to 0.00927, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 37: loss improved from 0.00927 to 0.00889, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 38: loss improved from 0.00889 to 0.00876, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 39: loss improved from 0.00876 to 0.00855, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 40: loss improved from 0.00855 to 0.00832, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 41: loss improved from 0.00832 to 0.00807, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 42: loss improved from 0.00807 to 0.00763, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 43: loss did not improve from 0.00763
#
# Epoch 44: loss improved from 0.00763 to 0.00746, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 45: loss improved from 0.00746 to 0.00720, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 46: loss did not improve from 0.00720
#
# Epoch 47: loss did not improve from 0.00720
#
# Epoch 48: loss did not improve from 0.00720
#
# Epoch 49: loss did not improve from 0.00720
#
# Epoch 50: loss improved from 0.00720 to 0.00703, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 51: loss did not improve from 0.00703
#
# Epoch 52: loss improved from 0.00703 to 0.00695, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 53: loss did not improve from 0.00695
#
# Epoch 54: loss did not improve from 0.00695
#
# Epoch 55: loss improved from 0.00695 to 0.00689, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 56: loss improved from 0.00689 to 0.00684, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 57: loss improved from 0.00684 to 0.00680, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 58: loss did not improve from 0.00680
#
# Epoch 59: loss did not improve from 0.00680
#
# Epoch 60: loss improved from 0.00680 to 0.00677, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 61: loss improved from 0.00677 to 0.00673, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 62: loss improved from 0.00673 to 0.00669, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 63: loss improved from 0.00669 to 0.00660, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 64: loss improved from 0.00660 to 0.00658, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 65: loss improved from 0.00658 to 0.00657, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 66: loss did not improve from 0.00657
#
# Epoch 67: loss improved from 0.00657 to 0.00647, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 68: loss did not improve from 0.00647
#
# Epoch 69: loss improved from 0.00647 to 0.00643, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 70: loss improved from 0.00643 to 0.00633, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 71: loss did not improve from 0.00633
#
# Epoch 72: loss did not improve from 0.00633
#
# Epoch 73: loss did not improve from 0.00633
#
# Epoch 74: loss improved from 0.00633 to 0.00610, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 75: loss did not improve from 0.00610
#
# Epoch 76: loss improved from 0.00610 to 0.00605, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 77: loss improved from 0.00605 to 0.00600, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 78: loss improved from 0.00600 to 0.00585, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 79: loss did not improve from 0.00585
#
# Epoch 80: loss improved from 0.00585 to 0.00566, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 81: loss did not improve from 0.00566
#
# Epoch 82: loss did not improve from 0.00566
#
# Epoch 83: loss improved from 0.00566 to 0.00545, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 84: loss did not improve from 0.00545
#
# Epoch 85: loss improved from 0.00545 to 0.00530, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 86: loss improved from 0.00530 to 0.00527, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 87: loss did not improve from 0.00527
#
# Epoch 88: loss improved from 0.00527 to 0.00506, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 89: loss did not improve from 0.00506
#
# Epoch 90: loss did not improve from 0.00506
#
# Epoch 91: loss did not improve from 0.00506
#
# Epoch 92: loss improved from 0.00506 to 0.00493, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 93: loss did not improve from 0.00493
#
# Epoch 94: loss improved from 0.00493 to 0.00483, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 95: loss did not improve from 0.00483
#
# Epoch 96: loss did not improve from 0.00483
#
# Epoch 97: loss did not improve from 0.00483
#
# Epoch 98: loss did not improve from 0.00483
#
# Epoch 99: loss improved from 0.00483 to 0.00482, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 100: loss improved from 0.00482 to 0.00476, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 101: loss did not improve from 0.00476
#
# Epoch 102: loss improved from 0.00476 to 0.00463, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 103: loss did not improve from 0.00463
#
# Epoch 104: loss did not improve from 0.00463
#
# Epoch 105: loss did not improve from 0.00463
#
# Epoch 106: loss did not improve from 0.00463
#
# Epoch 107: loss improved from 0.00463 to 0.00457, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 108: loss improved from 0.00457 to 0.00452, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 109: loss did not improve from 0.00452
#
# Epoch 110: loss improved from 0.00452 to 0.00442, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 111: loss improved from 0.00442 to 0.00431, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 112: loss improved from 0.00431 to 0.00431, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 113: loss improved from 0.00431 to 0.00427, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 114: loss improved from 0.00427 to 0.00426, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 115: loss did not improve from 0.00426
#
# Epoch 116: loss did not improve from 0.00426
#
# Epoch 117: loss improved from 0.00426 to 0.00421, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 118: loss did not improve from 0.00421
#
# Epoch 119: loss improved from 0.00421 to 0.00416, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 120: loss did not improve from 0.00416
#
# Epoch 121: loss improved from 0.00416 to 0.00414, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 122: loss did not improve from 0.00414
#
# Epoch 123: loss did not improve from 0.00414
#
# Epoch 124: loss improved from 0.00414 to 0.00400, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 125: loss did not improve from 0.00400
#
# Epoch 126: loss did not improve from 0.00400
#
# Epoch 127: loss improved from 0.00400 to 0.00399, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 128: loss improved from 0.00399 to 0.00391, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 129: loss did not improve from 0.00391
#
# Epoch 130: loss did not improve from 0.00391
#
# Epoch 131: loss improved from 0.00391 to 0.00385, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 132: loss did not improve from 0.00385
#
# Epoch 133: loss did not improve from 0.00385
#
# Epoch 134: loss improved from 0.00385 to 0.00376, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 135: loss improved from 0.00376 to 0.00373, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 136: loss improved from 0.00373 to 0.00371, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 137: loss improved from 0.00371 to 0.00366, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 138: loss did not improve from 0.00366
#
# Epoch 139: loss did not improve from 0.00366
#
# Epoch 140: loss did not improve from 0.00366
#
# Epoch 141: loss improved from 0.00366 to 0.00351, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 142: loss did not improve from 0.00351
#
# Epoch 143: loss improved from 0.00351 to 0.00341, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\1\best_month_model.keras
#
# Epoch 144: loss did not improve from 0.00341
#
# Epoch 145: loss did not improve from 0.00341
#
# Epoch 146: loss did not improve from 0.00341
#
# Epoch 147: loss did not improve from 0.00341
#
# Epoch 148: loss did not improve from 0.00341
# Epoch 148: early stopping
# 3th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.04974, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 2: loss improved from 0.04974 to 0.04781, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 3: loss improved from 0.04781 to 0.04484, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 4: loss improved from 0.04484 to 0.03932, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 5: loss improved from 0.03932 to 0.02953, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 6: loss improved from 0.02953 to 0.02328, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 7: loss improved from 0.02328 to 0.02093, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 8: loss improved from 0.02093 to 0.01985, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 9: loss improved from 0.01985 to 0.01907, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 10: loss improved from 0.01907 to 0.01847, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 11: loss improved from 0.01847 to 0.01800, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 12: loss improved from 0.01800 to 0.01750, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 13: loss improved from 0.01750 to 0.01714, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 14: loss improved from 0.01714 to 0.01681, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 15: loss improved from 0.01681 to 0.01652, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 16: loss improved from 0.01652 to 0.01628, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 17: loss improved from 0.01628 to 0.01603, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 18: loss improved from 0.01603 to 0.01584, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 19: loss improved from 0.01584 to 0.01564, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 20: loss improved from 0.01564 to 0.01548, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 21: loss improved from 0.01548 to 0.01533, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 22: loss improved from 0.01533 to 0.01518, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 23: loss improved from 0.01518 to 0.01506, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 24: loss improved from 0.01506 to 0.01495, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 25: loss improved from 0.01495 to 0.01484, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 26: loss improved from 0.01484 to 0.01472, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 27: loss improved from 0.01472 to 0.01462, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 28: loss improved from 0.01462 to 0.01451, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 29: loss improved from 0.01451 to 0.01440, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 30: loss improved from 0.01440 to 0.01428, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 31: loss improved from 0.01428 to 0.01403, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 32: loss did not improve from 0.01403
#
# Epoch 33: loss improved from 0.01403 to 0.01396, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 34: loss improved from 0.01396 to 0.01387, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 35: loss improved from 0.01387 to 0.01366, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 36: loss improved from 0.01366 to 0.01355, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 37: loss improved from 0.01355 to 0.01353, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 38: loss improved from 0.01353 to 0.01352, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 39: loss improved from 0.01352 to 0.01317, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\2\best_month_model.keras
#
# Epoch 40: loss did not improve from 0.01317
#
# Epoch 41: loss did not improve from 0.01317
#
# Epoch 42: loss did not improve from 0.01317
#
# Epoch 43: loss did not improve from 0.01317
#
# Epoch 44: loss did not improve from 0.01317
# Epoch 44: early stopping
# 4th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05180, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 2: loss improved from 0.05180 to 0.05000, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 3: loss improved from 0.05000 to 0.04715, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 4: loss improved from 0.04715 to 0.04163, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 5: loss improved from 0.04163 to 0.03169, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 6: loss improved from 0.03169 to 0.02388, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 7: loss improved from 0.02388 to 0.02049, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 8: loss improved from 0.02049 to 0.01941, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 9: loss improved from 0.01941 to 0.01847, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 10: loss improved from 0.01847 to 0.01785, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 11: loss improved from 0.01785 to 0.01733, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 12: loss improved from 0.01733 to 0.01686, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 13: loss improved from 0.01686 to 0.01650, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 14: loss improved from 0.01650 to 0.01614, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 15: loss improved from 0.01614 to 0.01587, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 16: loss improved from 0.01587 to 0.01556, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 17: loss improved from 0.01556 to 0.01529, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 18: loss improved from 0.01529 to 0.01512, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 19: loss improved from 0.01512 to 0.01484, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 20: loss improved from 0.01484 to 0.01471, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 21: loss improved from 0.01471 to 0.01450, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 22: loss improved from 0.01450 to 0.01438, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 23: loss improved from 0.01438 to 0.01423, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 24: loss improved from 0.01423 to 0.01412, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 25: loss improved from 0.01412 to 0.01401, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 26: loss improved from 0.01401 to 0.01390, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 27: loss improved from 0.01390 to 0.01380, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 28: loss improved from 0.01380 to 0.01371, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 29: loss improved from 0.01371 to 0.01360, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 30: loss improved from 0.01360 to 0.01352, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 31: loss improved from 0.01352 to 0.01342, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 32: loss improved from 0.01342 to 0.01333, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 33: loss improved from 0.01333 to 0.01324, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 34: loss improved from 0.01324 to 0.01317, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 35: loss improved from 0.01317 to 0.01306, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 36: loss improved from 0.01306 to 0.01297, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 37: loss improved from 0.01297 to 0.01289, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 38: loss improved from 0.01289 to 0.01280, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 39: loss improved from 0.01280 to 0.01272, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 40: loss improved from 0.01272 to 0.01265, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 41: loss improved from 0.01265 to 0.01256, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 42: loss improved from 0.01256 to 0.01247, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 43: loss improved from 0.01247 to 0.01239, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 44: loss improved from 0.01239 to 0.01229, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 45: loss improved from 0.01229 to 0.01212, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\3\best_month_model.keras
#
# Epoch 46: loss did not improve from 0.01212
#
# Epoch 47: loss did not improve from 0.01212
#
# Epoch 48: loss did not improve from 0.01212
#
# Epoch 49: loss did not improve from 0.01212
#
# Epoch 50: loss did not improve from 0.01212
# Epoch 50: early stopping
# 5th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05018, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 2: loss improved from 0.05018 to 0.04397, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 3: loss improved from 0.04397 to 0.03161, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 4: loss improved from 0.03161 to 0.02241, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 5: loss improved from 0.02241 to 0.01967, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 6: loss improved from 0.01967 to 0.01883, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 7: loss improved from 0.01883 to 0.01771, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 8: loss improved from 0.01771 to 0.01720, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 9: loss improved from 0.01720 to 0.01662, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 10: loss improved from 0.01662 to 0.01618, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 11: loss improved from 0.01618 to 0.01581, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 12: loss improved from 0.01581 to 0.01548, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 13: loss improved from 0.01548 to 0.01524, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# Epoch 14: loss improved from 0.01524 to 0.01498, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\4\best_month_model.keras
#
# ...
#
# Epoch 24: loss improved from 0.00952 to 0.00947, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\44\best_month_model.keras
#
# Epoch 25: loss did not improve from 0.00947
#
# Epoch 26: loss did not improve from 0.00947
#
# Epoch 27: loss did not improve from 0.00947
#
# Epoch 28: loss did not improve from 0.00947
#
# Epoch 29: loss did not improve from 0.00947
# Epoch 29: early stopping
# 46th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05551, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 2: loss improved from 0.05551 to 0.05324, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 3: loss improved from 0.05324 to 0.04935, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 4: loss improved from 0.04935 to 0.04011, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 5: loss improved from 0.04011 to 0.02382, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 6: loss improved from 0.02382 to 0.01579, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 7: loss improved from 0.01579 to 0.01258, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 8: loss improved from 0.01258 to 0.01111, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 9: loss improved from 0.01111 to 0.01036, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 10: loss improved from 0.01036 to 0.00980, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 11: loss improved from 0.00980 to 0.00950, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 12: loss improved from 0.00950 to 0.00926, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 13: loss improved from 0.00926 to 0.00909, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 14: loss improved from 0.00909 to 0.00897, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 15: loss improved from 0.00897 to 0.00887, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 16: loss improved from 0.00887 to 0.00881, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 17: loss improved from 0.00881 to 0.00875, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 18: loss improved from 0.00875 to 0.00871, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 19: loss improved from 0.00871 to 0.00868, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 20: loss improved from 0.00868 to 0.00865, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 21: loss improved from 0.00865 to 0.00862, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 22: loss improved from 0.00862 to 0.00861, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 23: loss improved from 0.00861 to 0.00859, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 24: loss improved from 0.00859 to 0.00858, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 25: loss improved from 0.00858 to 0.00856, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 26: loss improved from 0.00856 to 0.00856, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 27: loss improved from 0.00856 to 0.00853, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 28: loss improved from 0.00853 to 0.00852, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 29: loss improved from 0.00852 to 0.00851, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 30: loss improved from 0.00851 to 0.00849, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 31: loss improved from 0.00849 to 0.00848, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 32: loss improved from 0.00848 to 0.00847, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 33: loss improved from 0.00847 to 0.00845, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 34: loss improved from 0.00845 to 0.00841, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 35: loss improved from 0.00841 to 0.00839, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 36: loss improved from 0.00839 to 0.00836, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 37: loss improved from 0.00836 to 0.00830, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 38: loss did not improve from 0.00830
#
# Epoch 39: loss improved from 0.00830 to 0.00789, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\45\best_month_model.keras
#
# Epoch 40: loss did not improve from 0.00789
#
# Epoch 41: loss did not improve from 0.00789
#
# Epoch 42: loss did not improve from 0.00789
#
# Epoch 43: loss did not improve from 0.00789
#
# Epoch 44: loss did not improve from 0.00789
# Epoch 44: early stopping
# 47th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05380, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 2: loss improved from 0.05380 to 0.05013, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 3: loss improved from 0.05013 to 0.04089, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 4: loss improved from 0.04089 to 0.02272, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 5: loss improved from 0.02272 to 0.01381, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 6: loss improved from 0.01381 to 0.01231, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 7: loss improved from 0.01231 to 0.01055, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 8: loss improved from 0.01055 to 0.00993, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 9: loss improved from 0.00993 to 0.00959, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 10: loss improved from 0.00959 to 0.00927, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 11: loss improved from 0.00927 to 0.00905, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 12: loss did not improve from 0.00905
#
# Epoch 13: loss improved from 0.00905 to 0.00838, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\46\best_month_model.keras
#
# Epoch 14: loss did not improve from 0.00838
#
# Epoch 15: loss did not improve from 0.00838
#
# Epoch 16: loss did not improve from 0.00838
#
# Epoch 17: loss did not improve from 0.00838
#
# Epoch 18: loss did not improve from 0.00838
# Epoch 18: early stopping
# 48th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: loss improved from inf to 0.05367, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 2: loss improved from 0.05367 to 0.04545, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 3: loss improved from 0.04545 to 0.02414, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 4: loss improved from 0.02414 to 0.01401, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 5: loss improved from 0.01401 to 0.01071, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 6: loss improved from 0.01071 to 0.00964, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 7: loss improved from 0.00964 to 0.00921, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 8: loss improved from 0.00921 to 0.00898, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 9: loss improved from 0.00898 to 0.00883, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 10: loss improved from 0.00883 to 0.00876, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 11: loss improved from 0.00876 to 0.00870, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 12: loss improved from 0.00870 to 0.00865, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 13: loss improved from 0.00865 to 0.00861, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 14: loss improved from 0.00861 to 0.00858, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 15: loss improved from 0.00858 to 0.00855, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 16: loss improved from 0.00855 to 0.00852, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 17: loss did not improve from 0.00852
#
# Epoch 18: loss improved from 0.00852 to 0.00847, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 19: loss improved from 0.00847 to 0.00845, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 20: loss improved from 0.00845 to 0.00844, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 21: loss improved from 0.00844 to 0.00840, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 22: loss improved from 0.00840 to 0.00838, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 23: loss improved from 0.00838 to 0.00835, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 24: loss improved from 0.00835 to 0.00831, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 25: loss improved from 0.00831 to 0.00825, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 26: loss improved from 0.00825 to 0.00808, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 27: loss improved from 0.00808 to 0.00797, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 28: loss improved from 0.00797 to 0.00726, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 29: loss did not improve from 0.00726
#
# Epoch 30: loss did not improve from 0.00726
#
# Epoch 31: loss did not improve from 0.00726
#
# Epoch 32: loss did not improve from 0.00726
#
# Epoch 33: loss improved from 0.00726 to 0.00615, saving model to ../../result\month_min_max_m2o_japan_out_m_hybrid\RNN_LSTM_GRU\47\best_month_model.keras
#
# Epoch 34: loss did not improve from 0.00615
#
# Epoch 35: loss did not improve from 0.00615
#
# Epoch 36: loss did not improve from 0.00615
#
# Epoch 37: loss did not improve from 0.00615
#
# Epoch 38: loss did not improve from 0.00615
# Epoch 38: early stopping
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# (8, 2)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# (8, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step

# %%
# file_path = '../../temp_data/influA_japan_temp_month.csv'
# #Load data set
# df = read_data(file_path, 7)
# df.corr()
# # plot_month_per_year(df, 'case')

# %%
# tmp = load_model(r'D:\my_study\gr3\DATN\result\month_min_max_m2o_japan\RNN_LSTM_GRU\0\best_month_model.keras')
# forecasts = make_forecasts(testX, tmp)
# # invert predictions
# forecasts = inverse_transform(forecasts,scaler)
# testY_ = inverse_transform(testY,scaler)
# new_shape = (testY_.shape[0] * testY_.shape[1], testY_.shape[2])
        
# r2_image_path = os.path.join('.', 'r2_image.png')
# mae, mse, rmse, mape, rmspe, mare, nse, nnse, r2_pearson, r_value = save_plot(testY_.reshape(new_shape)[:,0].flatten(), forecasts.reshape(new_shape)[:,0].flatten(), r2_image_path)
